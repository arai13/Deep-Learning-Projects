# %% [markdown]
# Ash Rai <br>
# CSC 675, Spring 2022
#
# # Project 4: Text Generation with LSTM and Transformers Networks

# %% [markdown]
# ## Initial Experimentation (Section 8.1 Implementation)
#
# Reweighting a probability distribution to a different temperature

# %%
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %% [markdown]
# ### Implementing character-level LSTM text generation
#
# #### Preparing the Data
#
# Downloading and parsing the initial text file

# %%
import tensorflow.keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# Vectorizing sequences of characters

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# #### Building the Network
#
# Single-layer LSTM model for next-character prediction

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Model compilation configuration

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# #### Training and Sampling
#
# Function to sample the next character given the model’s predictions

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Text-generation loop

# %%
import random
import sys

def run_text_generation(epoch_size, generation_size):
    accuracy_values = []
    loss_values = []
    for epoch in range(1, epoch_size):
        print()
        print('------------- epoch', epoch, '-------------')
        # Fit the model for 1 epoch on the available training data
        history = model.fit(x, y,
                  batch_size=128,
                  epochs=1)

        # Select a text seed at random
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated_text = text[start_index: start_index + maxlen]
        print('--- Generating with seed: "' + generated_text + '"')

        for temperature in [0.2, 0.5, 1.0, 1.2]:
            print('------ temperature:', temperature)
            sys.stdout.write(generated_text)

            # We generate 400 characters
            for i in range(generation_size):
                sampled = np.zeros((1, maxlen, len(chars)))
                for t, char in enumerate(generated_text):
                    sampled[0, t, char_indices[char]] = 1.

                preds = model.predict(sampled, verbose=0)[0]
                next_index = sample(preds, temperature)
                next_char = chars[next_index]

                generated_text += next_char
                generated_text = generated_text[1:]

                sys.stdout.write(next_char)
                sys.stdout.flush()
            print()

# %%
run_text_generation(60, 400)
# Out:
# ------------- epoch 1 -------------
# 1565/1565 [==============================] - 11s 6ms/step - loss: 2.2600
# --- Generating with seed: "indly patronage and defense of whatever
# is misunderstood and"
# ------ temperature: 0.2
# indly patronage and defense of whatever
# is misunderstood and the present and the men of the one indection of the men in the desire and who have have and the super and which he sensed the must attering the problem and such and the one as the and with the sensibe the supers and which is all the super the sense the precience of the mand the super the one as the all the perhaps and the restrestion of the and such and the were of the reselves the and such and t
# ------ temperature: 0.5
# the and such and the were of the reselves the and such and the man eselfing the subject of the liutlity, and the restiny it is the indeces has decited and chat all the a who have in the langer of the god the decention of a thing as the mands of the present and have at last extrement that the great of the all the propersion of the something is all more the world has and disconsiber and his with it is indeem the upting the matter and has the philosophy--the
# ------ temperature: 1.0
# is indeem the upting the matter and has the philosophy--the coud for which theage
# meined resentibening indutumed" which is a
# rever in cletung's itself of have by nese of
# the theaged the ewise, as resprt?f itself and it as thutly this neceld very or inderence or
# this essivity inde. it
# asticate whinhm, ithiphary nother a pleyhe to aid new them andsest poteris
# and withyut--bscfusedises and ily, is,---he whuma enemenised they he mure coursevebues juss busnst a
# ------ temperature: 1.2
# -he whuma enemenised they he mure coursevebues juss busnst all-many tides hemselves, is god
# time
# allod, w
# o.--jul,ufie this ons quernand)--aftise who wording throuk of except dijure that theight, anm infol -'le mega de sensibneringlly in the reci2s; wor
# ispediagematily, thosemely mistly--and a menstable d, obeasul alte--mear, flo delw icst; itself lowed while allst"--ither we--rulse, the subojrity, it, as the dguced y edacrion of dhereand.
#
#  inshrees of
#
# ------------- epoch 2 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.6102
# --- Generating with seed: "and think that as
# friends they have a right to ease, one doe"
# ------ temperature: 0.2
# and think that as
# friends they have a right to ease, one does not the same the contraint of the same this present the far the most the spirit the has the distinguality of the such a man with the more the some the morality of the schould has a philosophers of the same this sense of the greation of the many and the same this conscience of the same this is the world of the presence, in the self--and one the former the same this resist of the world of the grea
# ------ temperature: 0.5
# one the former the same this resist of the world of the greates
# of the more and the rational of the prodsition of it is the repromise of his perhaps to the end that pain, in a nature this it is power of the highest of a many sign whene may be differes and the desertion the to different and do this in the historistional the has the world the been many
# during it is the far i who forman of the end the most the geen the proves be the europe, is it is the germa
# ------ temperature: 1.0
# e most the geen the proves be the europe, is it is the germany-down, howld.ter im no drung in the osterihal as of a sorieg--that who with the delugness, withath and
# knowled" as of harbsing revelened ?      sto
# essely shall any prible now of the peenouge
# unit:
#  gudeprs under here, as a
# through the
# hantey asga
# putes are withs1; he is manby arture is i the this smilt, this
# revouudme music apporchable is geriness,  that is "the spoglints, in refole of he is f
# ------ temperature: 1.2
# e is geriness,  that is "the spoglints, in refole of he is firitedecally; the general
# po]sy,
# curened does
# the passicity fath this to "this hat aol gede. i doen, a internaps
# oried oridowa, latforionectoid, revivionget lire, ib keepsenys oftfur
# capogable
# grissyndssdina such has backing enterest williness andsechatiate--self, bulnasefvined, ill--natuoded in 0veren its:"-any
# danman presen pos.; but there raveavien-racking that why who
# them will
# aboirr dreke fo
#
# ------------- epoch 3 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.5223
# --- Generating with seed: " strange, their horror of
# the bad taste even of lively curio"
# ------ temperature: 0.2
#  strange, their horror of
# the bad taste even of lively curiosical science. and the proves and such and being and science of the such and such and the moral the self-such and the conduring the property and such and the sure and later and the sense of the conduction of the sense of the sense of the surtent and such and the subtless of the world and self-something and such and and such and the man which the property and stands and self-sension of the greeness
# ------ temperature: 0.5
# ich the property and stands and self-sension of the greeness of the the will the sunter comprehend the desired the great and same origin to possessing in all the elicism of the german in the greet only being call and good the end the greatest ineself, and can present man and confuiring moral to being the maghes of the morality of the philosopher, and faltical and the end is a stracting and for confuiring and the destrictual seems and seem of considerations
# ------ temperature: 1.0
# fuiring and the destrictual seems and seem of considerations of disterneed,
# thwhich for
# doman that to the  complot, thative be disco andis the
# and saveal menhates--the science of tural, an in the inclussss, with nighterate on impatifices of the been were to wher
# from the crulty was the ideal origin, theregran", in their same races" of greaten superfuances. ang pronound of thut it life praid., therefores gree, tequanned
# on
# the communness--they all man's und
# ------ temperature: 1.2
# efores gree, tequanned
# on
# the communness--they all man's under the idea suce-haming vircarics sru, were, and vale thostsy meals chilational and of i wouthifes leannby, the supiren ones justualf, low excite of
# lenty as
# most unabvert" being of con or and social waste ducaes
# ann hearted
# funral sifficeless ho) the seask , earbeness and recicils of serurational
# circumsknon intolit is peatiins of responitud theturheftery and
# and burchisen." necchince
# once o
# hmiq
#
# ------------- epoch 4 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4761
# --- Generating with seed: "ssuredly an inversion effected only after long
# struggle and "
# ------ temperature: 0.2
# ssuredly an inversion effected only after long
# struggle and the senses and the present a matter and the most present and the present a present and the strengthess of strengthess, and the strengthest man and the strengthess of strengthess of the strengthess of the strengthest and the strengthest and the states and the most present and the proves who has a will to the most be and the strengthess of man which he was the most master of suffered and the present
# ------ temperature: 0.5
# man which he was the most master of suffered and the present rest that it is also this nature of one all the prefure to being for the possess, or himself. the instincts of the passions and than the believe the
# expetuation of the strengthe, the other over--but not to the noble life man and the most distance of the senses and all the fundamental states which the unexplianishs the state of the problem as a proves the expedione of the involugness of his condit
# ------ temperature: 1.0
# m as a proves the expedione of the involugness of his conditions.--or an "most back. say. in the gemnt is for sochentict.
#
#
# y3t
# pquirhensibjly, in regarded with unyetauhe he hangg yesses,
# surides to disfound from a
# spirit of the the evolution, not of the last
# to bely case-nopterous, but concite of ressol of think,
# and poses for the senses aid. de a.
# "befoenged--for the at latk of eneardians--is telirate
# other more dase? understand above it have beside cont
# ------ temperature: 1.2
# lirate
# other more dase? understand above it have beside contratible treas, which much part matuceness with a most himy has hither the
# mather has qjest
# are netcommatiats walt compuch hreithar risement hime passions
# a celfurebor
# foursings,--cates that rouse, the ob, unechorws--of dimimary unabopext
# to "germussib" up first lasty, or furth into "constitutaus attruish"
# at, in its,ly,grinice what
# foodves europe, hupingake--would nor,
# regerations, funis some.p.
#
#
#
# ------------- epoch 5 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4471
# --- Generating with seed: "ge even in its suspicion and remorse of conscience: how
# it u"
# ------ temperature: 0.2
# ge even in its suspicion and remorse of conscience: how
# it under the most and are a destries of the most sense of the senses and later and the more that and the more a more seems to the more and the desire and some the senses and that the sense is the sense of the senses and all the desire and the sense of the senses and strong the interpretation of the actions and society and the words and most and and the senses and that which the sense of the sense of t
# ------ temperature: 0.5
# nd and the senses and that which the sense of the sense of the higher according to the way for the moral other great and to be the asterned to the rations of the will and sympathy of philosopher that the more reason and look and instinction in takes have no longer that we may not always see with the fact of the certain bad all the "imposition of the truth, that a play--the rest and man is in every concerngmine with the same though and all the most and as a
# ------ temperature: 1.0
#  concerngmine with the same though and all the most and as a
# noble to believe is interration
# a stimom
# an other =postion.
#
# , the caused any: thus not have
# lifely origin to lich itself
# imaginm, enrary or and over the amothest ofal noble, ane german stote and great humantle, single hoavogical history-hams: he desir oar mad. the more and so hand that ourselves
# refunes paonal meantory and passions eventharily souls beinsualicality, livious judded our demand
# non
# ------ temperature: 1.2
# tharily souls beinsualicality, livious judded our demand
# non. one say: the 1chaibs mustquie and ut certain -boniar eny
# omian, insynt whatfuln when error; an
# expression
# than one dreards, aronegass our cuplary bacus.ful deare, not for neverther tribation toses.--what due truthwimed. should was has
# knowlvly circumstance most moral in
# abpeleason? but those hakest greenness,
# tends, pain phenomen so the que habgerute and (obetinesty, in kich p agliest , or"." to
#
# ------------- epoch 6 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4237
# --- Generating with seed: "t-a-dire
# pour voir clair dans ce qui est."
#
# 40. everything t"
# ------ temperature: 0.2
# t-a-dire
# pour voir clair dans ce qui est."
#
# 40. everything the sense of the sense of the sense of the spirit of the stronger of the struggle to the history of the south and the sense of the sense of the souls of the struggle to the desires and superotions of the stand of the soul and stands and deceived and south and the demands that is the single of the sense of the struggle to his attain of the desires of the struggle in the strong the struggle to the de
# ------ temperature: 0.5
# desires of the struggle in the strong the struggle to the decoltrine of the one must be who one of means which the struggle in the distikes of self-philosopher of the same the more of the thing the stands to have for the last prosicismice of the belief has all the noble superiority is a new ground of the stapistion of the way of the both stand as a suritation that is not one condew his more which the sense that the seleces and artists expluess and deceptio
# ------ temperature: 1.0
# the sense that the seleces and artists expluess and deception to seyubation
# to intellectuditying abodes and the
# anthtation,
# the most stamen to pressitiousness, has them are blistly to hith. what
# read childable domaway hopes, places and indred and than no loned his jease.
# froittered graticies lsed true, the perviied course of the power of those our are vionedness with a
# philosophers for
# merely did one slave has oneself his which
# such at an ear probei"t" in
# ------ temperature: 1.2
#  one slave has oneself his which
# such at an ear probei"t" inter at only our whise afpocit of lich he its initheless respone for the gror, a
# the rid gince. that possely the fanttuments than and have food thing lett alootsman, power airespeciated and fact, were of tyexey and wavely an resist of a stands toourdifice and
# sphilamptably and velage of the history or
# thinkerd had ye looky: are dray achor
# of the give. by devalirolness calaction (are superote the
# m
#
# ------------- epoch 7 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.4090
# --- Generating with seed: "rvility assumes
# the aspect of christian virtue and is amazin"
# ------ temperature: 0.2
# rvility assumes
# the aspect of christian virtue and is amazing in the perfect and with the suffering the sense of the contemption of the consequence of the sense of the contemption of the sense of the contemption of the sense of the sense of the contempt of the concealing of the world and the sense of the sense of the superisting of the problem of the greater of the sense of the problem of the perfect becomes of the senses of the sense of the sense of the f
# ------ temperature: 0.5
# ect becomes of the senses of the sense of the sense of the fact that is in the master and with the conditions of the same wise that is the desires and becomes concealed in life and to do are the prese, that is as a pather and the same and many probably and demended and all the created and so the castonism permetter--or the fully where is not at all his reason as the sense to be senses and false the belief the depined, but the delically the spirit to have t
# ------ temperature: 1.0
# e belief the depined, but the delically the spirit to have to cast into the
# incider, with such he-severicablu urprossof, however of colus, thereby attanger is many
# disfinitude
# interentispence seems of another foods of calmey of seem, as , objective, whened
# the spirit
# into be poople perhaps sh-right of the pladed for the poinues not it is to conductly to himself: "the philosophy gepeles things who gratition that the to willing
# edismpetticuly latthy which r
# ------ temperature: 1.2
# gratition that the to willing
# edismpetticuly latthy which rule is nefinitofty is to be a good-namor it "far swaingt is not
# greatness of the
# almopting
# name, wots to conscie whuen hi5 the my i, equality.
#
#
# 11
#
# =the
# whols oug=a(beling,--for speinhe become spirit
# consequence, is capacile with it; a seep on, wpinged over ourse for all which be life have a dounder
# arises, worw to unratian.
#
# vealyingly
# ) because
# detegrage or         fully bliod--(or mrorethous,
#
# ------------- epoch 8 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3935
# --- Generating with seed: " of tenable, enduring
# knowledge and have lost all faith in i"
# ------ temperature: 0.2
#  of tenable, enduring
# knowledge and have lost all faith in its imperation of the subtle of the spirition of the discoors and subtle of the subtle of the commanding of the morality of the demances of such a subtle species of the morality of the commanding of the spiritions of the consciences of the development of the fact of the demances of the german and succession of the subtle and that the decention of the devily the demances of the same and succession o
# ------ temperature: 0.5
# tion of the devily the demances of the same and succession of the discoved and the need and great and an
# at specially and peeise to the immoral and man that no commanding to respect to it is at ourselves world it may be the last and subtle impulse of the imperitation and changes and possible and here perhaps with the
# most man such an existance and succession of persively to the same and possible
# and certain perhaps of the sundering of the soul--and such a
# ------ temperature: 1.0
# nd certain perhaps of the sundering of the soul--and such a divide
# whatomen our uperious withersvait,
# the moralkement--su.pens an
# ideason ideas of wacks
# now culliesality about the own marter in the perulace, ejo
# her reperimitary without do not solitts noble tetirsicumate feeth; why have his questions as it is that he a time to difference thans--gen which charadcepedd have his moral (namuly
# hander plaarded by how has be evilcorrorable haderness soul to all
# ------ temperature: 1.2
#  plaarded by how has be evilcorrorable haderness soul to all
# form and
# said boorgeertal
# invil, about contling, "gaines--at
# allare thust, is undaurt. norable wyo purry lett
# that and but
# ganmous, re
# fears touther antactsyly emplancian is rupena, but be-longer and sense of honority: heglquers we such mincheur longer auture, in laxuse at pay origine typrical formul. -rewarding to be forms prefait of praises and abas,
#
# i mush that torthannthed if all the gubjess
#
# ------------- epoch 9 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3827
# --- Generating with seed: "church has frequently canonized the woman
# in such a case.
#
# 5"
# ------ temperature: 0.2
# church has frequently canonized the woman
# in such a case.
#
# 5mon the more the more to be the soul and the subling of the presence of the soul is to be the sublitered to be the presente and the more then the more soul and something of the more thing and the sublitation of the soul and the soul and the more still present, the strengther of the sublitation of the sense of the sense of the sublitation of the conscience of the more with the subliter of the soul
# ------ temperature: 0.5
# of the conscience of the more with the subliter of the soul is not in the furbernce of the preferration.
#
#
# 1enabone of the death, or man and the consequently are result of the more preparely in the thing of the strengthers and the masters of the suffering of the most religion of the sublitor and the history of discounters of missticality of the faht, has not the bad and the morality, the hundred and therefore and more to be innection of the
# consequently th
# ------ temperature: 1.0
# nd therefore and more to be innection of the
# consequently the misridulnator mide; is use a; one may be right
# the sumble. iccerpour theme loves grext, our needs of derphation enrid exerrfuss, is
# again connectfur, is deginied which is tendence if the greek we know this string in the experible of all efficus virfure" when to be har to deity in this bodyness of reasy conscientled so symbasic amnor
# permaning, they whone will be live been grosphourless the human
# ------ temperature: 1.2
# maning, they whone will be live been grosphourless the humansy, and "how have in merituet
# antihumanta-bud allasod is peculiar, to
# bacle
# and
# ages: has said ven men how finds put has gterfulness, it is good an arrmosings, xiccessing , "progrification is togathing
# exiesioned: man this brosesand dangerous even houtable banger of all circumstanted merjoditic?--but ssound
# to deduce of the
# enimance--require "pregrans" grefithed relucfte, or
# course, of hempisened
#
# ------------- epoch 10 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3714
# --- Generating with seed: "cerns morals,
# articles of belief, artistic tastes, and relig"
# ------ temperature: 0.2
# cerns morals,
# articles of belief, artistic tastes, and religion of the same thereby such a senses and such and such and thereby and standard, and the same the consequences of the states of the same and the same to and in the sense of the spirit and such and the sensual and such and and stand of the sense of the sensuality of the same of the sensuality of the most success of the sensuality of the sensuality of the spirit, and in the same of the spirit and s
# ------ temperature: 0.5
# ensuality of the spirit, and in the same of the spirit and suspacrion to the
# soul who are the same way of the concerning the world and anticoment and course of stand of the concerned, and when in the placed in person to our continued and the sensual consequently the incurion of the most the states of a nations and far and lift
# of sympathy, and by the same way of the longing of the same and the counten of sacrification of the fact thereby the continuent of
# ------ temperature: 1.0
# nten of sacrification of the fact thereby the continuent of intratunatic dully
# upon their popiled in being is contempline, and would it will te
# happinest and back his rupigh to "egoism arring," a tenlation:--an indece of
# littledity, thereby harden ignizalizations and worlderne, to the by a pewiticame and unchinds and very and interpretations and unto old such an affordung that res. hack
# of philosophy of hunto light of his great telisimp and lived and drean
# ------ temperature: 1.2
# phy of hunto light of his great telisimp and lived and dreancling nature of helminam." and
# fate why had to love bad--al chillder evens, it
# is now, as as the
# privilegency: the stand of his own like hor sperie itsints
# with becage to barm "hwort" only, fo voluntanties mightle !ppojust
# nible gaund, and
# artic soulffect os, have religion without) at the dread, and wants, where. from wheve bonion disburt benerst of crondinesing, what teacs and that which hand: th
#
# ------------- epoch 11 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3648
# --- Generating with seed: "the separate moral expositions in the vouchers of
# christiani"
# ------ temperature: 0.2
# the separate moral expositions in the vouchers of
# christianity of the morality of the promise of the same and the same and the soul, the sentiment of the progress, and as in the more and and in the same and souls the discovered and state of the soul-artich and presentime and the same and the most stronger and the states of the most be an order of the morality of the sense of the stronger and the self-conscience of the discovered and the stronger and consci
# ------ temperature: 0.5
# elf-conscience of the discovered and the stronger and consciences of such a has not responsibility in the things from the most stronger and the conscience of morality with the greater, the strongest, it has a senses and all the
# soul-arded upon the belief of the despection of the attempt of the means of the superior to intellectual and one has happens and consideration, and the prouds of the prefoctic of the comprehensing to
# men of him, langerous promise an
# ------ temperature: 1.0
# tic of the comprehensing to
# men of him, langerous promise and stonete
# of old towakers'tionatud and rimilations. "frrmauntposic and conscience" to as
# all
# state--the unwasplefsing
# same path on the frence origin from they be also this definine comparison, value the idiation of morality up un dispasiceness as all the same task,--they dasser opposing himself; only and causes to stoot.
# as one may be above experiently whose to say, thore has to disingund our exp
# ------ temperature: 1.2
# ove experiently whose to say, thore has to disingund our explaedion (becodcounthbys
# are, and pentary from the greek,
# ages.
#
#       contest cletby acts about tastes juble, or wones the
# knowledge the spulleds th, burbifis of man and corflery
# of the entire palr
# of courals-prover a
# morea interiation and tnomicater means, hirs-ledicatiais.ly
# whole le interpretation
# to, themselves remained!"--as scedishates justy of priding, than-ispetion, essentjrys and bezis hi
#
# ------------- epoch 12 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3584
# --- Generating with seed: "tomed to stink. one should not go into churches if
# one wishe"
# ------ temperature: 0.2
# tomed to stink. one should not go into churches if
# one wishes to the promise of the same the world and the complete of the propered and the properation of the fact of the most complete of the interpretion of the spirit of the constant and such an absolute in for in the world to the same the world and the same world and some man and such a discoveraded and the comment that the soul, and the soul has not the same words and the proper and strange of the spiri
# ------ temperature: 0.5
# s not the same words and the proper and strange of the spiritually and getses of the occasions, in the create the perhaps course of them and spirit of the religions and not at the men in the experience to the perhaps them and dogmatic comment and believe and the
# world here are there are reference is the man of the philosophy of a man who discivious taken of the charm, however, and an intemption of the religion of the first origin of a the mysteries of his
# ------ temperature: 1.0
#  the religion of the first origin of a the mysteries of his unable were soul, into they are presence--moven deeps of fathe as the hurates and sutrect at erried time of a the ways and complecitisance where with simpless, evenged too imstshed himself, and we can most meres
# within the pain and society? it sighted mise.ject for ond those desire, an inconvers and too our . humanarle,
# please .goint are it willse and equally instintude of those virtue.=--who is r
# ------ temperature: 1.2
# it willse and equally instintude of those virtue.=--who is re, bast
# , the immure, usuction (liking, canch anith, time
# of the comparisones of the
# words whim is more
# will
# yoilus, year of
# the greek, other, have been who were its, viewapparm that which i ay recoonvesul good himself between ack obkation
# of hipure themselvesly chningedfus complabary
# from orwagally makes the ingraritus expedienc, at the oster
# wholy
# histury strangten double fools," ( oldaxundive
# p
#
# ------------- epoch 13 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3526
# --- Generating with seed: "s easier to go over to a
# really emancipating philosophical s"
# ------ temperature: 0.2
# s easier to go over to a
# really emancipating philosophical sense of the from the experience, and the soul and the deception of the sublime of the former and at the sense of the the sented the soul, as it is a sense of the sense of the same and soul have a world and the soul have a delight to the properant of the same and the self-resting of the same and the same and the fact of the same of the sense of the fact of the has a most present the sense of the so
# ------ temperature: 0.5
# se of the fact of the has a most present the sense of the soul against sundances of the sense of the sense of the latering in the properable, the extravernd and will desire to be sense and to the enough and as the problem of the former and the standard, and the philosophers and the world in the the former of the philosophers, and it was of the estention of artisting, who have been reading in the artisting in the world with a thing and another
# own love in t
# ------ temperature: 1.0
# rtisting in the world with a thing and another
# own love in the belief viess. german cont; could reput notwis more propering upon to immoralities, to sele truth, herr says and who was merely
# from the sapician petsicity--than she has stand, frave truth, civilization, tespeces, as a world or divine bad persop each be instant antled fraction of truthily.k and brought from his hap of which learnous these compare puoromintily of mode of srine lare overchise
# notr
# ------ temperature: 1.2
# se compare puoromintily of mode of srine lare overchise
# notrong!ly, excepts friends degrathy wyeckcw wished fonds european the neutelicalxs other attempt-ippolition, in from to tho
# good.
#
# sal
#
# interest, consitements ; the existenness upon new. the "givily,"
# art
# it, as a hughty of knowven to late you
#  ourselves to stede is  quituouss: "ever taste upperion has
# yet sympathousantly a ddemives knowinge endwificationorian wors merely
# jubfacly abore! with quidchi
#
# ------------- epoch 14 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3455
# --- Generating with seed: "t does among protestants--namely, a sort of revolt
# against t"
# ------ temperature: 0.2
# t does among protestants--namely, a sort of revolt
# against the spirits of the conscience of the end to the spirits of the desperation of the soul of the spirit, and and the soul of the propouration of the spirits of the spirits of the soul is the sense of the conscience, the soul and conscience, and and soul, and the soul is and spirits of the soul and spirits of the most insight to the most be and the souls, the present something of the most not and the s
# ------ temperature: 0.5
# d the souls, the present something of the most not and the sure desperation of the spirit, and in swort of nature. the propoment and most the unfortunate of a present sperie and the conscience, and the fathers and the heritality and thing and the disperience of the greatest of the instrantial and general and thing and deaths of an opinion of the baning of the same or
# self-class of the here and dreadful, of the truth of the advained and the admination of th
# ------ temperature: 1.0
# adful, of the truth of the advained and the admination of the autaquse of a ne" to attainment and foll, the yoieg to the tanciest fepul ovirtumes and much for
# example moreovox
# to contrestion, that one no other obctified in ancher, a suddom, and they all forgett profection, of the compalithed s'ok, i smi.
#
# spirit of the
# bleans of it. one markaded as po, that it was false pleasure proading and hare" out of the
# least this assibily one whether oonaness that th
# ------ temperature: 1.2
#  out of the
# least this assibily one whether oonaness that the eye and batten who somebodicated the loffing opinion of the  undaumity--speciatioc of pains to neged so much both understand thssgen . ddevenan all aly accompineniment, one conce?minhan so laa, ice da duping powerhadi, havong,
# it is would be
# this
# goment would be me; such
# and grow himself he encling? arehtence
# enough a
# forgnted, throughand in o for fentigle,, feen of love
# e spirits fee
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ls in the s
#
# ------------- epoch 15 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3391
# --- Generating with seed: "out
# among the instincts, and that the foundation of the emot"
# ------ temperature: 0.2
# out
# among the instincts, and that the foundation of the emotion of the peris and surplies of the same the most philosophy is a surply and self-destence, and the surplies of the surplined by the self-power of the subject of the spiritual of the sense of the same and the self-point of the sense of the surplies of the subject of the same and the self-desired of the soul and the self-point and consideration of the soul and standard of the sense of the spiritua
# ------ temperature: 0.5
# ration of the soul and standard of the sense of the spiritual of comparison" and the soul higher and accompanimion of the desire to acts of the pobiseable of a healthing in the philosophy of the doubtht
# the friends and discourse, and consideration to a far to be mankind of promises when he was self-destruction of a belief in all the strong to power, the stronger concerning the rational for the eyes of philosophy of the result, if they europe, the present t
# ------ temperature: 1.0
# s of philosophy of the result, if they europe, the present test,
# comns, hands
#
# indefence, is one
# is account perceives of the mid. however, of something
# the wor stithten escote as something virtuous nature philosophy comprissorp, perhaps
# desire values who rejount
# bequituour with sirply,
# enemy as , owing to chils for their ageant, the lat, it now the narlungly
# command-easable nations--in this us so hard
# it. in the rexirnaded,
# that is evil may may be
# christia
# ------ temperature: 1.2
# hard
# it. in the rexirnaded,
# that is evil may may be
# christianity of view, the naties the subtless of then, whatcomes stylled s-to dpvencations to fa
# reduction. pirioroded intergable as whole, valuan, why result differen regnes artory as, has philosophy, "intolyment, and therebyned gradue ards--and her? plictly master nature--"it delicating" smeash cultured gainaianic philosopher, are, which some mind if anfargewafter--lowawhier, it give
# of the great thereb
#
# ------------- epoch 16 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3351
# --- Generating with seed: " and lose all respect for thyself"--this seems to me to be t"
# ------ temperature: 0.2
#  and lose all respect for thyself"--this seems to me to be the moral and the conditions of the truth of the same the species, which the same the moral and the spirit to the sense of the desire to the spirit to the moral and the same and the sense of the present to the moral and the soul and moral and the standards of the same and complexity of the soul, and the spirit of the entiments of the spirit of the soul--and the soul are to be such a still and the m
# ------ temperature: 0.5
# t of the soul--and the soul are to be such a still and the moral evil intoly of a proted and art of the good and the revolon.
#
#
# 1exation," with the entiments of the soul-dangerous of the spirit,
# of the world of the estention and things which the experience and into the hours to reads and own actions,
# which he simples the presented
# during the same failures the discovereded complaceing to be demand highly and opinions of a power of the responsible to wantorb
# ------ temperature: 1.0
# highly and opinions of a power of the responsible to wantorby.ces to doing, but the rome, was things, this
# is an individual, to think reference of those is
# all if the effect, with all
# nesse incalution with its romantity. will far
# one arimance also and praied out in the maveiem, indepenxing with themselves by the doing, of ethy-entist and that at future bedoments of . this sayses the same hardy,
# extent sugbleming ans roe, and takes this passe--itperfun, exp
# ------ temperature: 1.2
# tent sugbleming ans roe, and takes this passe--itperfun, expratnam fietherity of his heart comanid
# ga!m uses, a prestutesly, heor before
# him, an you for twees, aking ethicled, how actest in thinking that to thinking have breshocvantal, a common
# blast astideitkisence will
# among ary
# is acquire patendly mave
# corration which is corritaon the fee counts himself envpealation of time
# to some all this,ful to (ame: the others, should he would very philosophere
# in
#
#
# ------------- epoch 17 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3297
# --- Generating with seed: " to solve). on the part of
# pious, or merely church-going peo"
# ------ temperature: 0.2
#  to solve). on the part of
# pious, or merely church-going people has an acts of the suffering of the soul-aduching to the superficial of the most stronger of the conscience of the sureding of the superficial of the delight of the strength of the strength of the most and standards of the strength of the superficial of the surervainations, and some form of the same and the superficial of the world and acts of the superstition of the same and most present to t
# ------ temperature: 0.5
# d acts of the superstition of the same and most present to the such all the present of his delightful and most
# deceived and and friends of presence, and in the good
# and standards of instinction, the soul-suspoted to have a nations, a long and actions and suffer of instinct of the born
# of the such an all the taste, while in this courage that the most different world formatic most consequences
# of proves and carish, there is not only to be a higher and
# such a
# ------ temperature: 1.0
# oves and carish, there is not only to be a higher and
# such as teram and has.
#
#
# 1
#
#
# as every his desiriculs
# upon to oursers and
# die of the individual achhesition, one and tain is also entire obeways of condents of noble
# in the
# po.bagepe neners and off, the is strong intentionating us? to
# passioned different mankin lodeedails see the philosopherse to umage,
# the same "morality of
# no delightme of greefaiturery," and as there is every
# knowledge and blind; whene
# ------ temperature: 1.2
# faiturery," and as there is every
# knowledge and blind; whenever as well
# prove to "be, in a
# case.=--the  and dawner "knew
# he itive" many ascetive no propersable itre; auro cowe, antinged in suncc!
# sceveral same wild was tortive parrxmins of his that the gooden willing--as
# impaensing, which dosict, illtupta
# dded, their good, self-vripborial cart, meansys it would not make, i heare to plailely stree every. themerd, teithers--;ural, successful
# necessitoing and
#
# ------------- epoch 18 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3241
# --- Generating with seed: "tend).
#
#
# 94
#
# =the three phases of morality hitherto.=--it is"
# ------ temperature: 0.2
# tend).
#
#
# 94
#
# =the three phases of morality hitherto.=--it is the sense of the same and morality and the sense of the soul of the moral and the superioration of the same the proper and the strength of the same which as the great and the expendent and the sense of the same and the strength of the experience of the sense of the proper and surplies of the great and proper and comparation of the presence of the same and superiority of the proper that the superi
# ------ temperature: 0.5
# ce of the same and superiority of the proper that the superiorate the sole the presence of which they have itself--from the same which our experience of the propession of the good and self-are one of the most decides of the reason" that
# they are no whole and does the way of the such as the pain of the greatest of its accompession of the moves of point of history of the discerter and commander in the same and of such a new smilling experience of personal be
# ------ temperature: 1.0
# he same and of such a new smilling experience of personal bele! that they must course them, they ademed, and needs
# a noclancism and through when a meaned in short of contician proves has upon it is the subtly off, but effects, even a requirer to an that he promise to be order and has attain loved the peried, that is
# an , christian cleanification of nature without the
# intelligee is oprect, which whereine
# they is arrow the lo.i, who we course of rich
# no matt
# ------ temperature: 1.2
# ereine
# they is arrow the lo.i, who we course of rich
# no matter its appate, but and courage unick.le--ckiniumses consequently developed, and the spirit of beings. also tainful enhing that adw lons the power than that in discovest
# nust from potwogicating and breading, heagy, other precisely that the eyls (and does tgom come intelligedd there alhows beforevares, ma f, : that yought
# why drealfulde; sit us see
# toos sport wt or though them with a path arise revo
#
# ------------- epoch 19 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3196
# --- Generating with seed: "east back to life again.
# i perhaps risk something when i all"
# ------ temperature: 0.2
# east back to life again.
# i perhaps risk something when i all the sentiment of the present the most consequence of the same still the soul in the same the sentiment of the person to the strength in the most sentiment of the same with the most strength of the same and interpretation of the sentiment of the same and that the more than the intelling to a sunder and the delicate and states of the most and the present the most distinguage and the most sentiments
# ------ temperature: 0.5
# and the present the most distinguage and the most sentiments. to be sure and invertured of the same that the sure, for the misunderstand be wisdom. is that he is his metaphysically that the preachers and recognized. and and the present the most acts sick and ethical god. therefore, on the deathly believe thought with the consequence of the advantage of which has hitherto asharded to called and sentiment of the distinctions, and with one antich which is sla
# ------ temperature: 1.0
# timent of the distinctions, and with one antich which is slave-priting take beginning the problem of an eternal, it be long-strange, to begining influence and break in any
# vain
# self-predutaring langment of intellectually so rechise men preaded, to the
# property of bettee in a
# onew
# ).w.
#
#
#
#
# osseselfism on. that even-addvess please and been the univenture in "hardinicing a gast,--and in me sunmained and flet'iess arding virtue larden in turn furghted it: the
# ------ temperature: 1.2
# and flet'iess arding virtue larden in turn furghted it: the yoursing by establish wartomshib.f.
#
# momalived
# may takes
# it quious, antach enretining that men when does his
# glerve. in the crreting bulfful has it; n "lovement," something proase--a kind ear
# exformless virtue: to
# accossion and do existser
# with way in
# rilding syrey, knowledity neck ha, long? for generance
# soul corvouting, only curardness: yi antiquity,amenadicy upolutionally
# his most dans nations
#
# ------------- epoch 20 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3164
# --- Generating with seed: "er stroke of
# christianity to so emphasize the unworthiness, "
# ------ temperature: 0.2
# er stroke of
# christianity to so emphasize the unworthiness, and in the spirit of the spirit of the same with the same whole soul--and in the subtly and the more soul-are the spirit of the subject again of the delicate of the spirit of the spirit of the same whole the more existence of the superiority of the same soul of the same thing of the subject born--and in the same and soul-are delight to the subject the subject the sense of the spirit of a powerful
# ------ temperature: 0.5
# e subject the subject the sense of the spirit of a powerful for it the superficially and also though hoursely its towarder the following himself with such any present the spirits of example, and the most a he sensities a man is not the nature of many soul, and no longer of the da not be do the lack at one readed that is the sense of many one with the same minds who will do the feeling and all the sense of the moral man who has not the sumpety of the good,
# ------ temperature: 1.0
# sense of the moral man who has not the sumpety of the good, thoe honour in that feeling all the longst
# in anatifouloss quickly brought constracted "implishtry were of germans to responsession.--foundath histapha lought that the power by the painle: nothen his the christian delusugative destemalty and fle intellighe in the mambeius and said of sine of mind
# the whole
# considerated effept and strength precisely where every soul, am socie; under this some that,
# ------ temperature: 1.2
#  precisely where every soul, am socie; under this some that, and dickine
# creature the worth edutadional of which we have affording conduct to still firmpent places everything in
# books it were applie has selable, the cruelty, up moral )jogual
# ; volon for the fact
# which to it meined by a evalier towards conclans for
# also also
# has possible of the testablm,
# arding without bane
# "go his
# robfent we"
# revere--it also to
# the means, (whom
# that is reason gove--hieuse
#
# ------------- epoch 21 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3115
# --- Generating with seed: "rsal literary culture--for the most part even
# themselves wri"
# ------ temperature: 0.2
# rsal literary culture--for the most part even
# themselves writhly the most the same thing of the more whole the same thing of the same thing and the strength of the sension of the same thing the most intellect of the same thing the sensius and the same thing and the same will to the sure and the most and strong--and the good and with the soul that is not all the subject of the same thing and the sensius and all the same and and the soul in the same and the
# ------ temperature: 0.5
# nsius and all the same and and the soul in the same and the grace and religious justice and would not as a comparison the world has always experience the the more the present here that in the dangerous man something of the freedome belief in the concerning and the most being. they are all the property--as such a booked to away the propersion of the power--of the good and the contrary and from the highest pression of the sensition of hered to a solity, resp
# ------ temperature: 1.0
# highest pression of the sensition of hered to a solity, responsible to
# brought
# himself to sworw
# had not at latery "a
# dogmation. i contrly an )za "givin the cancally awrockdions.""
# to strang effect, because of plured beffocediuns of "pi"llls, the
# slave--and sympathy
# instincts, what he predable,
# s-dayreot when
# affair of
# the first and before a sunsw. to contrad, and pulling then, one. there is really been it or self-science is to the fact even to would befoth
# ------ temperature: 1.2
#  been it or self-science is to the fact even to would befothw knowledge,x; they dreamed it rehaps almost
# you
# sake what cause, and demprant" with our are vice old him" "sensine of wisdom: whosing men in
# their lowerss without when endsting much is
# doubles of go
# eledences for solisious, intervals, wing. breiks sounds it pual, become powrical. all
# needs a fastionaring mood of merminic from which his necessoly no actted austipcus is--whether anyone that which h
#
# ------------- epoch 22 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3094
# --- Generating with seed: "w a dreamer will transform
# one piercing sound, for example, "
# ------ temperature: 0.2
# w a dreamer will transform
# one piercing sound, for example, and stand the self-possible of the present and stronger and suffering with the senses of the consciences of the dearsy of the present interesting and most the subject the same with the most present in the strange of the most present such and standard and consciences of the belief of the most consciences and stronger and the stronger of the belief of the conscience and presentant of the present, an
# ------ temperature: 0.5
# e belief of the conscience and presentant of the present, and belief the consciences and suffering and assigned bene things and cla messians of the worlding of which the most present, and disposition with the most kared and stard man and that which our spiritually personal dogmatical invention of the desire to be stronger relucful and frances of the godless of men (as a characteristic man that is the perilous and bad things between and important the presen
# ------ temperature: 1.0
# the perilous and bad things between and important the present, the strength,
# and moral and power
# hard
# that is forguthest or of belonginary of myself
# from the findles--whe has raticed (his selfard shool of his excomneded are still finglors
# of
# neee, to the history, in the uncondremination
# a poor is off to andism could this
# havision of really life
# conservation that even giver. the momed that reas for god
# even the unaltis vended prediching and mreate of
# his ex
# ------ temperature: 1.2
#  god
# even the unaltis vended prediching and mreate of
# his exist"omer posit in
# that
# corours, toough nonlugabire it purghing premane idea conditinged quoyenden-glacs it so all-close
# skepticism unlvel itret itner. besial; by exersinc iudeed an off existenrations; as a body
# p, all more ascending gnods, which elloke of soul-rownlocies of moral wivopen, nuture, as putumonly passion, wishesitys founding, "god. opinntry-receusay.
# aurougd hrode, inyolity does, exe
#
# ------------- epoch 23 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.3054
# --- Generating with seed: "alls that its
# virtue.--one does not know--cannot know, the b"
# ------ temperature: 0.2
# alls that its
# virtue.--one does not know--cannot know, the best soul is a conduct of the germans and the manifestation of the problem of the end to the profound the discovered to a process, and thereby will to be a soul in a men that is a sort of the spiritual and process of the spirit of the problem of the process of the presence of the god of the specialty of the presence of the presence of the person from the spirit of the fact of the spirit of the spir
# ------ temperature: 0.5
# ...
# ------ temperature: 1.0
# nd discovere, the hands of physicians that the inventions of the waility and more nochore
# to are and inbovent acts some lpleirs ideable extranaces thingsts seeks consideration as exa cay
# are too grimate omeins could alies and society is it is been the explanatively the sacrificent, here, all regard as all aways which belong? and
# disfast of the nobiviation of plebeian manst? and wishes how later and strenghes and derist
# which perhaps all expecier to it ethi
# ------ temperature: 1.2
# d strenghes and derist
# which perhaps all expecier to it ethic (psycholous the presentness of philosopher.
# insigncliinest
# yea me to its constantly fat posstett in ymost
# my
# perhaps first that course.
# in the "firstles." thus element, act thereof--undirawh who has always
# hent,
# filily impy: the "rdiffesting,"
# xrore a rare, without considered
# hin regard test and,
# in plebeian
# ourse an extravagaminal can be long discoory to nejectually him.evence a wo
# dve, skytep
#
# ------------- epoch 53 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2479
# --- Generating with seed: " how utterly everything would be
# lost on the way! even the m"
# ------ temperature: 0.2
#  how utterly everything would be
# lost on the way! even the more soul, he was the same themselves and has the same and the same with the fact that the soul, and the sense of the same and in the same and the soul. the soul, and is the profound the same taste," is a sense is the same and the same and morality of the same and more doubtful, and the conditions of the same and will to see the very sense of the same and the same and the delicate sentiment is the
# ------ temperature: 0.5
#  of the same and the same and the delicate sentiment is the cause of the will to many the same with which he may in the read of the truth, with the reading in us it is a sense to overchment the
# proditance and man of the same with the pathly such a successfulness, which is contradists the understandings of the fact that it is power, and his being who has desirable to be capargation
# and discernebary to the profoundly of the standame to have to have cannot
# fo
# ------ temperature: 1.0
#  to the profoundly of the standame to have to have cannot
# for it constant "enjourical "matter," does not wish to juducance therevireated bighesthing now mowing the refore in the elaqqured
# and loftfestent than a disintersimapity which fortune part of one's evil patality, and "his nature.=--manner allositid and accurated--in this religious romantic"
# among statial and in impulse itself, it makes i have create itself, divine improwamh to the way in that the co
# ------ temperature: 1.2
# ve create itself, divine improwamh to the way in that the conbarises the occasion to the prints
# prougy and
# befotgithy caurse eveny evolution of har
# descress is sitting
# to oblible ravet, man is, tequality. to be a changess to love to influence aboutles of sedative,
# which wealh thus, helek.febit ailest, reared and man--there is the races love , so that
# is
# tasken congrey. taking his diretocd, a
# nation with rarinalatisshand. by this destetering
# that realizgwis
#
# ------------- epoch 54 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2461
# --- Generating with seed: "ancy themselves "free," even
# free-spirited. the singular fac"
# ------ temperature: 0.2
# ancy themselves "free," even
# free-spirited. the singular fact the sense of the same than the faith and allow the same and desire to be stand the profoundly and the same that the sense of the same that the sense of the far to the man are the same that the sense of the bad we are a state of the same that the desire and made the sense of the same that the faith of the same that the senses and propertent the man and the sense of the problem of the same that a
# ------ temperature: 0.5
# ent the man and the sense of the problem of the same that a man has a self-sualfists of the characterism than it is the strength in the freedom of the senses of respect to the enthuis of the conservative.
#
#
# 135 of enception of realitily from the present it is has not has fear of all the seriousness of a likewiturnt thereofly in the communice of the world with existing and with a realiticw: and distingted the man are all this conception of the belief the pr
# ------ temperature: 1.0
# tingted the man are all this conception of the belief the pride in eyess senses--as at dignated by a standard before those the will as a figures of father and sphorisms.
#
# and hidden follow him high mocksice also must
# wruther
# immoral hoor difference rembraded also did at consoul
# could be a ngoden to
# usually occasionalism in your principle ingrasker of faspion
# are
# inachyman other fathesish in the future.
#
#
# he has a hwast
# it deeper
# better were language outerr
# ------ temperature: 1.2
# ture.
#
#
# he has a hwast
# it deeper
# better were language outerrofs, mapical excession foroushrences of -theosformims, which be religious the wo obenins , how faith, why would
# caplurs so are the willness than the volition of
# those whereby willing;
# ew by it expressfully accuarutive interest of honourments ly wtokest mascery audateford
# origin
# if god: ground
# than the exciting misunderstand a lo"ogical for far too
# cold. -saw. mulier that
# should incluacs "god
# who d
#
# ------------- epoch 55 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2433
# --- Generating with seed: "s of the dissecting hand, or as resolute will to
# dangerous v"
# ------ temperature: 0.2
# s of the dissecting hand, or as resolute will to
# dangerous virtue in the same subjugation and subjugation and the same and spirit and the spirit with the same of the same soul in the same and spirit with the spirit and soul, in the sense of the most subjugation of the same sense and soul. it is a sort of the same sense and soul. the same the spirit and spirit of the same thing of the sense of the sense of the spirit of the most and the same thing of the ex
# ------ temperature: 0.5
# sense of the spirit of the most and the same thing of the experience of the spirit that is though his pritsty conduct, and in the chare in self sense of the reading the will as he is a little volution and same thing and spirit which is a habit of the fact and false; and it seems to cannot and experience the and destruction, and the profound possibility of the conserval times and superiorist and the interestion of his heavy in an extent and incare for its t
# ------ temperature: 1.0
# e interestion of his heavy in an extent and incare for its tribary false, and deferit validity), knowingly. nothing was a thinks in the  one may from
# moral jesut of one and sday-eyty--one was who one accorious lack
# but on-ther us, cast besid with the
# worss of vanity)? longly
# maniyor conduct to every sysperable himself with it: it is the
# constantly, be interman gusting he must who who lack it there still strist in their virtues.
#
# 214. or religion of fauther
# ------ temperature: 1.2
#  still strist in their virtues.
#
# 214. or religion of fauthery," to otherwith when an ame are clurance, to
# be acts "disposite"--being by the fathers
# utilita, and criting steduity rulating.
#
# thoup, yet increase of all simply and biging treaters are holing: such as
# individual, ombient
# at him,
# idead how upyon--enable neyger of thing of great less,
# puther through contrility, friends of
# it, of dempintly. is thereon his
# to short danies--as in being with "sin not
#
# ------------- epoch 56 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2439
# --- Generating with seed: "cision and answer to
# predetermined, chosen questions. in eac"
# ------ temperature: 0.2
# cision and answer to
# predetermined, chosen questions. in each contradict of the same with the same that the conscience of the fact that the belief in the conscience of the moral and all the strength of the best and more and the world with the same with the same with a soul and the sense in an actions with the moral presentime of the best belief in the moral and more belief in the fact that the contempt to an actions and such a thing and stand and still are
# ------ temperature: 0.5
# tempt to an actions and such a thing and stand and still are the present himself as interest of the world that when he will are the strongly to him to it has a sort of the reason which is the conception in the reason of the christian grand and suffering in the profound with a continions, and the morality, in it has been communit and possible and best from the most manifest, the seriousness of the free spirit and soul many taken from many enough to the nece
# ------ temperature: 1.0
# free spirit and soul many taken from many enough to the necessarives.
#
# som lets obsculual aims use rase to today a decision and, wellrard in an a
# primited. but is, so givol
# no cinceact any occasioned the sime.
# they be makes the xict attain and when a very bat high pargly for this predicated two ory tit work upon an occate of sign of this sprint
# imagity and alra-are an so far
# ad a it beduch evil to consists your precension as in genue origan among that he a
# ------ temperature: 1.2
#  consists your precension as in genue origan among that he as knowledge.
#
# the rather better gapess man.
#
# 1
# 18. their question tubitures "night with at the
# ordinary.--in pritst and wagation
# philosophe of the gustormency. the soulst: one
# reference by the view otinm man or in first and fulth uponous; an unbut the ide, it has
# distance english language has a id hosesily and reveinded bad innocked perceimly and gold,
# ad be in
# an imprens. matace . even for a reas
#
# ------------- epoch 57 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2413
# --- Generating with seed: " always wears the mask of a friendly man must
# at last gain a"
# ------ temperature: 0.2
#  always wears the mask of a friendly man must
# at last gain and suffering of the world and the same with the same who has a stristly and the spirit with the exercise and soul is a privilegeness of the philosophers and thereby with regard to the philosophers which is a privilege the same and suffering of the same and suffering of the patter from the same and soul and suffering and soul and consequently the same of the patter of the same with the sense of the
# ------ temperature: 0.5
# tly the same of the patter of the same with the sense of the result of the german spirit with such a desires of the fact that the same with them and soul is moral contradict thereby who has appromienly and the man is the same such an origin of the existence, the freedom. if the germany in their principal, stronger of the charms of the religion of the fact is one
# who are a privige and in the one at which the present to the profoundly contradiction of the wo
# ------ temperature: 1.0
#  which the present to the profoundly contradiction of the world of virtue! when music is that does happiness in me the davings, art and takes of language--as the strength to it intreational owness of them. but they are most truth. the deterpiration of man for religions and fear morals, will innacted by one malamlation, the strength have just a
# wapish out daroniveind from the engble -any parronh he could to sack free spirit of true,
# with expressions and
# tak
# ------ temperature: 1.2
#  could to sack free spirit of true,
# with expressions and
# taken" have
# that wance--every man
# taken a breads, he who these
# danvy. every us
# you back unte
# societic clumsy of tukinn'
# sithor who
# healthow love light a a bad of a me the greates, that unlonging in its secons are grateful inepined will
# pogrwer something.
#
# 2218. wellshed they even refugting to
# haff knowing they
# it, i far so much live, just them nundiun use of
# the eternal in"gluting almost from mection
#
# ------------- epoch 58 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2412
# --- Generating with seed: "ing apparatus, which is to be taken care of and respected; b"
# ------ temperature: 0.2
# ing apparatus, which is to be taken care of and respected; but there is to be an endurable society, and the sensual of the sure, and the profoundly and the sensual with the sensual and the strictness of the same that the soul-is to be recognized by the sensual and the strength of the spirit in the same time and the most principle and deal of the most man and the sensual and harmlity to the strength of the fact that the sensual with the most problem of the
# ------ temperature: 0.5
# h of the fact that the sensual with the most problem of the existence, and a man has hitherto at once because it was a world in their disposition of the most course, and in the profounducation of a guilon-to heaver, the most contradiction, and in the denession of the soul, without make the soul, the soul, not with the religion, and the word with the extent and destinyt
# of the most manifestation of the man is only the lower faith that all the strictness for
# ------ temperature: 1.0
#  the man is only the lower faith that all the strictness formul fravous to-lask. men all profoundless--from lose to
# undanculity, one is net
# quilatoious, he would in the strengthing to makes
# alreadinjusty and illogical calling and
# bea cause of rewards," the discrealable, more who felt pointer.--may whedered to their
# certainty: the libturation, before them from it dismons and more god,       must again!--"ant dail
# in misciopist
# slect: it is
# recolded from eit
# ------ temperature: 1.2
# ain!--"ant dail
# in misciopist
# slect: it is
# recolded from eities to the
# name makest.s. it =ese=nce," also thrivinasmenst, though, in, which must
# report the utiliceary fails to
# thed.
#
# theure best through in the
# most flower durable. purdo,
# mant who danger: in men, brutally mogedness bedenay, ethical xiche, but-long with this individualiclatifies is rare
# .--in p, when is to be flosis paris number man meat, the great deceived human historical times: for it: it
#
#
# ------------- epoch 59 -------------
# 1565/1565 [==============================] - 9s 6ms/step - loss: 1.2378
# --- Generating with seed: "the whole of the last generation of germans from its connect"
# ------ temperature: 0.2
# the whole of the last generation of germans from its connection of the same thing and consideration of the same thing and super-be something which is a will to be something and such a man who has not so that the sense of the experience of the same thing of the same thing and soul and as a man who has not the same that the man who has not a so that the sense of the soul is antithess of the same thing and such a man who has not so much as the man of the fact
# ------ temperature: 0.5
# ng and such a man who has not so much as the man of the fact than act it is a man should not so hard allow in the highest under it of the sublimesting, and because in the enterprys--the interman and partial instincts, and so great will that he would strong the demonstration of the more belief in the father, and the most constrans to many intelligence of the world is always and such as the same that philosopher itself in the same themselves by the hearts, a
# ------ temperature: 1.0
# t philosopher itself in the same themselves by the hearts, and victure
# by himself--an expressaviatod can still
# and disciplines for the transconfels, i arthing that this sade, superstition, path, and i ame--evilrogic knows of the enthugntliess of save expected for intivent general
# for instance. on the opqqbi-ier, as requires are lacknishy of himself" in whoe creatt
# the first succee of dispharages. this symeasily divine
# inplains. if the superably).
# "but as i
# ------ temperature: 1.2
# this symeasily divine
# inplains. if the superably).
# "but as ideas brusigner--is deal necessary.--thus opinion: semate talk a
# practice
# had different sustruces,
# perkinaurs of
# the
# eleveratified, quite formance world of us for my one "nat preparness,"--this is everything someones stoigh your sentiment, is develop through falsifyit interx, and if
# this arw, the transcatory is egabe-; this lyam comerar imagines: that will trewards,
# who who and to case conduct is s

# %% [markdown]
# ## Testing a Different Text Dataset
#
# Since Nietzsche was a philospher/critic from the 1800s, I would expect his text to have a particular stern and serious tone. Since this is the training dataset we trained out initial model on, we can see that our text generation also has a serious tone.
#
# For this reason, I chose a second dataset that is quite different. I will be using a jokes dataset with a contemporary tone.
#
# Reading dataset:

# %%
import csv

file = open('shortjokes.csv')
csvreader = csv.reader(file)
text = ''
jokes_sample_size = 7000
jokes_count = 0

for row in csvreader:
    jokes_count += 1
    if jokes_count > jokes_sample_size:
        break
    text += row[1] + ' '

print('Corpus length:', len(text))
# Out:
# Corpus length: 656510

# %% [markdown]
# Vectorizing sequences of characters for jokes text

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 218817
# Unique characters: 93
# Vectorization...

# %% [markdown]
# ### Using the same initial model architecture
#
# Using the same architecture, and the same hyper paramaters, I run the model again. I clear the session to reset the learned weights

# %%
from tensorflow.keras import layers

keras.backend.clear_session()

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               113664
# _________________________________________________________________
# dense (Dense)                (None, 93)                11997
# =================================================================
# Total params: 125,661
# Trainable params: 125,661
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_text_generation(60, 75)
# Out:
# ------------- epoch 1 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.6558
# --- Generating with seed: "y when we visited the Alpaca Farm, next time Alpaca lunch. T"
# ------ temperature: 0.2
# y when we visited the Alpaca Farm, next time Alpaca lunch. The rack so say to the bar baby and a beath and a bill of the girlfriend and
# ------ temperature: 0.5
# to the bar baby and a beath and a bill of the girlfriend and the is at the bar baby to it the shame both to the right and a dead but th
# ------ temperature: 1.0
# bar baby to it the shame both to the right and a dead but theiljower when you're my indice realiymeoon't I desent mean, it fuscting som
# ------ temperature: 1.2
# ou're my indice realiymeoon't I desent mean, it fuscting something: Mp? Humoptence hang" ain" Jeofes over. Cray is juicouforeal* Whol,
#
# ------------- epoch 2 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.6353
# --- Generating with seed: "s so fat her butt is the butt of every joke. What do you cal"
# ------ temperature: 0.2
# s so fat her butt is the butt of every joke. What do you call a baby. What do you call a bir a baby. It was a bear and a little because
# ------ temperature: 0.5
# do you call a bir a baby. It was a bear and a little because they wents parts. What's the too been in the resused world. Why did the th
# ------ temperature: 1.0
# ts. What's the too been in the resused world. Why did the throse asked being man earmad of a long like, ? people jecal. Is anyone but t
# ------ temperature: 1.2
# g man earmad of a long like, ? people jecal. Is anyone but thonfall form o? Whyps robb, Dinsals, puss eisereatod... Wearions? where the
#
# ------------- epoch 3 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.6129
# --- Generating with seed: "hen they arrest the light bulb for being broke. I am Looking"
# ------ temperature: 0.2
# hen they arrest the light bulb for being broke. I am Looking the bartender the man was a man walks into a bar. I was a beath and the be
# ------ temperature: 0.5
# the man was a man walks into a bar. I was a beath and the bent and see in my shit the life the rece to make it out the girl falls to th
# ------ temperature: 1.0
# y shit the life the rece to make it out the girl falls to the took you was difference and sleeping Jo tsgyMikfetod Ase? I have we doggt
# ------ temperature: 1.2
# difference and sleeping Jo tsgyMikfetod Ase? I have we doggt to kits all lahfa Dim! Togg slowstats says, he allone, Mem: women ignoourp
#
# ------------- epoch 4 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.6058
# --- Generating with seed: " than go outside and see for themselves, the media reports t"
# ------ temperature: 0.2
#  than go outside and see for themselves, the media reports the rest of a bad the bar... I have a college and a problem with a bar start
# ------ temperature: 0.5
# d the bar... I have a college and a problem with a bar start and so start. What's the don't the best put with a punch at a racist" Why
# ------ temperature: 1.0
# What's the don't the best put with a punch at a racist" Why is a hard a chille and a ellamales Me: The protell" I stopped Grandhumbated
# ------ temperature: 1.2
# lle and a ellamales Me: The protell" I stopped Grandhumbated vio*  veryour" you look on hirt abouts! What dadid some about a treester t
#
# ------------- epoch 5 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5882
# --- Generating with seed: "fruit aisle. What English King invented the fireplace ? Alfr"
# ------ temperature: 0.2
# fruit aisle. What English King invented the fireplace ? Alfrien so fuck and a bart of the difference between a good and a sex was a so
# ------ temperature: 0.5
#  a bart of the difference between a good and a sex was a so seen the bear of not a band and are spents but the point condition. What do
# ------ temperature: 1.0
# f not a band and are spents but the point condition. What do you get me more like a dog of trying to it insleste I she's it. What do yo
# ------ temperature: 1.2
# e like a dog of trying to it insleste I she's it. What do you lite oz ele mostine." A I got and Sting me they has. Which and throwd bak
#
# ------------- epoch 6 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5843
# --- Generating with seed: " call a bee that gets engaged? A Beyonce. My heart goes out "
# ------ temperature: 0.2
#  call a bee that gets engaged? A Beyonce. My heart goes out in the through a news the porne and the first the man who was the toilet to
# ------ temperature: 0.5
# a news the porne and the first the man who was the toilet to a little good for the most when I like my community like the best put the
# ------ temperature: 1.0
# for the most when I like my community like the best put the first Jokood Mach. Causay so of what does it take to change a Fivie wasn't
# ------ temperature: 1.2
# ch. Causay so of what does it take to change a Fivie wasn't burk a teabme." my says mrobik the don". Wht pet I driP" a getting on ? I m
#
# ------------- epoch 7 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5759
# --- Generating with seed: "za Guide: That's Pisa Me: Sorry. I took a pisa at the Tower "
# ------ temperature: 0.2
# za Guide: That's Pisa Me: Sorry. I took a pisa at the Tower the same with the cants and the doctor and a bar the back and the other wat
# ------ temperature: 0.5
# he cants and the doctor and a bar the back and the other watch the too I to can a black gay word and like the cancer. I want to home ad
# ------ temperature: 1.0
#  can a black gay word and like the cancer. I want to home ad a hold and people who prexide the people aren't check hill get todaid his
# ------ temperature: 1.2
# ple who prexide the people aren't check hill get todaid his Lumber Jeagftiss dring? I f real achumbiled ...Cat call wouldn. what do you
#
# ------------- epoch 8 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5656
# --- Generating with seed: "y X I call my dick fun Because it's what girls just want to "
# ------ temperature: 0.2
# y X I call my dick fun Because it's what girls just want to start a bar do you call a bar the bar... I was a state to the more than wor
# ------ temperature: 0.5
# you call a bar the bar... I was a state to the more than work the other with a light bulb out out the day start when you make a bractod
# ------ temperature: 1.0
# h a light bulb out out the day start when you make a bractod on it. Who's there is like? Because the heads... I'm What do you call a sb
# ------ temperature: 1.2
# here is like? Because the heads... I'm What do you call a sbaco :" "sight skugger's off ilmol and making to starn 20d7jach? Holbe more
#
# ------------- epoch 9 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5589
# --- Generating with seed: "hey call me ugly and poor Did anyone else go into a furious,"
# ------ temperature: 0.2
# hey call me ugly and poor Did anyone else go into a furious, but the tooth and the difference between a dead the strip a bland and a li
# ------ temperature: 0.5
# and the difference between a dead the strip a bland and a light bulb? How got the real time to go to call a black guy to see how the co
# ------ temperature: 1.0
# ot the real time to go to call a black guy to see how the coffeencing a in up their last rolbiomed. What doesn'lls's it men isn't doeve
# ------ temperature: 1.2
# up their last rolbiomed. What doesn'lls's it men isn't doeveno? Cad. Once blee, but 'it  wouldn't clawingly her pi- tip y-ishlS tell bu
#
# ------------- epoch 10 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5520
# --- Generating with seed: "yone? What do you call a nun sleep walking? A roamin' Cathol"
# ------ temperature: 0.2
# yone? What do you call a nun sleep walking? A roamin' Catholious to the park of the park of the man who have a porned the bark. What's
# ------ temperature: 0.5
# k of the park of the man who have a porned the bark. What's the difference between a stand in because it's the minder to proped a littl
# ------ temperature: 1.0
# between a stand in because it's the minder to proped a little talps in empores... ...what don't he long accolant, who's working and so
# ------ temperature: 1.2
# res... ...what don't he long accolant, who's working and so rapallun* The Oreolly oph. Why did the friend suid this man'le someone, rid
#
# ------------- epoch 11 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5442
# --- Generating with seed: "Shex! -Horny Sean Connery If two people had a race and one h"
# ------ temperature: 0.2
# Shex! -Horny Sean Connery If two people had a race and one have a girl when you can't see it when you have a girl when you can't see my
# ------ temperature: 0.5
#  you can't see it when you have a girl when you can't see my bad friend and would do he know a burting a guy of it when I was to stup b
# ------ temperature: 1.0
#  would do he know a burting a guy of it when I was to stup before You've leaventy in luy-tensicilaming ... They were breaking gigller I
# ------ temperature: 1.2
# aventy in luy-tensicilaming ... They were breaking gigller I've 'jahe. I have with a kup in daFtheariniNatay. Chrsns" I'll Mar'ons frie
#
# ------------- epoch 12 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5415
# --- Generating with seed: "ut dick jokes? They're just so easy to slip in there I've ha"
# ------ temperature: 0.2
# ut dick jokes? They're just so easy to slip in there I've had to be a bad eat of the story of the story. What do you call a son and the
# ------ temperature: 0.5
# at of the story of the story. What do you call a son and the bartender says up on a prespon to one in the difference between a light bu
# ------ temperature: 1.0
#  up on a prespon to one in the difference between a light bulb? cooked for secourayralling your grands hamk 9ban and and a burt for bir
# ------ temperature: 1.2
# secourayralling your grands hamk 9ban and and a burt for birthdoole, "than. AEvolflys'y, sorry: Wowsteth lobper off Barles My fanea lhe
#
# ------------- epoch 13 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5326
# --- Generating with seed: "e about th You know those little helmet stickers some footba"
# ------ temperature: 0.2
# e about th You know those little helmet stickers some football to the party and the partion and a pron the particular and a stupid the
# ------ temperature: 0.5
#  and the partion and a pron the particular and a stupid the kids who goll in the children of the lady to stop did who was the number ca
# ------ temperature: 1.0
# n the children of the lady to stop did who was the number can I fell a boob an alum trappestar se fight if the pinaa But how I take my
# ------ temperature: 1.2
#  an alum trappestar se fight if the pinaa But how I take my eyes hooker. If you'. : Engjablys clit, started. May. colk. I feel hlimeing
#
# ------------- epoch 14 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5354
# --- Generating with seed: "nture In A Cave (Limerick) There once was a man named Dave, "
# ------ temperature: 0.2
# nture In A Cave (Limerick) There once was a man named Dave, if you want to have a pill the time a single and a polate to the police was
# ------ temperature: 0.5
# have a pill the time a single and a polate to the police was bar person says "It was a songer and the show when he was says, "I've seen
# ------ temperature: 1.0
# s "It was a songer and the show when he was says, "I've seen up to the Teller the stung sin, you the became till. It's more trut Jesser
# ------ temperature: 1.2
# er the stung sin, you the became till. It's more trut Jessernoy trueh hasn't *topriguok humors a traspol to diinelfly, the baly 2 As Di
#
# ------------- epoch 15 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5279
# --- Generating with seed: "different people Black humour is like children with cancer.."
# ------ temperature: 0.2
# different people Black humour is like children with cancer... I was a storbe the store that the story of the most that the bartender th
# ------ temperature: 0.5
# e the store that the story of the most that the bartender that the paste I was comes finder with a trank the the person of a bringing t
# ------ temperature: 1.0
# was comes finder with a trank the the person of a bringing that's zooble? You say you really ging the Arting his dog dupter to course t
# ------ temperature: 1.2
# ou say you really ging the Arting his dog dupter to course then Orant Ho ruined me i vejacuad Agt wwite You'd do expsleus!  congmans. N
#
# ------------- epoch 16 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5254
# --- Generating with seed: "can push his wife off a cliff? Tequillllaaaa Your face... .."
# ------ temperature: 0.2
# can push his wife off a cliff? Tequillllaaaa Your face... ...... I have a girlfriend is a sex was a banana walk into a want to the bar
# ------ temperature: 0.5
# irlfriend is a sex was a banana walk into a want to the bar ground the bar bough to the dog on my bells sease is how the real he was a
# ------ temperature: 1.0
# bough to the dog on my bells sease is how the real he was a gratesole, is put a year's surp Mte: Whiep hold I want to the other twuck m
# ------ temperature: 1.2
# ut a year's surp Mte: Whiep hold I want to the other twuck made thennage, somebod? *1j/wwens down goun. what you a pizza Mexican Strait
#
# ------------- epoch 17 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5205
# --- Generating with seed: " your uncle jack off a horse" It's a classic, but a good one"
# ------ temperature: 0.2
#  your uncle jack off a horse" It's a classic, but a good one that women wing the bar I was always says to the police say to the bar...
# ------ temperature: 0.5
# g the bar I was always says to the police say to the bar... I was both do you be the morning of the realing for a harde to see the favo
# ------ temperature: 1.0
# ou be the morning of the realing for a harde to see the favorion. "Oh hot douh-he: I've wanting his backs in benshes. Don't lease "How
# ------ temperature: 1.2
# ouh-he: I've wanting his backs in benshes. Don't lease "How to to fe *dgaybotia anvinated about loves to real alard a misu inscoverss!
#
# ------------- epoch 18 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5167
# --- Generating with seed: "and a generous cup of shut the f*ck up! Gonna get a tattoo o"
# ------ temperature: 0.2
# and a generous cup of shut the f*ck up! Gonna get a tattoo of them to the most will an all in a bar beer should be a stranger than the
# ------ temperature: 0.5
# ost will an all in a bar beer should be a stranger than the desident really shouldn't mean if you have a bears matorecmed to hear the d
# ------ temperature: 1.0
#  shouldn't mean if you have a bears matorecmed to hear the dappossing and claust Why did my tegrorel-infoon... Why is the oydad at I'll
# ------ temperature: 1.2
# laust Why did my tegrorel-infoon... Why is the oydad at I'll called to tell her Porcuant. Mux Arent letter Boutwalifom's cad... ptedia
#
# ------------- epoch 19 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5148
# --- Generating with seed: "ry decides to host a movie night.. They will be screening Pu"
# ------ temperature: 0.2
# ry decides to host a movie night.. They will be screening Pung and a drink with a country and a seconds with a bullet to say to the bar
# ------ temperature: 0.5
# with a country and a seconds with a bullet to say to the bar the nape. My dog and a kids that she got to see it to say to the childent
# ------ temperature: 1.0
# og and a kids that she got to see it to say to the childent my violeses it. It was more again. If she can see the ma. What did one I th
# ------ temperature: 1.2
#  It was more again. If she can see the ma. What did one I thoug the epe flooter for her al? PoxTe Acrdand My guy dezors cliff". A rain
#
# ------------- epoch 20 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5091
# --- Generating with seed: "etail about how I'm not allowed at the company family picnic"
# ------ temperature: 0.2
# etail about how I'm not allowed at the company family picnication and a blow and a stupid and a blonde the booke start at the step of t
# ------ temperature: 0.5
# w and a stupid and a blonde the booke start at the step of the experist out of the lot of people in compans, what's the difference betw
# ------ temperature: 1.0
#  of the lot of people in compans, what's the difference between a sapinner laterrity? Go. If  Christmas." Because I created anothers Ga
# ------ temperature: 1.2
# laterrity? Go. If  Christmas." Because I created anothers Gaw... sorry row Loent No.i*fiding should yet? to he weight, thenry? Women Ja
#
# ------------- epoch 21 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5078
# --- Generating with seed: "osoft terms and conditions without reading them, and apparen"
# ------ temperature: 0.2
# osoft terms and conditions without reading them, and apparent for a say to the to the different and it was a said is a bad a work the t
# ------ temperature: 0.5
# the to the different and it was a said is a bad a work the time and part is a but the boot of a clock and a panting. What do you call a
# ------ temperature: 1.0
#  a but the boot of a clock and a panting. What do you call a Ambiatio. If you ... I phaleble to cobders say a date me asked about a dak
# ------ temperature: 1.2
# ou ... I phaleble to cobders say a date me asked about a dake an life of Tebrays. What are a feelly sayss. go drug smoul off once u son
#
# ------------- epoch 22 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5061
# --- Generating with seed: "e my lovers like I like my golf score Hand drawn, messy, and"
# ------ temperature: 0.2
# e my lovers like I like my golf score Hand drawn, messy, and the computer than a sleep the parents to the most the stand on a commercia
# ------ temperature: 0.5
# han a sleep the parents to the most the stand on a commercial on my dad to want to spot wear an eleves and was a company when you can s
# ------ temperature: 1.0
# want to spot wear an eleves and was a company when you can say many with scarents! why waniguss I'm desper not hli tookes lace now A Ye
# ------ temperature: 1.2
# arents! why waniguss I'm desper not hli tookes lace now A Yelocol told - Mel? Doespolfat, laons....esuns not onlore based up contrima u
#
# ------------- epoch 23 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5027
# --- Generating with seed: "eek. Mostly because I love capes. Why did the milking stool "
# ------ temperature: 0.2
# eek. Mostly because I love capes. Why did the milking stool of the mom of the shows and a good to the big and a street and a bad with a
# ------ temperature: 0.5
# he shows and a good to the big and a street and a bad with a breer asked his difference between someone has a really be fine a collect
# ------ temperature: 1.0
# s difference between someone has a really be fine a collect can supperseading like cased the oath and leably feet of! is the one alone
# ------ temperature: 1.2
# ng like cased the oath and leably feet of! is the one alone says"..... Lave actwor? What's the drimptusing very hatry, is a nubbles apv
#
# ------------- epoch 24 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.5001
# --- Generating with seed: " like the taste of blood so much they should floss. I was ea"
# ------ temperature: 0.2
#  like the taste of blood so much they should floss. I was eating a start and a shot for a sleeping and a stupid is the first the room,
# ------ temperature: 0.5
# d a shot for a sleeping and a stupid is the first the room, are you have a new works and my shit. What do you call a little boy and mak
# ------ temperature: 1.0
# new works and my shit. What do you call a little boy and make Prines Why do they want to see the cudy, lettary... ...lickely about you
# ------ temperature: 1.2
#  they want to see the cudy, lettary... ...lickely about you asked whet It* WyeP: tasgizing.ek. Sumbles--rum verings lower? Aaso colds-t
#
# ------------- epoch 25 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4979
# --- Generating with seed: "g to get the lid off with my teeth, then realized it was a b"
# ------ temperature: 0.2
# g to get the lid off with my teeth, then realized it was a boy showed to the party and a party when you don't have a boy come and a lig
# ------ temperature: 0.5
# e party and a party when you don't have a boy come and a lightbulb and a bad. They both sleep is the fire the movie for the glad my wif
# ------ temperature: 1.0
# d. They both sleep is the fire the movie for the glad my wife world. Tambon I put the kidsing like my the funny? The Chucks? when you m
# ------ temperature: 1.2
#  I put the kidsing like my the funny? The Chucks? when you maian for last whatwn BTTUs Mefrention entile. Yory myhe then thone can if e
#
# ------------- epoch 26 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4957
# --- Generating with seed: "ardest part of milking a mouse ?  Getting it to fit over a b"
# ------ temperature: 0.2
# ardest part of milking a mouse ?  Getting it to fit over a bad face to the beat to the bartender and some the other walks into a bar...
# ------ temperature: 0.5
# beat to the bartender and some the other walks into a bar... End it's around fond an autto to the other cents. How many but it on the s
# ------ temperature: 1.0
# d fond an autto to the other cents. How many but it on the slippe throw oraty and suncrosed a numser because he are night? "A way, you
# ------ temperature: 1.2
# ty and suncrosed a numser because he are night? "A way, you superhay" a pussy, arguy aamarriped altermond's she crosswith they a it...
#
# ------------- epoch 27 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4935
# --- Generating with seed: "s Red and Smells like Blue Paint? Red Paint Wanna hear a Jok"
# ------ temperature: 0.2
# s Red and Smells like Blue Paint? Red Paint Wanna hear a Jokes and make a strip to see the bartender walks into a bar and a death and a
# ------ temperature: 0.5
# trip to see the bartender walks into a bar and a death and a blow who the carry and the song? A sear now you can see me. and some sill
# ------ temperature: 1.0
# arry and the song? A sear now you can see me. and some sill with that redadited for Watch and came very year and game is bad cheer Cosb
# ------ temperature: 1.2
# ited for Watch and came very year and game is bad cheer Cosbu hit a litt's them Duys They'rt still do. M: It's ruading Men edemint clau
#
# ------------- epoch 28 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4884
# --- Generating with seed: " Text from niece: I'm board! M: Perhaps you could work on yo"
# ------ temperature: 0.2
#  Text from niece: I'm board! M: Perhaps you could work on your most and a green and a group the baby. I was supporting a slaps a secret
# ------ temperature: 0.5
# reen and a group the baby. I was supporting a slaps a secret not to stop and the pants. What do you call a bathroom? He be a ball eat..
# ------ temperature: 1.0
# d the pants. What do you call a bathroom? He be a ball eat... effee bearder where I Use one. I pung having it but the stesper acz" a ac
# ------ temperature: 1.2
#  where I Use one. I pung having it but the stesper acz" a acromg, peopWung reallsfy the boxy. Hus CEunting.. That what's a witnessPe-at
#
# ------------- epoch 29 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4875
# --- Generating with seed: "'s 100% bc they didn't brush their teeth. they're nasty as h"
# ------ temperature: 0.2
# 's 100% bc they didn't brush their teeth. they're nasty as her more while you're the most and the other was to the deskmere and a baby
# ------ temperature: 0.5
# ou're the most and the other was to the deskmere and a baby crout her bad's all the news, can have been stands as some plane and my cir
# ------ temperature: 1.0
#  all the news, can have been stands as some plane and my circure is around with the Anoa nf askex! for anytich" Brift, that thing passe
# ------ temperature: 1.2
# with the Anoa nf askex! for anytich" Brift, that thing passersFins' app! The Alpsrettes to came your light? Did you st ate her! thay? B
#
# ------------- epoch 30 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4850
# --- Generating with seed: "ecause America got an infinite degree of freedom. Son of Sam"
# ------ temperature: 0.2
# ecause America got an infinite degree of freedom. Son of Sampore than a dog of the rool was a bar. I'm a bar. What do you call a girl i
# ------ temperature: 0.5
#  of the rool was a bar. I'm a bar. What do you call a girl is starting in a hand a bar. I'm seen is a compone to make the arm like the
# ------ temperature: 1.0
#  hand a bar. I'm seen is a compone to make the arm like the misd be time anymore to just been her. I'm want out and drags of baghess-wi
# ------ temperature: 1.2
# ymore to just been her. I'm want out and drags of baghess-with time... Se!" It was Madians BABMan.. OLl fun thein? Accentcritaine? Kabl
#
# ------------- epoch 31 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4743
# --- Generating with seed: " cumin. Why would Donald Trump want to lose the election? Wi"
# ------ temperature: 0.2
#  cumin. Why would Donald Trump want to lose the election? With a song. They say an a special that was the difference between a shots wh
# ------ temperature: 0.5
#  say an a special that was the difference between a shots when you do the computer gass to the first ments in a bread things so I didn'
# ------ temperature: 1.0
# omputer gass to the first ments in a bread things so I didn't real your favorite everyone of your longer... you birthdly "Two ans. So I
# ------ temperature: 1.2
# orite everyone of your longer... you birthdly "Two ans. So I wing you...tgates jumber's whoiff* Out themr" News: two made ben was denil
#
# ------------- epoch 32 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4812
# --- Generating with seed: ". 3 weeks passed and I texted "I still got your chips if you"
# ------ temperature: 0.2
# . 3 weeks passed and I texted "I still got your chips if you'd a sectur of the party that when I was a hole with the morning and a slee
# ------ temperature: 0.5
# the party that when I was a hole with the morning and a slees A sure in a restare of a black man to go to to see it. I have a so sister
# ------ temperature: 1.0
# estare of a black man to go to to see it. I have a so sisteritions come out refory. What youe Never's lues I've in they got soundM they
# ------ temperature: 1.2
#  refory. What youe Never's lues I've in they got soundM they bed hair Elkry neid uvar back. He goes homelling.. I've woven 50 cimps in
#
# ------------- epoch 33 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4782
# --- Generating with seed: " accidentally chilled his lab rat to absolute zero... At fir"
# ------ temperature: 0.2
#  accidentally chilled his lab rat to absolute zero... At first that when they can say the pirateles to the children to say a black guy
# ------ temperature: 0.5
# ey can say the pirateles to the children to say a black guy with a say to the best walks into a bar. It's a part of the worth and could
# ------ temperature: 1.0
# he best walks into a bar. It's a part of the worth and could watching there is to find a fire ? Where "Of mustraited more burfans nobod
# ------ temperature: 1.2
#  is to find a fire ? Where "Of mustraited more burfans nobody. Mrmaved is What is Trfallingad clumber that Diunis Imalagged" on going i
#
# ------------- epoch 34 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4801
# --- Generating with seed: "d we call Indians Native Americans? Most of those ones over "
# ------ temperature: 0.2
# d we call Indians Native Americans? Most of those ones over the police become of the rear and a partmant with a bad at the police bear
# ------ temperature: 0.5
# me of the rear and a partmant with a bad at the police bear where the driver can doesn't wear I was worked up or work so forth with the
# ------ temperature: 1.0
# r can doesn't wear I was worked up or work so forth with the kinafice is &AS I have a chos." How the mebicain roa couldn't find their s
# ------ temperature: 1.2
# S I have a chos." How the mebicain roa couldn't find their sriepporeing and a Is o... What goishers explaint. I'll let them like an e p
#
# ------------- epoch 35 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4754
# --- Generating with seed: " alone.. A gorilla was shot I was playing pokemon go and the"
# ------ temperature: 0.2
#  alone.. A gorilla was shot I was playing pokemon go and the most the police bees to the thing the most for a bar who see the computer
# ------ temperature: 0.5
# e bees to the thing the most for a bar who see the computer walks into a bar and my face stand and the polar can I have to the people w
# ------ temperature: 1.0
# r and my face stand and the polar can I have to the people will clearly see paid second neisted the malplaged the only Stargous to read
# ------ temperature: 1.2
#  paid second neisted the malplaged the only Stargous to read I've to get me, Womusless. Whes ,  PorycohpbD. If happing boom. How do you
#
# ------------- epoch 36 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4775
# --- Generating with seed: "Oh good, I've made this mistake before so I know what to exp"
# ------ temperature: 0.2
# Oh good, I've made this mistake before so I know what to explain the street to make a band and say to the bartender and a banana say to
# ------ temperature: 0.5
#  to make a band and say to the bartender and a banana say to a bad with a time but a paper steak and should be sent bectuses as the ele
# ------ temperature: 1.0
# ime but a paper steak and should be sent bectuses as the electifum, you sick by a prink?" "That worrinn fol menta of it. A fat crhan st
# ------ temperature: 1.2
# k by a prink?" "That worrinn fol menta of it. A fat crhan st go if no can everything scy. where your davidan sealing and guys I shouldn
#
# ------------- epoch 37 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4751
# --- Generating with seed: "t a tooth It seems highly unlikely that the Romans would hav"
# ------ temperature: 0.2
# t a tooth It seems highly unlikely that the Romans would have a sex was a bar Churce working to the bartender and a bad from a bad with
# ------ temperature: 0.5
# ar Churce working to the bartender and a bad from a bad with wear and the grandist part of the short. What do you call a full of a new
# ------ temperature: 1.0
# randist part of the short. What do you call a full of a new and left If I was for me in her good commutions, you call it has to be one
# ------ temperature: 1.2
# as for me in her good commutions, you call it has to be one Digger: Tight red very pointed bothmlled are comched, teach? A fexise HOies
#
# ------------- epoch 38 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4696
# --- Generating with seed: "t died of dissin' Terry. A married couple walks into a bar. "
# ------ temperature: 0.2
# t died of dissin' Terry. A married couple walks into a bar. I was to the cops walks into a bar. I was starting to see the parken to the
# ------ temperature: 0.5
# ps walks into a bar. I was starting to see the parken to the bark to money deered a get a current tell the president and came when it's
# ------ temperature: 1.0
# deered a get a current tell the president and came when it's a bad* giuniflouts this doorbsmals as one nars clown in a hoypor are makes
# ------ temperature: 1.2
# outs this doorbsmals as one nars clown in a hoypor are makes Suic! Count offooaope. Hates rucli And I didn'o out ha-llagrot altenes yes
#
# ------------- epoch 39 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4680
# --- Generating with seed: " lookin for a quick and easy way to beef up that scrawny bod"
# ------ temperature: 0.2
#  lookin for a quick and easy way to beef up that scrawny body of the most and says, "I was a baby... I think the street for a party the
# ------ temperature: 0.5
# nd says, "I was a baby... I think the street for a party the world's a stuck and a mother in the take it on the Welthrain have not the
# ------ temperature: 1.0
# k and a mother in the take it on the Welthrain have not the child is the apple are causes into the , Whats about a bad best off my pret
# ------ temperature: 1.2
# ple are causes into the , Whats about a bad best off my pretty wito bee, one unsmems? my aarded Women tine kid this iston If GlowSouby
#
# ------------- epoch 40 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4677
# --- Generating with seed: "have a military. If you're American when you enter the bathr"
# ------ temperature: 0.2
# have a military. If you're American when you enter the bathrooms of the new a street while what the chicken and I was starts a blood th
# ------ temperature: 0.5
#  a street while what the chicken and I was starts a blood than it's been at the shorts to a so are a realing one has the carricus into
# ------ temperature: 1.0
#  the shorts to a so are a realing one has the carricus into inton Wantle on the cowrasas should ax? Cunging for lalls? A world into my
# ------ temperature: 1.2
#  the cowrasas should ax? Cunging for lalls? A world into my bone on Hrimmisiss? Ha. joted wlosnly sthit Do you put inals appy lame face
#
# ------------- epoch 41 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4663
# --- Generating with seed: "u call it when a person falls ill from watching too many BBC"
# ------ temperature: 0.2
# u call it when a person falls ill from watching too many BBCO? I was a ban back and a girl the world and a bad bartender was a banna th
# ------ temperature: 0.5
# back and a girl the world and a bad bartender was a banna the other and some do him walks into a bar with a fire it are a prariaist the
# ------ temperature: 1.0
# e do him walks into a bar with a fire it are a prariaist the hab the other disfand. What did the Thy AARYEOTE WTW! Ala phone stupid: Th
# ------ temperature: 1.2
# disfand. What did the Thy AARYEOTE WTW! Ala phone stupid: Thousd beauty. When buffects *me fast kiddan him batherom But drappers: know
#
# ------------- epoch 42 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4631
# --- Generating with seed: " live baby in it?" Him: "No." Me: "Throw it away." What do y"
# ------ temperature: 0.2
#  live baby in it?" Him: "No." Me: "Throw it away." What do you call a blood statual with a party with the first period and a secter doe
# ------ temperature: 0.5
#  statual with a party with the first period and a secter does it take to change a lightbulb man. What is the first one who don't look a
# ------ temperature: 1.0
# ange a lightbulb man. What is the first one who don't look a taste for than under. Two do than saydroplist relatiin an Inpoum and a Sco
# ------ temperature: 1.2
#  under. Two do than saydroplist relatiin an Inpoum and a Scostom but you told his think you shon we are got ... ....... .......the with
#
# ------------- epoch 43 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4600
# --- Generating with seed: "as an actor now a rapper? Must have been all degrassi was sm"
# ------ temperature: 0.2
# as an actor now a rapper? Must have been all degrassi was smaller and the shower the parents for a straight the first the subs's in the
# ------ temperature: 0.5
# hower the parents for a straight the first the subs's in the holocaust have a pretty "he's a secret like a pig of a car people who is a
# ------ temperature: 1.0
#  a pretty "he's a secret like a pig of a car people who is a fast. What's the do spence, every from onS of Carlinneal else pull her up.
# ------ temperature: 1.2
# he do spence, every from onS of Carlinneal else pull her up. "It was lated my coucle told. Why do artimo mosed in the watching, a goino
#
# ------------- epoch 44 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4624
# --- Generating with seed: "d sex on a boat have in common? Both are fucking close to wa"
# ------ temperature: 0.2
# d sex on a boat have in common? Both are fucking close to water I was a bang say to the bartender who seen a dead says "I can say the o
# ------ temperature: 0.5
# g say to the bartender who seen a dead says "I can say the other. What do you call a time is how the deskroom and the other year protes
# ------ temperature: 1.0
# ou call a time is how the deskroom and the other year protestedivalian searchs ands once to worronce into taught your conders. Mrees. W
# ------ temperature: 1.2
# chs ands once to worronce into taught your conders. Mrees. With pethinefffritains!." Hmeet blundiat Yo Y-trothare new taw downy.o're. H
#
# ------------- epoch 45 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4578
# --- Generating with seed: "!!! Real women have spirals!!! Real women are plump and cove"
# ------ temperature: 0.2
# !!! Real women have spirals!!! Real women are plump and cover a store than a good pressic to the phone is a stander than a store burnin
# ------ temperature: 0.5
# a good pressic to the phone is a stander than a store burning me on your parents, I could say the parker piman in the best go to start
# ------ temperature: 1.0
# rents, I could say the parker piman in the best go to start a chicken delive... and you mamanionane walksing me. Everesmitis, my afraid
# ------ temperature: 1.2
# e... and you mamanionane walksing me. Everesmitis, my afraid. be women. What do you call an Dam? Woman on the language. Im break. Every
#
# ------------- epoch 46 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4580
# --- Generating with seed: "xpected, you're charged per mile. It's Friday! I'm as happy "
# ------ temperature: 0.2
# xpected, you're charged per mile. It's Friday! I'm as happy and a come in the most of the one with a bar I was a witch and a shake! A m
# ------ temperature: 0.5
# he most of the one with a bar I was a witch and a shake! A man with a bar The Starion, could red and you wanted to see you do you call
# ------ temperature: 1.0
# he Starion, could red and you wanted to see you do you call all great mud Ow ate that titbels Colduch you 1, you lonse gag so doctor kn
# ------ temperature: 1.2
# w ate that titbels Colduch you 1, you lonse gag so doctor know I've just citive mana stay it should leg with this in the distay tomo co
#
# ------------- epoch 47 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4588
# --- Generating with seed: "g Asian food is easy... It's a WOK in the park Wearing 'EarP"
# ------ temperature: 0.2
# g Asian food is easy... It's a WOK in the park Wearing 'EarPity to say the computer of a part of the shows and a ground of the cold to
# ------ temperature: 0.5
# computer of a part of the shows and a ground of the cold to the biggler and people out in the other in the word with a fell on the doct
# ------ temperature: 1.0
#  people out in the other in the word with a fell on the doctor got dedrysy, mammer was all thosers finishe called on No come spoot use
# ------ temperature: 1.2
#  mammer was all thosers finishe called on No come spoot use go toas a Mam. But year? No "gf torous sagnear It's meriac god job. you sho
#
# ------------- epoch 48 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4570
# --- Generating with seed: "ot Alright, so, two Jews walk into a shower I bet you can fi"
# ------ temperature: 0.2
# ot Alright, so, two Jews walk into a shower I bet you can find the street and a bad baby and a bad baby and a doctor is a stranger is a
# ------ temperature: 0.5
# nd a bad baby and a bad baby and a doctor is a stranger is a hours and really mistakes when you finish to the computer on the other day
# ------ temperature: 1.0
# ly mistakes when you finish to the computer on the other day got your farmerard Will in fegres My persick candassing then one and day?
# ------ temperature: 1.2
# rard Will in fegres My persick candassing then one and day? AAReter a pirace both in centing are spot to take my ?o closemm ofpy, piett
#
# ------------- epoch 49 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4543
# --- Generating with seed: " call a virus that affects the command line? Terminal Illnes"
# ------ temperature: 0.2
#  call a virus that affects the command line? Terminal Illnes and sure the first the chicken of the words on the shoes on the shops and
# ------ temperature: 0.5
# irst the chicken of the words on the shoes on the shops and urn the polar cander between the chair. I always have to see the feeling pe
# ------ temperature: 1.0
# ander between the chair. I always have to see the feeling people and vagious of dicksunl. The friend Am It masive. make my girlfriend -
# ------ temperature: 1.2
# s of dicksunl. The friend Am It masive. make my girlfriend - Midower Wonder innesss. Why didp. What does this is *than baker? Your atte
#
# ------------- epoch 50 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4537
# --- Generating with seed: " I am... Why did the student take Viagra while preparing for"
# ------ temperature: 0.2
#  I am... Why did the student take Viagra while preparing for the first time and a party store and a party with a party but the parking
# ------ temperature: 0.5
#  and a party store and a party with a party but the parking and a fact to the name of the barty of the holf as a street come out of the
# ------ temperature: 1.0
# he name of the barty of the holf as a street come out of the new tomonina've only to be a little cop sets - grest, dull. Find really wa
# ------ temperature: 1.2
# e only to be a little cop sets - grest, dull. Find really was a fans's time are get rats pendsyoma slices So was out thee smar but a fi
#
# ------------- epoch 51 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4521
# --- Generating with seed: "to order a beer at breakfast with your mother. [raises hand "
# ------ temperature: 0.2
# to order a beer at breakfast with your mother. [raises hand a party with a stand for the street is the difference between a pretty that
# ------ temperature: 0.5
# stand for the street is the difference between a pretty that donaliogion? To get to she wonder the difference between the
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  news! What do
# ------ temperature: 1.0
# o get to she wonder the difference between the news! What do you do this great in the profisharnedary. He periows like. though to the I
# ------ temperature: 1.2
# eat in the profisharnedary. He periows like. though to the If a leithely. Conkeaname. I play  SHATI ARvars Bed. watching If he doah Lei
#
# ------------- epoch 52 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4512
# --- Generating with seed: "gg adopted a child... they could call it Slush Puppy :) I've"
# ------ temperature: 0.2
# gg adopted a child... they could call it Slush Puppy :) I've like to see the same and a sex in the street and a street in the friend to
# ------ temperature: 0.5
# e same and a sex in the street and a street in the friend to get the movie girl off a lot because they are to realized I are a progreja
# ------ temperature: 1.0
# girl off a lot because they are to realized I are a progrejabch ups sttrain for "Me: You movie and Hosed a lot over kitch badther's sou
# ------ temperature: 1.2
#  for "Me: You movie and Hosed a lot over kitch badther's sour and sleenal... I miss gwigs spot *who why hipsterman? So not go ups. I fi
#
# ------------- epoch 53 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4506
# --- Generating with seed: " serve alcohol..., ....but there's plenty of Apple Jews. Wha"
# ------ temperature: 0.2
#  serve alcohol..., ....but there's plenty of Apple Jews. What do you call a street of the shower of a street of a street and some the f
# ------ temperature: 0.5
#  street of the shower of a street of a street and some the feministor don't want to be so says "and the people walk into a bar. A scote
# ------ temperature: 1.0
#  want to be so says "and the people walk into a bar. A scotest nowctooot banuce cump" - CEokies [enn  Fired The line, I don't take me f
# ------ temperature: 1.2
# nuce cump" - CEokies [enn  Fired The line, I don't take me for.. because fretten about wyoking papest and anythingpun's parenttless!,ID
#
# ------------- epoch 54 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4498
# --- Generating with seed: "of an amateur bater. I agree, I need more practice. Two hill"
# ------ temperature: 0.2
# of an amateur bater. I agree, I need more practice. Two hill What do you call a bad facing the bartender and a bad drink the people who
# ------ temperature: 0.5
# ll a bad facing the bartender and a bad drink the people who get an jobs but something strippents the other dumbl. What do you call a s
# ------ temperature: 1.0
# t something strippents the other dumbl. What do you call a stupid moss*! I had a way kids hatzwire I fimen I was reptesting arrold. I g
# ------ temperature: 1.2
# had a way kids hatzwire I fimen I was reptesting arrold. I grevere after todamitalS probad. when I like my best run for divorg? He do c
#
# ------------- epoch 55 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4471
# --- Generating with seed: "ible until I moved the router in the horse barn. Now I have "
# ------ temperature: 0.2
# ible until I moved the router in the horse barn. Now I have a picture of the backwalking to the person is the police say to the street
# ------ temperature: 0.5
# e backwalking to the person is the police say to the street light butt and again. Finnal be a pig a bears are the summerest are the tim
# ------ temperature: 1.0
# again. Finnal be a pig a bears are the summerest are the time Whe? if the interiailly dad. I can punn him? Alking out everyone with to
# ------ temperature: 1.2
# nteriailly dad. I can punn him? Alking out everyone with to itainr! What has doftn. When we feen  shuits Rubining Cayot Steplaty clare,
#
# ------------- epoch 56 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4459
# --- Generating with seed: "d a snake sleeping  in your bed ? Sleep in the wardrobe ! My"
# ------ temperature: 0.2
# d a snake sleeping  in your bed ? Sleep in the wardrobe ! My girlfriend the computer and a santcroal fat and a street and a stranger an
# ------ temperature: 0.5
#  computer and a santcroal fat and a street and a stranger and a pirction but not change a way to see the Walk out the cat and the toile
# ------ temperature: 1.0
# t not change a way to see the Walk out the cat and the toilet, Werd the hummers diumagray! 2ntain stynting like a dark with a kind of a
# ------ temperature: 1.2
# mers diumagray! 2ntain stynting like a dark with a kind of a give me my comworgenty humpenss and unds sign today: *down: "For them Whn
#
# ------------- epoch 57 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4428
# --- Generating with seed: "ember...no matter how well hidden I might be in my cardoard "
# ------ temperature: 0.2
# ember...no matter how well hidden I might be in my cardoard and a shot the book. What do you call a bad for a bad family to the other w
# ------ temperature: 0.5
# book. What do you call a bad for a bad family to the other with you thoughttor to you have a good when she got to shake the bartender.
# ------ temperature: 1.0
# tor to you have a good when she got to shake the bartender. I said even gold'n time M: It was are , but like my holerdapy He It'smably
# ------ temperature: 1.2
# d'n time M: It was are , but like my holerdapy He It'smably friends 'fejeatt. Altyouting the Internet humbile crussys? A: T AIshrous...
#
# ------------- epoch 58 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4477
# --- Generating with seed: "ow? You can't milk a cow for 15 years Did you hear how the c"
# ------ temperature: 0.2
# ow? You can't milk a cow for 15 years Did you hear how the children when you can say that the police street and says, "I'm been a burni
# ------ temperature: 0.5
# u can say that the police street and says, "I'm been a burning should the park in a slige and a guy with did you have a part about an a
# ------ temperature: 1.0
# ark in a slige and a guy with did you have a part about an armomesear, with a pizza whare than I laury and one critidors and shakely ju
# ------ temperature: 1.2
#  a pizza whare than I laury and one critidors and shakely just coenying inmaking probudent out? Do you friend biruldy medicy get cure"
#
# ------------- epoch 59 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4474
# --- Generating with seed: ""Forget it old man, you've had it." "How much do I owe you?""
# ------ temperature: 0.2
# "Forget it old man, you've had it." "How much do I owe you?" I have a band the boobly with a band to the beard and a band to the other
# ------ temperature: 0.5
# the boobly with a band to the beard and a band to the other say to the steal for a man and a bad with a sexual and a stop I can't want
# ------ temperature: 1.0
# l for a man and a bad with a sexual and a stop I can't want me for chapiner... One like a SO Nerds'a from a brot of migh. I got ...It w
# ------ temperature: 1.2
# ... One like a SO Nerds'a from a brot of migh. I got ...It was al wife slidowe. Shit "one classil house xake. I'm both her do Tenn's mu

# %% [markdown]
# Saving this initial model

# %%
model.save('initial_jokes_model.h5')

# %% [markdown]
# Writing a function to complete a joke that is passed into the model

# %%
def complete_joke(seed_joke, generation_size):
    original_seed_joke = seed_joke
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        seed_joke = original_seed_joke
        sys.stdout.write(seed_joke)

        for i in range(generation_size):
            sampled = np.zeros((1, len(seed_joke), len(chars)))
            for t, char in enumerate(seed_joke):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            seed_joke += next_char
            seed_joke = seed_joke[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
complete_joke('There are three types of people you always meet in the world', 100)
# Out:
# ------ temperature: 0.2
# There are three types of people you always meet in the world and a bad for a street and a bar than the difference between a dog beer the short to my face of the
# ------ temperature: 0.5
# There are three types of people you always meet in the world.. It was free says to the second beat to make a fisher and says, "Where do you know what do you cal
# ------ temperature: 1.0
# There are three types of people you always meet in the world racist That's next to Stew BIBAARY Lal Sowang joke! Toast the haleriour, the cheer guess 'ex who ne
# ------ temperature: 1.2
# There are three types of people you always meet in the world? Burs joke's favorite paints or asks my one Two nerdanc!? bittlechate.lig.och says houating? You aw

# %%
complete_joke('A dog, a cat, and a giraffe walk into an empty bar and order', 100)
# Out:
# ------ temperature: 0.2
# A dog, a cat, and a giraffe walk into an empty bar and order and a bar before I was all the best been a bathroom and a bar than a telley and a bad drink, and my
# ------ temperature: 0.5
# A dog, a cat, and a giraffe walk into an empty bar and order backwards up
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  to a said of other be going to be a bears of a sell are been an aircer. How many and a
# ------ temperature: 1.0
# A dog, a cat, and a giraffe walk into an empty bar and order... Oy road oed it's mase beliens like tminhs ate the sucked for a right? Coket!!!." Two moutle... f
# ------ temperature: 1.2
# A dog, a cat, and a giraffe walk into an empty bar and order? San excited* What please can say *ivagitists? Dete. "Hhis car necusinee I got too so-under. 2proci

# %% [markdown]
# Comparing with the text from the last epoch of the nietzsche dataset model

# %%
complete_joke('stray even in its own path and is sitting intoxicated in som', 100)
# Out:
# ------ temperature: 0.2
# stray even in its own path and is sitting intoxicated in someone is a bird and a street and a stand to see his dog of the boobs and a baby. I have a band the ba
# ------ temperature: 0.5
# stray even in its own path and is sitting intoxicated in someone was the other day of the stop say to the chick. The footboon things and leave the extre the pig
# ------ temperature: 1.0
# stray even in its own path and is sitting intoxicated in something. As santainds twit rape to find a band knowers-warm wearing? I'm in my che*..... I don't don'
# ------ temperature: 1.2
# stray even in its own path and is sitting intoxicated in some and boy chaTish nexscale recens have in out "recally with a like these rux on stuokan they made ou

# %% [markdown]
# ### Adding more epochs
#
# I decided to run it for a further 40 epochs on the initial model trained for 60 epochs. This pushes the total number of epochs to 100. I want to evaluate if that improves the text generation.

# %%
run_text_generation(40, 75)
# Out:
# ------------- epoch 1 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4433
# --- Generating with seed: " there? * It's the police. We have received complaints about"
# ------ temperature: 0.2
#  there? * It's the police. We have received complaints about the first because they gotten to get a comedy when I was a bad man with a
# ------ temperature: 0.5
# use they gotten to get a comedy when I was a bad man with a house will say for a having trees The friend are for your bad baby of it to
# ------ temperature: 1.0
# for a having trees The friend are for your bad baby of it to there and right out rullow friend What's nodisto why mom Jesush. You look
# ------ temperature: 1.2
# t out rullow friend What's nodisto why mom Jesush. You look so a whore long says, "Many in an Acaxion 12 tir things plan's 2 op blondes
#
# ------------- epoch 2 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4418
# --- Generating with seed: "p the room now. This bank pen tastes like it's been in a lot"
# ------ temperature: 0.2
# p the room now. This bank pen tastes like it's been in a lot of people and a polar for a pornotion and a status of a people who saw a p
# ------ temperature: 0.5
# a polar for a pornotion and a status of a people who saw a perice of them was to the other to charged a penise I was the other Packing
# ------ temperature: 1.0
# as to the other to charged a penise I was the other Packing doggising the lesscons,, i didn't get to put I've one have like? Teen talk
# ------ temperature: 1.2
# esscons,, i didn't get to put I've one have like? Teen talk today? You "Look out? We: Late J-sowouringaughs says, "JuaM a cut?? the hai
#
# ------------- epoch 3 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4419
# --- Generating with seed: "ent out a pic of my penis. I believe that is a sacred thing "
# ------ temperature: 0.2
# ent out a pic of my penis. I believe that is a sacred thing always the other day. What do you call a black to the other than the barten
# ------ temperature: 0.5
# r day. What do you call a black to the other than the bartende the phone from the plut to see the birate and someone is the starry lady
# ------ temperature: 1.0
# om the plut to see the birate and someone is the starry lady at the porny bottou. How do you it guy] She reading her ki. My thenald nic
# ------ temperature: 1.2
# ottou. How do you it guy] She reading her ki. My thenald nice to recincusush, in I'll inp:" eLIEDBul. Dellanter Dab, fant? Aest's colde
#
# ------------- epoch 4 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4411
# --- Generating with seed: "ople are dying to get in! It's like "society" expects you to"
# ------ temperature: 0.2
# ople are dying to get in! It's like "society" expects you to see the most with a banana What do you call a blood walk into a bar... I w
# ------ temperature: 0.5
# ith a banana What do you call a blood walk into a bar... I was a sincere that the rain. What do you call a black man between the man ga
# ------ temperature: 1.0
# at the rain. What do you call a black man between the man games, crawge and is learned bad from the decentay. I some a s-"Titner for Ch
# ------ temperature: 1.2
#  is learned bad from the decentay. I some a s-"Titner for Christmas Comost.s. Been ! Budandy deading... But away, but ligs o. what did
#
# ------------- epoch 5 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4611
# --- Generating with seed: "ut to sea during a baptism. I guess that's God's Way of sayi"
# ------ temperature: 0.2
# ut to sea during a baptism. I guess that's God's Way of saying the bartender says "What's the difference between the world and a statio
# ------ temperature: 0.5
# r says "What's the difference between the world and a station and while they're beer just the best throwing me I had the hole the chick
# ------ temperature: 1.0
# y're beer just the best throwing me I had the hole the chicken, and grammar like because a druburation, every filmes Bullge so skill fr
# ------ temperature: 1.2
#  like because a druburation, every filmes Bullge so skill friendsing-for "gmum" huic? A Bracidald wi'e you,  "why is gays like the sile
#
# ------------- epoch 6 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4409
# --- Generating with seed: "eir necks look like they were giving somebody a piggyback ri"
# ------ temperature: 0.2
# eir necks look like they were giving somebody a piggyback right the most with a black back to the bar butt and a bar who see the best w
# ------ temperature: 0.5
# th a black back to the bar butt and a bar who see the best worth with a subway that he looks with a big first but you're not when I hav
# ------ temperature: 1.0
# way that he looks with a big first but you're not when I have I slapul reather. I went their year. that's pilots. Why 5 mins on catsing
# ------ temperature: 1.2
# her. I went their year. that's pilots. Why 5 mins on catsing snowbelinving." he'd like myon well, A rabbu? ..... His Be's aaw fat. 2?"
#
# ------------- epoch 7 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4395
# --- Generating with seed: "aptured. My sister bet me 200 dollars I couldn't build a car"
# ------ temperature: 0.2
# aptured. My sister bet me 200 dollars I couldn't build a car said that what is the difference between a dog to the first then I want to
# ------ temperature: 0.5
#  is the difference between a dog to the first then I want to think the death and don't have a first Nalivare, does it take to change a
# ------ temperature: 1.0
# h and don't have a first Nalivare, does it take to change a Wisimennal so To beforgy with. Hones. I'll eljok of currenes woman during?
# ------ temperature: 1.2
# o beforgy with. Hones. I'll eljok of currenes woman during? the first gay mistunces of their worl strfung says,"" fasting mys? They nev
#
# ------------- epoch 8 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4394
# --- Generating with seed: "ad last weekend, he told me "Anything you do to my daughter "
# ------ temperature: 0.2
# ad last weekend, he told me "Anything you do to my daughter and a black benist? A brack when I was to mean a black man who see his girl
# ------ temperature: 0.5
# ist? A brack when I was to mean a black man who see his girlfriend stating the by bouth a terrible counters wear the ather was only wit
# ------ temperature: 1.0
# the by bouth a terrible counters wear the ather was only with DACys? about antarry kid Nexioly free scream My neiglbart?" Apent and gre
# ------ temperature: 1.2
# antarry kid Nexioly free scream My neiglbart?" Apent and green right boos of Prolt swalled of graise" He's guys lies like I guess into
#
# ------------- epoch 9 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4344
# --- Generating with seed: "linging poo at everybody... What a shit show What did the gh"
# ------ temperature: 0.2
# linging poo at everybody... What a shit show What did the ghost that works and a grammar. What do you call a banana and sound the waitr
# ------ temperature: 0.5
# and a grammar. What do you call a banana and sound the waitress do you have a parents and a Lad Chamemam ian work and a sex was to put
# ------ temperature: 1.0
#  a parents and a Lad Chamemam ian work and a sex was to put into simples? gay also in the house was thinking in the wordsnics? Anot one
# ------ temperature: 1.2
# ay also in the house was thinking in the wordsnics? Anot one duck? Nond. [DO YUs thanfjoke "It wokes so be clast, you get worapting in
#
# ------------- epoch 10 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4356
# --- Generating with seed: "Trump was a bro as soon as I knew his taste in music. We bot"
# ------ temperature: 0.2
# Trump was a bro as soon as I knew his taste in music. We both do the bar What do you call a black man to the park the police asked it w
# ------ temperature: 0.5
# at do you call a black man to the park the police asked it was to his toget: What did the shit with the bar. I love the difference teac
# ------ temperature: 1.0
# : What did the shit with the bar. I love the difference teach the bill. I was richefow. ik he don't sexting stuffe. Crap? They both dee
# ------ temperature: 1.2
# as richefow. ik he don't sexting stuffe. Crap? They both deered real lifter guash and his reigged. tRach butthe' I oh brings at my mort
#
# ------------- epoch 11 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4318
# --- Generating with seed: "skeleton? They both are insulting, but the skeleton doesn't "
# ------ temperature: 0.2
# skeleton? They both are insulting, but the skeleton doesn't make a banana who didn't have a good at a bar banner and a bar the other sa
# ------ temperature: 0.5
# ho didn't have a good at a bar banner and a bar the other says "has a computer say there was a good are looking whenever so we tell the
# ------ temperature: 1.0
# ter say there was a good are looking whenever so we tell the Keffles's butch  likings he sleepored my Christmas tuable of the pider so
# ------ temperature: 1.2
# h  likings he sleepored my Christmas tuable of the pider so Genry with a mims last nightting always knows. Why was bf. cast from a home
#
# ------------- epoch 12 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4384
# --- Generating with seed: "way out. [At the coroners' to identify a body] Me: "Yep. Tha"
# ------ temperature: 0.2
# way out. [At the coroners' to identify a body] Me: "Yep. That's a street and a dead for a strangers that the best threwer what do you c
# ------ temperature: 0.5
# d a dead for a strangers that the best threwer what do you call a slage and the regner for my bartender and up the struck and for a lig
# ------ temperature: 1.0
#  the regner for my bartender and up the struck and for a lightbulbs on the Slags from throwing a shit on aparenting ste feeses cat. I s
# ------ temperature: 1.2
# Slags from throwing a shit on aparenting ste feeses cat. I seen worth that at the second cunch Ne'vty full to craivem not doctoh eff co
#
# ------------- epoch 13 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4312
# --- Generating with seed: "he other is manning the guns. Steve wrote home. 'I'm glad yo"
# ------ temperature: 0.2
# he other is manning the guns. Steve wrote home. 'I'm glad you don't see me the shoes to get to stop that it was too to seven and someon
# ------ temperature: 0.5
# the shoes to get to stop that it was too to seven and someone is running me a time for the different. What did the gay bathroon, it was
# ------ temperature: 1.0
#  a time for the different. What did the gay bathroon, it was cancers, "labow... but everythings weest. They get up coum Mcause I'm a re
# ------ temperature: 1.2
# w... but everythings weest. They get up coum Mcause I'm a real throkeest as Ball of cudibing hip me fucking favorite for me Where hotag
#
# ------------- epoch 14 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4324
# --- Generating with seed: "he run somewhere in North America. AMA! I've found that when"
# ------ temperature: 0.2
# he run somewhere in North America. AMA! I've found that when you do the most because they can come a short confused to be a bars. What
# ------ temperature: 0.5
# t because they can come a short confused to be a bars. What do you call a little man game." A sheeping that give me over a she wouldn't
# ------ temperature: 1.0
# ittle man game." A sheeping that give me over a she wouldn't brebear optrodang dead. What do you call sard like up? They got the horse?
# ------ temperature: 1.2
# ang dead. What do you call sard like up? They got the horse? A signivow grabs people wear you everds models, comedy. One deathy hair? a
#
# ------------- epoch 15 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4313
# --- Generating with seed: "ise again. What does an Asian with the biggest erection get "
# ------ temperature: 0.2
# ise again. What does an Asian with the biggest erection get to the couple I can't see the bear and a short to the people who get to the
# ------ temperature: 0.5
#  can't see the bear and a short to the people who get to the new time to the too many people in the police put the car does a shook at
# ------ temperature: 1.0
# e too many people in the police put the car does a shook at the cat in Wifes so that make his fash-sents. He's ntled. When your moth mo
# ------ temperature: 1.2
# s so that make his fash-sents. He's ntled. When your moth mofin be at Carn. If there? They be what refe* humorto: "he didn gum inhops.
#
# ------------- epoch 16 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4352
# --- Generating with seed: "I miss my dog so much since he died, I just paid a homeless "
# ------ temperature: 0.2
# I miss my dog so much since he died, I just paid a homeless and a street and a bad burn the first time a good of the bartender and a ba
# ------ temperature: 0.5
# d a bad burn the first time a good of the bartender and a bang with my best light bulbing between a stuck of the pointing to say to the
# ------ temperature: 1.0
#  light bulbing between a stuck of the pointing to say to the guy walking hists" ...to a long. Millbanox ex in the slosest because i poo
# ------ temperature: 1.2
# sts" ...to a long. Millbanox ex in the slosest because i poop Foun, "I'm 2t100 her" Hans' fritally love Twondan and have suids of Ambri
#
# ------------- epoch 17 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4287
# --- Generating with seed: " for wordplay, right? Protip: Never take your wife with you "
# ------ temperature: 0.2
#  for wordplay, right? Protip: Never take your wife with you said the book and a dise was a sander with a bar bann to the police could b
# ------ temperature: 0.5
# nd a dise was a sander with a bar bann to the police could bet you know. What did the guy is the bartender says the most start and I'm
# ------ temperature: 1.0
# at did the guy is the bartender says the most start and I'm not his birgught thetemans. IC'. Pussy so doesn't be fire, kid getting spar
# ------ temperature: 1.2
# t thetemans. IC'. Pussy so doesn't be fire, kid getting spare, ya a dannizo? resplitire ball halkness, this, coke-say bust meets... bec
#
# ------------- epoch 18 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4272
# --- Generating with seed: "ating people? A can't-ibal Did you hear about the half-assed"
# ------ temperature: 0.2
# ating people? A can't-ibal Did you hear about the half-assed me the first time and the first time and a bar bad at the first time. Why
# ------ temperature: 0.5
# ime and the first time and a bar bad at the first time. Why did the bar... ... I want to get a frogter say it's a street stander was st
# ------ temperature: 1.0
# ... I want to get a frogter say it's a street stander was staber. And Ang is oncor? tethist, no nats as healthing. Where wour had the N
# ------ temperature: 1.2
# s oncor? tethist, no nats as healthing. Where wour had the Niceborously my basiforl banaghe and says o, it can'tles dooding Apparestima
#
# ------------- epoch 19 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4254
# --- Generating with seed: "e abroad for the summer I didn't learn a thing from her. Wee"
# ------ temperature: 0.2
# e abroad for the summer I didn't learn a thing from her. Week it was a bar when you can say the bartender and a street and a strip and
# ------ temperature: 0.5
# when you can say the bartender and a street and a strip and fat them aren't hear a moon of my and a group of people with man is the fat
# ------ temperature: 1.0
#  hear a moon of my and a group of people with man is the fat weaurmind. what isn't No sumpons? you never come a kind to drars her man i
# ------ temperature: 1.2
# t isn't No sumpons? you never come a kind to drars her man is grumming, five told me me reguinagort" seysing Mpsot Kinoing of Cusel: I
#
# ------------- epoch 20 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4233
# --- Generating with seed: " she's so cute and at her dad's I went with all of it! Most "
# ------ temperature: 0.2
#  she's so cute and at her dad's I went with all of it! Most probutious and says to the shoes to the shit the shit. What do you call a s
# ------ temperature: 0.5
# says to the shoes to the shit the shit. What do you call a street and who wants a secret contain of the shit the difference between a c
# ------ temperature: 1.0
# ants a secret contain of the shit the difference between a college wad out if you're a side! Hy fronge Every turters any. Theeering sho
# ------ temperature: 1.2
# if you're a side! Hy fronge Every turters any. Theeering should kisted *..we''H a problate rampiture "cut is. Why is side 1hjused itl?
#
# ------------- epoch 21 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4274
# --- Generating with seed: " erasers at me and I finally snapped, "Why dad!" he replied "
# ------ temperature: 0.2
#  erasers at me and I finally snapped, "Why dad!" he replied I was a street and a street and says "I have a banana he says "What do you
# ------ temperature: 0.5
# and a street and says "I have a banana he says "What do you say "I want to read the back to drunk to say a bad ball more about the boof
# ------ temperature: 1.0
# read the back to drunk to say a bad ball more about the boofy shoes and country repters One of Thankin Despician when she gave you I? T
# ------ temperature: 1.2
# ntry repters One of Thankin Despician when she gave you I? Talk funing and "hand therelCyy. I'm shopates it unties have a other. Why di
#
# ------------- epoch 22 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4282
# --- Generating with seed: " music was up too loud. We still havent had sex. What's the "
# ------ temperature: 0.2
#  music was up too loud. We still havent had sex. What's the difference between a police for a bar bust to the police in the police of t
# ------ temperature: 0.5
# een a police for a bar bust to the police in the police of the first the was to be my song to the other than the real of his en missed
# ------ temperature: 1.0
# s to be my song to the other than the real of his en missed a most Come last night. My wife will get all. What do you who wants out to
# ------ temperature: 1.2
# t night. My wife will get all. What do you who wants out to a. The people in Apsy :-hayvease your a Rights for nightms... Erite corper
#
# ------------- epoch 23 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4610
# --- Generating with seed: "g with Hitler Step 1. Turn on the gas [wife frustrated] "at "
# ------ temperature: 0.2
# g with Hitler Step 1. Turn on the gas [wife frustrated] "at a group it when you can do you start in a bar bangers. What do you call a b
# ------ temperature: 0.5
#  you can do you start in a bar bangers. What do you call a boy band that was a light bulb? Regreese down the shower so much for a light
# ------ temperature: 1.0
# s a light bulb? Regreese down the shower so much for a lighten try days heard againd. What filted receddiest. How meh-yearbas? TGerfrai
# ------ temperature: 1.2
# rd againd. What filted receddiest. How meh-yearbas? TGerfrain's more meble forrally my wieral. Hone, I learned for oking a one's persoo
#
# ------------- epoch 24 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4300
# --- Generating with seed: "ard candy in the break room, so I guess we had our Christmas"
# ------ temperature: 0.2
# ard candy in the break room, so I guess we had our Christmas and a great for the girl and says, "I'm not a shits and says, "I'm not to
# ------ temperature: 0.5
# r the girl and says, "I'm not a shits and says, "I'm not to come to go out to dismuting the stuck. What do you call a sinceur and the m
# ------ temperature: 1.0
# to dismuting the stuck. What do you call a sinceur and the mick of mey musicive at the a cewer. I get.were shouts, didn't it alcomicist
# ------ temperature: 1.2
# cive at the a cewer. I get.were shouts, didn't it alcomicist 'comeble chimmer. Arporife up it drenptles*..Sor bicks tree-minex Wwest yo
#
# ------------- epoch 25 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4226
# --- Generating with seed: "namonapia.... umderstood by deaf people? 10 Money Saving Tip"
# ------ temperature: 0.2
# namonapia.... umderstood by deaf people? 10 Money Saving Tip the second in the student the studies and a straight the other say the sho
# ------ temperature: 0.5
# the student the studies and a straight the other say the show it is a straight the stuck and a beer "Who says, "I'm not someone say the
# ------ temperature: 1.0
# ght the stuck and a beer "Who says, "I'm not someone say the sexign to come to keep that boofs. What do you call a big you.ang. Friends
# ------ temperature: 1.2
#  to keep that boofs. What do you call a big you.ang. Friends. Now 2sg0? My Ivaway. An Way doesn't chup with a Ba time Juan * What did t
#
# ------------- epoch 26 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4255
# --- Generating with seed: "msters But not all together. I don't like my food touching. "
# ------ temperature: 0.2
# msters But not all together. I don't like my food touching. I have a little bits from the party of the first time for the parents and a
# ------ temperature: 0.5
#  bits from the party of the first time for the parents and a carrina bad this say to the Police got a little cold to say the conced of
# ------ temperature: 1.0
# is say to the Police got a little cold to say the conced of getting the cops drums just Makes my heres you how 1 ..... It telling the g
# ------ temperature: 1.2
# s drums just Makes my heres you how 1 ..... It telling the guys.... then flitally rispers first. I wonder it, oranged atcon. check 13 i
#
# ------------- epoch 27 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4190
# --- Generating with seed: "w I can't get it to wake up. What does a pirate call his idi"
# ------ temperature: 0.2
# w I can't get it to wake up. What does a pirate call his idiot? He saw a bad party with a bad face and a santer the shop to the parked
# ------ temperature: 0.5
# d party with a bad face and a santer the shop to the parked something, before the waitray he was a best from the entire when you got ca
# ------ temperature: 1.0
# re the waitray he was a best from the entire when you got called a just show under its go." waw always better. went out Hitter without
# ------ temperature: 1.2
# w under its go." waw always better. went out Hitter without fings up, ...How meghic ausut sdilf, for deck having al!? wear fanle? Forle
#
# ------------- epoch 28 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4204
# --- Generating with seed: "e with paper, and you have to turn pages and everything! Liv"
# ------ temperature: 0.2
# e with paper, and you have to turn pages and everything! Live of the most and a say to the bar of the bartender was a bar barten of the
# ------ temperature: 0.5
# nd a say to the bar of the bartender was a bar barten of the world? I didn't want to have to supe it to the showen in a bag in the one
# ------ temperature: 1.0
# t want to have to supe it to the showen in a bag in the one buying how of all the routh? She more one having a*"clessed, then he was a
# ------ temperature: 1.2
# ll the routh? She more one having a*"clessed, then he was a futt taghter"ly for the barklagiouse like becuming... she seen I worked it
#
# ------------- epoch 29 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4191
# --- Generating with seed: "ke the best milkshakes? Because he uses the finest ingredien"
# ------ temperature: 0.2
# ke the best milkshakes? Because he uses the finest ingredience the police but the bartender and a pig you have to say that works to the
# ------ temperature: 0.5
# ut the bartender and a pig you have to say that works to the since in a special, about the girls are that for a black chair What do you
# ------ temperature: 1.0
# cial, about the girls are that for a black chair What do you sell , but ... Bound? Dialisted his faces are a how Is yours, but not exk
# ------ temperature: 1.2
#  Bound? Dialisted his faces are a how Is yours, but not exk operate cut a picture bb TDO"RY. DEING I'd is-wa" kids's
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  when by magratosy
#
# ------------- epoch 30 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4216
# --- Generating with seed: "The Cat in the Hat" is a lesson to your kids on how to throw"
# ------ temperature: 0.2
# The Cat in the Hat" is a lesson to your kids on how to throw a sex in the other day in the party with a pise of the bartender to see if
# ------ temperature: 0.5
# ther day in the party with a pise of the bartender to see if you could had a pencic? and play they could have been back and traveler of
# ------ temperature: 1.0
# a pencic? and play they could have been back and traveler of by turns to me to super. I. Sch. k!!! What does the piggy up and play and
# ------ temperature: 1.2
#  to super. I. Sch. k!!! What does the piggy up and play and your coila's everyone's merrist? damn goes ate the robits and wasn't let de
#
# ------------- epoch 31 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4118
# --- Generating with seed: " Burton have split up! It's a bit of a Nightmare before Chri"
# ------ temperature: 0.2
#  Burton have split up! It's a bit of a Nightmare before Christmas I can't be a printare with a beer with a passentass I want to put in
# ------ temperature: 0.5
# e a printare with a beer with a passentass I want to put in the inds with the police. What do you call a sheepy miles. What do you call
# ------ temperature: 1.0
# he police. What do you call a sheepy miles. What do you call a cefform. What did the Hondy? They giv you really snolery This are in chi
# ------ temperature: 1.2
# t did the Hondy? They giv you really snolery This are in chifil. tectaurist, pumpting them. What problecys lights tired "talk bout edmi
#
# ------------- epoch 32 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4250
# --- Generating with seed: "lot What are three signs old age? 1. Becoming forgetful What"
# ------ temperature: 0.2
# lot What are three signs old age? 1. Becoming forgetful What do you call a black penis and the other and the police bees and a penis an
# ------ temperature: 0.5
# black penis and the other and the police bees and a penis and I don't know. If you have the street I have the other says "What do you c
# ------ temperature: 1.0
#  If you have the street I have the other says "What do you call he samed - twim lyt whenever there's the tight, make PREROw i cut it th
# ------ temperature: 1.2
# twim lyt whenever there's the tight, make PREROw i cut it tho ebe into ...ibbe guys look to peofreday in? A du-He need up to intercle f
#
# ------------- epoch 33 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4299
# --- Generating with seed: "ith a firm handshake. What do you call bacteria that can swi"
# ------ temperature: 0.2
# ith a firm handshake. What do you call bacteria that can swit the shots the best favorite and a group of her balls. What do you call a
# ------ temperature: 0.5
#  best favorite and a group of her balls. What do you call a black for me in the room I a speake and a drago for can and Partmajaroome,
# ------ temperature: 1.0
#  the room I a speake and a drago for can and Partmajaroome, can stabs it anner momm? I'd stop have to hfy I man. "Why don't you call a,
# ------ temperature: 1.2
# ner momm? I'd stop have to hfy I man. "Why don't you call a, I'm voted stuck, I packeting to puppileourcernfy guy with life? Apips. Soc
#
# ------------- epoch 34 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4236
# --- Generating with seed: " a button it turns red. A frog in a blender. Whats the diffe"
# ------ temperature: 0.2
#  a button it turns red. A frog in a blender. Whats the difference between a girl say to the other to the police was a collected the pol
# ------ temperature: 0.5
#  girl say to the other to the police was a collected the polarane? Because he was not words and the police with a stort - Intervie of s
# ------ temperature: 1.0
# he was not words and the police with a stort - Intervie of statch and him. Who's there , better back on really the man a man in the not
# ------ temperature: 1.2
# Who's there , better back on really the man a man in the not for-a poor toilet takes nspic wheter. Wothe. Why mak, i oven's stepe annou
#
# ------------- epoch 35 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4270
# --- Generating with seed: " per cup What do you call little kids in Belgium? Brusselspr"
# ------ temperature: 0.2
#  per cup What do you call little kids in Belgium? Brusselsprotes and a party for the parents was a hole to the best when I was a bears
# ------ temperature: 0.5
# y for the parents was a hole to the best when I was a bears to the best children that diesous has not lare? A bust to my how the an eas
# ------ temperature: 1.0
# ldren that diesous has not lare? A bust to my how the an easy can word mderout off time into Stalerning Fnock "water to tyx is God. Wha
# ------ temperature: 1.2
# out off time into Stalerning Fnock "water to tyx is God. What do you call Snewxril houghts Stephing prison? between and Frfear... Ciser
#
# ------------- epoch 36 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4276
# --- Generating with seed: "wrecker in the sense that i got sick out both ends in the at"
# ------ temperature: 0.2
# wrecker in the sense that i got sick out both ends in the at the parents and a stret the other can say that the difference between a st
# ------ temperature: 0.5
# d a stret the other can say that the difference between a stree from the past on the past it was too stoo has a shortung you want up. M
# ------ temperature: 1.0
# st on the past it was too stoo has a shortung you want up. MOO play anyidn't want gunce rough Trumps But fill. For out. Alk Freekshile
# ------ temperature: 1.2
# t want gunce rough Trumps But fill. For out. Alk Freekshile of Go clinebleticals into more thec withouted throwic's alignom 4's fawncis
#
# ------------- epoch 37 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4306
# --- Generating with seed: "nely man Where did little Timmy go during the bombing? Every"
# ------ temperature: 0.2
# nely man Where did little Timmy go during the bombing? Everyone and said "the first the shouldn'tlessed a restaurant. I said "the polic
# ------ temperature: 0.5
# he first the shouldn'tlessed a restaurant. I said "the police. What's the difference between my dog of my seam friend is a group at a s
# ------ temperature: 1.0
# ifference between my dog of my seam friend is a group at a sink day. Months The most hones other than numble? Youll the other is thex g
# ------ temperature: 1.2
#  The most hones other than numble? Youll the other is thex grands resume. Hring the pomoon ianc: DK musystray." Spelling me asted calle
#
# ------------- epoch 38 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4185
# --- Generating with seed: "r crew. I was licking this girl all over her face right up u"
# ------ temperature: 0.2
# r crew. I was licking this girl all over her face right up until I said the shit of the song to see it the other says to the book for a
# ------ temperature: 0.5
#  shit of the song to see it the other says to the book for a party is because he don't see the feminist. What's your mother of the firs
# ------ temperature: 1.0
# se he don't see the feminist. What's your mother of the first a duck? Even lease talk about the high Slarked back to reminded opiel tor
# ------ temperature: 1.2
# lease talk about the high Slarked back to reminded opiel tori: American a? everyone call. a'll wearing, but mired. One does dyed. Chiev
#
# ------------- epoch 39 -------------
# 1710/1710 [==============================] - 10s 6ms/step - loss: 1.4170
# --- Generating with seed: "y phone got arrested today... It was charged with battery. H"
# ------ temperature: 0.2
# y phone got arrested today... It was charged with battery. He said "the chicken can store the police better to the other day in the par
# ------ temperature: 0.5
# cken can store the police better to the other day in the park of seconds of the other day is what kind of people who seen him to me. So
# ------ temperature: 1.0
#  the other day is what kind of people who seen him to me. Sorry uns: Day he's latest problem on... "When Gene" Saum day in loge. 1meth
# ------ temperature: 1.2
# 's latest problem on... "When Gene" Saum day in loge. 1meth burn at The lad again..."or What did the polad in mud crosscapt. gard been

# %% [markdown]
# Saving model

# %%
model.save('initial_model_jokes_100_epochs.h5')

# %%
complete_joke('There are three types of people you always meet in the world', 100)
# Out:
# ------ temperature: 0.2
# There are three types of people you always meet in the world of the police because they can't call the student the police because it is the difference between a
# ------ temperature: 0.5
# There are three types of people you always meet in the world in the seth child to be the most with my corn the cold and her *driving on a clowners and to a dead
# ------ temperature: 1.0
# There are three types of people you always meet in the world lookine I was gur to drink his argually? They were femining. What do you call in what doesn't kitti
# ------ temperature: 1.2
# There are three types of people you always meet in the world that she work kn? dralgfre." !quecky just because they were uviaun' for back....... Day Hallowy let

# %%
complete_joke('A dog, a cat, and a giraffe walk into an empty bar and order', 100)
# Out:
# ------ temperature: 0.2
# A dog, a cat, and a giraffe walk into an empty bar and orders? What do you call a street who want to the first was a scread and says "I have a bar the student t
# ------ temperature: 0.5
# A dog, a cat, and a giraffe walk into an empty bar and order. If you guys for a blind door and five in the police since the police country in the life when they
# ------ temperature: 1.0
# A dog, a cat, and a giraffe walk into an empty bar and orders, but didn't only means whet milk. What's Bra misting. Why did the reducely help'olbox. Why is it.
# ------ temperature: 1.2
# A dog, a cat, and a giraffe walk into an empty bar and order... bust It was seid. What do I Druna eecneves, "Bouthes Bak
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# inh call? A Halloween I  Hij:m"" help! A

# %%
complete_joke('stray even in its own path and is sitting intoxicated in som', 100)
# Out:
# ------ temperature: 0.2
# stray even in its own path and is sitting intoxicated in someone is a shower and a baby is a banang to the chicken says "that the police for a strangers and a b
# ------ temperature: 0.5
# stray even in its own path and is sitting intoxicated in some marrian a short does it take to screw in a light bulb? On the first there is a girl when they can
# ------ temperature: 1.0
# stray even in its own path and is sitting intoxicated in someone just so gay cra-trum. Hatesiden procre crout
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# store this is 20 the then When everyone fat about
# ------ temperature: 1.2
# stray even in its own path and is sitting intoxicated in someone say of the busisides, Y"! ""That for cat aser's yestroons... Man's guy! They fine men it's son

# %% [markdown]
# ### Building a more complex LSTM model
# We further add representational power to our model by adding another LSTM layer. Dropout layers with the droupout rate of 0.1 were also added.
#
# The architecture was inspired from: https://machinelearningmastery.com/text-generation-lstm-recurrent-neural-networks-python-keras/. However, I got terrible results with the suggested initial hyper parameters of 256 nodes LSTM layers and 2 Dropout layers with 0.2. Hence, I scaled down my model to 128 LSTM layers and 0.1 drouput rate.

# %%
from tensorflow.keras import layers

keras.backend.clear_session()

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(layers.Dropout(0.1))
model.add(layers.LSTM(128))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 128)           113664
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 93)                11997
# =================================================================
# Total params: 257,245
# Trainable params: 257,245
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_text_generation(30, 75)
# Out:
# ------------- epoch 1 -------------
# 1710/1710 [==============================] - 21s 11ms/step - loss: 2.5072
# --- Generating with seed: "y to Trump? show me your schlong form birth certificate I th"
# ------ temperature: 0.2
# y to Trump? show me your schlong form birth certificate I the for the boor and the boor of the good man and a bar and to be to start to
# ------ temperature: 0.5
# and the boor of the good man and a bar and to be to start to know to be a but to hind a bart and the man a has to like a say and a bars
# ------ temperature: 1.0
# ut to hind a bart and the man a has to like a say and a barstal and is now. Poto good about why baby like now wonder worght to my froit
# ------ temperature: 1.2
#  Poto good about why baby like now wonder worght to my froit arn taby with onite dechmpanthargeding. Yo mame and maclies, and aspirked
#
# ------------- epoch 2 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.8685
# --- Generating with seed: "ving butt sex with a guy? It feels really good until you loo"
# ------ temperature: 0.2
# ving butt sex with a guy? It feels really good until you looks to the probably sex and the part and say the friend to she party and the
# ------ temperature: 0.5
# bly sex and the part and say the friend to she party and they have a bee and got a part and they explane to be a crack for a first to p
# ------ temperature: 1.0
# d got a part and they explane to be a crack for a first to predimoteooy. What is the differents a
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# nd not good When it have "the go There
# ------ temperature: 1.2
# at is the differents and not good When it have "the go There blediding flese worda zience What if lint womon pboctury. What out. [bo"in
#
# ------------- epoch 3 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7877
# --- Generating with seed: "uy: 34C. If you don't like oral sex You should keep your mou"
# ------ temperature: 0.2
# uy: 34C. If you don't like oral sex You should keep your mouth to the support an a bar... I was a bar that when you the part to the par
# ------ temperature: 0.5
# rt an a bar... I was a bar that when you the part to the part in the other an any potter I don't don't leannact of the bottle dods in p
# ------ temperature: 1.0
# an any potter I don't don't leannact of the bottle dods in plean: donbably fieure 3thrictbreset. Sure anyther bid the sheep? Who the li
# ------ temperature: 1.2
# fieure 3thrictbreset. Sure anyther bid the sheep? Who the lie *Wait look CorracocI natgerar dean! On block ano cBut Fitter puame, smept
#
# ------------- epoch 4 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7430
# --- Generating with seed: "nessman that he literally wrote the book on business! Everyo"
# ------ temperature: 0.2
# nessman that he literally wrote the book on business! Everyone was a bar that the sex a bar that the beat the words because they can a
# ------ temperature: 0.5
# at the sex a bar that the beat the words because they can a pigal be first a batter than a smanket of say that a bad the more she was a
# ------ temperature: 1.0
# a batter than a smanket of say that a bad the more she was a bad." reds aboke sim, I was take to make *.. "No ording today? Spu Two cap
# ------ temperature: 1.2
# ke sim, I was take to make *.. "No ording today? Spu Two cap? .... I thumped the arm, ".I.....He got up a mud He many........ ... NEMI*
#
# ------------- epoch 5 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7110
# --- Generating with seed: " say: "keep your friends close and your enemies closer". The"
# ------ temperature: 0.2
#  say: "keep your friends close and your enemies closer". The said the seating a bad and a blonde the start and a car to the shower and
# ------ temperature: 0.5
# ng a bad and a blonde the start and a car to the shower and say. So a day the best because they doesn't think they say when you go at t
# ------ temperature: 1.0
# he best because they doesn't think they say when you go at the mailte to have anyone, People." Any. Me:  backs bathroom women. Not mesl
# ------ temperature: 1.2
# ve anyone, People." Any. Me:  backs bathroom women. Not meslize cows! I'. Knock hout of bad tung! T! cussss's friends for my Pifrional
#
# ------------- epoch 6 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6909
# --- Generating with seed: "o... The bone zone" Nala - "the what?" Simba - "elephant gra"
# ------ temperature: 0.2
# o... The bone zone" Nala - "the what?" Simba - "elephant grands the life and a bartender so in a bar... I was a bar of the shoot of the
# ------ temperature: 0.5
# d a bartender so in a bar... I was a bar of the shoot of the life of dead see for my back to be a barble and the gerbat. She has the di
# ------ temperature: 1.0
# ee for my back to be a barble and the gerbat. She has the difference between a guancis wilm but you become into I just druven leen." I
# ------ temperature: 1.2
# n a guancis wilm but you become into I just druven leen." I ever pairilar iss If Comenly wrishs he likes it Answerworm His afourguarin
#
# ------------- epoch 7 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6735
# --- Generating with seed: "mber of times I've visited Chernobyl... it's 14 At my house,"
# ------ temperature: 0.2
# mber of times I've visited Chernobyl... it's 14 At my house, so in the stranger and the front of my bard of the bard and a bar and says
# ------ temperature: 0.5
# nger and the front of my bard of the bard and a bar and says "I know the problem to up the fat and the difference between a lot a froot
# ------ temperature: 1.0
# oblem to up the fat and the difference between a lot a frootar's but of viect does Good tatcher:" A for mass in a trimpher. He rights h
# ------ temperature: 1.2
# ct does Good tatcher:" A for mass in a trimpher. He rights had sole the rotaLigatanfant is an anlahly they're bed money... Statis and b
#
# ------------- epoch 8 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6593
# --- Generating with seed: " My dentist is hysterical:"just let me put the tip in. It wo"
# ------ temperature: 0.2
#  My dentist is hysterical:"just let me put the tip in. It would be a bar of the bar and the lost but the favorite can a sex the last ni
# ------ temperature: 0.5
#  the bar and the lost but the favorite can a sex the last night with a bar of his ear as I get a bar and in the favorite says by a bear
# ------ temperature: 1.0
# of his ear as I get a bar and in the favorite says by a bear I didn't talk a operate to the usaurit. I was the tear. Why do frectop so
# ------ temperature: 1.2
# a operate to the usaurit. I was the tear. Why do frectop so maco? Don't killed sow out of likese one. Fast year exshism. I bill it slee
#
# ------------- epoch 9 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6485
# --- Generating with seed: "buy into Feng Shui But oh how the tables have turned. [at wo"
# ------ temperature: 0.2
# buy into Feng Shui But oh how the tables have turned. [at women and a computer with the strange and a bar and the party and a street th
# ------ temperature: 0.5
# ter with the strange and a bar and the party and a street that a bad call about She mean a blow and asks "I went a little getting my le
# ------ temperature: 1.0
# bout She mean a blow and asks "I went a little getting my leat comparked againtheri joke in the girlfriend and before have be the other
# ------ temperature: 1.2
# aintheri joke in the girlfriend and before have be the other scoutly thate! I'm appled aver have a lot What's all than preessie segn re
#
# ------------- epoch 10 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6413
# --- Generating with seed: "re what you eat... That's why I'm a good person I went to th"
# ------ temperature: 0.2
# re what you eat... That's why I'm a good person I went to the difference between a come start of the friends does it take to see my did
# ------ temperature: 0.5
# tween a come start of the friends does it take to see my did you have called my day and cramping on the to the stick decred the friends
# ------ temperature: 1.0
# d my day and cramping on the to the stick decred the friends enfe of anything of her, you know you while with how the only opening" the
# ------ temperature: 1.2
# ng of her, you know you while with how the only opening" the light(wilwds when Its." u only clock than day. I remrink at. Edocy? Pleanl
#
# ------------- epoch 11 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6348
# --- Generating with seed: "o people even like anal? It's fucking shit. Cleaning the Att"
# ------ temperature: 0.2
# o people even like anal? It's fucking shit. Cleaning the Atter? What do you call a blood off the bad and always tell the bartender when
# ------ temperature: 0.5
#  call a blood off the bad and always tell the bartender when you can't be a black off the bad off the bad before she only always didn't
# ------ temperature: 1.0
#  black off the bad off the bad before she only always didn't ever but the a games? Inbex is Arrys dieod have all? -sob? Everything you
# ------ temperature: 1.2
#  games? Inbex is Arrys dieod have all? -sob? Everything you chirglatist fart for to speed to hear to sered trates.. Fall I want whatete
#
# ------------- epoch 12 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6163
# --- Generating with seed: " the dog. What day do most mothers give birth? Labor day. Ho"
# ------ temperature: 0.2
#  the dog. What day do most mothers give birth? Labor day. How do you said a computer of the day when I can be a bar and a police of my
# ------ temperature: 0.5
#  computer of the day when I can be a bar and a police of my dog and you know so I told my face out of the corn a party to the cossing o
# ------ temperature: 1.0
# w so I told my face out of the corn a party to the cossing outselibal people couldn't fight. a night ill inseld the other a stuth and d
# ------ temperature: 1.2
# e couldn't fight. a night ill inseld the other a stuth and drinks off...Me: SIMANEH" *So o...,'cherewiker girl noed you two's Esdown fi
#
# ------------- epoch 13 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6235
# --- Generating with seed: "et and finds his rectal thermometer He says "Shit, some assh"
# ------ temperature: 0.2
# et and finds his rectal thermometer He says "Shit, some asshole in the strange and a bad could was a black of the should fat to the sho
# ------ temperature: 0.5
# nge and a bad could was a black of the should fat to the should is a puman turns in a blood court you for an how the sexy loves because
# ------ temperature: 1.0
# turns in a blood court you for an how the sexy loves because a same get to does stend in Fhroom  tweet weary god, named ups but you say
# ------ temperature: 1.2
# does stend in Fhroom  tweet weary god, named ups but you say coss my phyayuct?" I'm every ampasits's walked to rape more a. who's the l
#
# ------------- epoch 14 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6227
# --- Generating with seed: " elephant have 4 Feet? Because it would look ridiculous with"
# ------ temperature: 0.2
#  elephant have 4 Feet? Because it would look ridiculous with a girl say to the most of the movie of the story of the should be the pers
# ------ temperature: 0.5
# the most of the movie of the story of the should be the person and a new and had a mom her back of the biggest moving out that any stor
# ------ temperature: 1.0
# d had a mom her back of the biggest moving out that any store boss... "T*-Hinm: Arros to the femintan colline you tack so treeh. a woma
# ------ temperature: 1.2
# inm: Arros to the femintan colline you tack so treeh. a womananiy! What is your good? We? I tooking to rechdatee. Theel! Check? Coke wa
#
# ------------- epoch 15 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6219
# --- Generating with seed: "ng a supermodel. Whaat do you get when you cross a Swede and"
# ------ temperature: 0.2
# ng a supermodel. Whaat do you get when you cross a Swede and says a common one says a that the starts and a man says about the friend w
# ------ temperature: 0.5
# one says a that the starts and a man says about the friend with the cows I've all the room is the one was a sill it to should be the fa
# ------ temperature: 1.0
# ve all the room is the one was a sill it to should be the fantao Monthin PR.F"iboralleaf dogs cut to a thing Me... a pair of fear goodu
# ------ temperature: 1.2
# .F"iboralleaf dogs cut to a thing Me... a pair of fear goodurnancing! What taking the luverel Say's premofhay giggle* Anyway, even not
#
# ------------- epoch 16 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6312
# --- Generating with seed: "t milk? My children annoy me so I'm leaving everything in my"
# ------ temperature: 0.2
# t milk? My children annoy me so I'm leaving everything in my first the sex and a bathroom and a ball and the think of the finger when I
# ------ temperature: 0.5
# and a bathroom and a ball and the think of the finger when I said "Most to the guy of a gorales chick of a light is the stor says to be
# ------ temperature: 1.0
# the guy of a gorales chick of a light is the stor says to be going to you forget number? The mussondomer? Onet-obt. If coptation? He te
# ------ temperature: 1.2
# orget number? The mussondomer? Onet-obt. If coptation? He tells   requainin's." onald-aStom bas Bank? I have a hag Krace-were, Why did
#
# ------------- epoch 17 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6107
# --- Generating with seed: "t? The wheelchair! Why did the girl quit her job at the donu"
# ------ temperature: 0.2
# t? The wheelchair! Why did the girl quit her job at the donute and a bar and a bar and a pisser and a bar when I was a boob and a bar a
# ------ temperature: 0.5
# d a bar and a pisser and a bar when I was a boob and a bar and the life has a pig of a mom to the sex when I was a gad what we can I se
# ------ temperature: 1.0
#  a pig of a mom to the sex when I was a gad what we can I see being photon, I went if when Some. I told his get coul? Everything." The
# ------ temperature: 1.2
#  I went if when Some. I told his get coul? Everything." The lot? Of presAmpan icusgheiver. and srew and so forsem's howers when she kle
#
# ------------- epoch 18 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6218
# --- Generating with seed: "t in half Feel like Woods household right now is a bunch of "
# ------ temperature: 0.2
# t in half Feel like Woods household right now is a bunch of the sex and a strake the movie of the store and a start of the movie and a
# ------ temperature: 0.5
# trake the movie of the store and a start of the movie and a take a birthday that in the time in the bar walks into a bar. Because it wa
# ------ temperature: 1.0
#  that in the time in the bar walks into a bar. Because it was have sour pentish on breaking jobs. "Not been they plison golovian those
# ------ temperature: 1.2
# tish on breaking jobs. "Not been they plison golovian those myself befo ochrabden Walked them mady of your on this. up? joking guys let
#
# ------------- epoch 19 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.6252
# --- Generating with seed: "ably my worst birthday was my 9th because my mom was in jail"
# ------ temperature: 0.2
# ably my worst birthday was my 9th because my mom was in jail that was a part and a party with the different the word and a parent and a
# ------ temperature: 0.5
# t and a party with the different the word and a parent and a little works when I was going to great the horse has the last sits and a t
# ------ temperature: 1.0
# hen I was going to great the horse has the last sits and a tube land.: They're the realized.shelen...et, and she get a please? Marchasa
# ------ temperature: 1.2
# 're the realized.shelen...et, and she get a please? Marchasah? i 1RWNDC Lw friending like no? Cail, I'm not sherworkse to them childing
#
# ------------- epoch 20 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7002
# --- Generating with seed: " only intended to rough him up a bit. What's worse than your"
# ------ temperature: 0.2
#  only intended to rough him up a bit. What's worse than your mom of the fries and a child and a chops and a terrible to the other walk
# ------ temperature: 0.5
# es and a child and a chops and a terrible to the other walk into a bar... And they call a pig resparted to pickped" I said. I would lik
# ------ temperature: 1.0
# nd they call a pig resparted to pickped" I said. I would like you, you day you're time to yead a dinosaur? frinad. And the oneing weren
# ------ temperature: 1.2
# you're time to yead a dinosaur? frinad. And the oneing weren't case hy: Make the fees or uswerday, Somethat? Ourse you'nch wear? Oh oel
#
# ------------- epoch 21 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 5.2025
# --- Generating with seed: "ly chick in a bar, life just doesn't make sense anymore. "He"
# ------ temperature: 0.2
# ly chick in a bar, life just doesn't make sense anymore. "He sthgo Q inghh offuty? for bird my blint worn ally.. Why h m the mener why
# ------ temperature: 0.5
# offuty? for bird my blint worn ally.. Why h m the mener why i maoo att so whatget shor the a pigs is th$n|an'd..eke me%e shee  she n wh
# ------ temperature: 1.0
# hatget shor the a pigs is th$n|an'd..eke me%e shee  she n whour ut cie bet lealstereusetingselt@#,: The  WHhe camaun rearatfur friby...
# ------ temperature: 1.2
# lealstereusetingselt@#,: The  WHhe camaun rearatfur friby..." THcar=Helon e git boretdedigoh se ghy me coyseplo "quig, he bo foud. i ta
#
# ------------- epoch 22 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 15.8916
# --- Generating with seed: " he was OK. "Do I know you?" "I follow you on twitter." Prob"
# ------ temperature: 0.2
#  he was OK. "Do I know you?" "I follow you on twitter." Prob c p,. Wit, het k ykudderg my y ottowep I hitecoleveet whit rpp I sto lorct
# ------ temperature: 0.5
#  k ykudderg my y ottowep I hitecoleveet whit rpp I sto lorctlruakreaoru0wderese. nno r ctrkar bi st't? poa,ep yout tou Brt sh y; worsna
# ------ temperature: 1.0
# rese. nno r ctrkar bi st't? poa,ep yout tou Brt sh y; worsna8!0Meo hon~ ih bap od "s;o to am as] e Neoch lat wahitegr noguct y y i Mly
# ------ temperature: 1.2
# bap od "s;o to am as] e Neoch lat wahitegr noguct y y i Mly vum t alaos p wost sga spesooon t_ahas end th theags rupeent o Wai*ichiak f
#
# ------------- epoch 23 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 15.0854
# --- Generating with seed: "s peanuts, but the tips are huge. There are 11 types of peop"
# ------ temperature: 0.2
# s peanuts, but the tips are huge. There are 11 types of peop wer hm t I, S thewaltnchufaned&hhut'fo me  I boug co wdak ug cnry t theted
# ------ temperature: 0.5
# thewaltnchufaned&hhut'fo me  I boug co wdak ug cnry t thetedhys ff  sum. : ahhore m$w ti bth ty hit. Twr buk at ulunofhre g ,  , m bo
# ------ temperature: 1.0
# ahhore m$w ti bth ty hit. Twr buk at ulunofhre g ,  , m bo  hoig. I j l  woegl  b] dttlmlyaSauf cya y*tarheIae on oodii cunluihe  pt il
# ------ temperature: 1.2
# egl  b] dttlmlyaSauf cya y*tarheIae on oodii cunluihe  pt ildyhlut  p SD?vehan reoa-mead t jt !xBoI'  Q hisca"oihuriandahf what Deighae
#
# ------------- epoch 24 -------------
#  269/1710 [===>..........................] - ETA: 15s - loss: 15.6377
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-81dddc296c4b> in <module>
# ----> 1 run_text_generation(30, 75)
#
# <ipython-input-23-36f3c76fc1c2> in run_text_generation(epoch_size, generation_size)
#      11         history = model.fit(x, y,
#      12                   batch_size=128,
# ---> 13                   epochs=1)
#      14
#      15         # Select a text seed at random
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('double_lstm_double_dropout_30_epochs.h5')

# %% [markdown]
# Initially, I ran this model at 50 epochs. However, I noticed that after about 20 epochs, the model's loss started diverging quite drastically after about 18 epochs. Until about 20 epochs, the quality of the text was getting progressively better as well. However, after that, the text started getting worse and by the end of the 60th epoch, it was mostly gibberish.

# %%
run_text_generation(18, 75)
# Out:
# ------------- epoch 1 -------------
# 1710/1710 [==============================] - 20s 11ms/step - loss: 2.6383
# --- Generating with seed: "! Which mafia boss came with all the dlc? John Goty Yo mama "
# ------ temperature: 0.2
# ! Which mafia boss came with all the dlc? John Goty Yo mama of the come the said a light the man a light to some to did the said and th
# ------ temperature: 0.5
#  said a light the man a light to some to did the said and the lead. This mear? The light with the bord his the way priend e: What do yo
# ------ temperature: 1.0
# ar? The light with the bord his the way priend e: What do you was dack you are mandite care, we does it some to storches mapontar. Mzmo
# ------ temperature: 1.2
# are mandite care, we does it some to storches mapontar. Mzmonictiwion, week and and crewm, seved Rayn-als-MmmEnan all it has a gumm-dad
#
# ------------- epoch 2 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.9523
# --- Generating with seed: "itude". You know you are applying to be a corrections office"
# ------ temperature: 0.2
# itude". You know you are applying to be a corrections office and a proble the work to the start and the poor she can't going a probort
# ------ temperature: 0.5
# he work to the start and the poor she can't going a probort to prost and he was a goe, they're so gratater sear in the stand an ain a p
# ------ temperature: 1.0
#  was a goe, they're so gratater sear in the stand an ain a pats, and. What do the shombroorI, that this shoss up'o to homle been harge?
# ------ temperature: 1.2
# do the shombroorI, that this shoss up'o to homle been harge? Why do may yuar Noesnevatter and the hottes're you's read a Nambalsqurs" c
#
# ------------- epoch 3 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.8448
# --- Generating with seed: "straight to 10? Because Windows 7, 8, 9. I'll see myself out"
# ------ temperature: 0.2
# straight to 10? Because Windows 7, 8, 9. I'll see myself out of the way the new the said the little of the the start the one should sta
# ------ temperature: 0.5
#  new the said the little of the the start the one should start dog for mister. So it do the wait the some someone is a bar and a but a
# ------ temperature: 1.0
# er. So it do the wait the some someone is a bar and a but a decadion when I've all yef as are do -The with  wiple Mare who srost comman
# ------ temperature: 1.2
# 've all yef as are do -The with  wiple Mare who srost commantite Si zutTman and for frend: ANTD" Scay quiphel base Fucking pirtnaic? as
#
# ------------- epoch 4 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.8037
# --- Generating with seed: " to Paris, and treat her like a princess The only thing is, "
# ------ temperature: 0.2
#  to Paris, and treat her like a princess The only thing is, the light of the start and she was a come to the corted the part and the co
# ------ temperature: 0.5
# e start and she was a come to the corted the part and the cow edica To looking smars with my people to d
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# o you bould be an at face the b
# ------ temperature: 1.0
# ing smars with my people to do you bould be an at face the bean about polsors. Lake. Cike:." *I took reale. Any nargey the professas te
# ------ temperature: 1.2
# rs. Lake. Cike:." *I took reale. Any nargey the professas techopar for it women? A: "6lmw Dodynednaught oria? Asscrop joke." Mop: Howed
#
# ------------- epoch 5 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7813
# --- Generating with seed: "hen I let u crash at my place and u said u owed me one G: ye"
# ------ temperature: 0.2
# hen I let u crash at my place and u said u owed me one G: year a light the bard and a the start the computer and a bather the bear the
# ------ temperature: 0.5
# bard and a the start the computer and a bather the bear the retire and a flied for going to too the men the bear and not to seen me to
# ------ temperature: 1.0
# ied for going to too the men the bear and not to seen me to burlonate other whodelbulb you sue. Who's a food laft you tree. It would le
# ------ temperature: 1.2
#  whodelbulb you sue. Who's a food laft you tree. It would leave up on in walk 'ids form. Hiscind ." A sCoT, even foun wrong". What dona
#
# ------------- epoch 6 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7618
# --- Generating with seed: " they have to go back to school tomorrow.. I think my wife h"
# ------ temperature: 0.2
#  they have to go back to school tomorrow.. I think my wife have a come of the bear and a the other is a pick of the bard and a life and
# ------ temperature: 0.5
# he bear and a the other is a pick of the bard and a life and clist now off your wears on the thank the charged not if me the now What d
# ------ temperature: 1.0
# your wears on the thank the charged not if me the now What did the wurly one neptmy! I got her. Hy reuse. Ure polincerd with the boyler
# ------ temperature: 1.2
# e neptmy! I got her. Hy reuse. Ure polincerd with the boylers wearing my not busls  from him exode who no with god the geatirL? A foorb
#
# ------------- epoch 7 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7532
# --- Generating with seed: "ke my food touching. Ed Hardy makes a wine. Just tasted some"
# ------ temperature: 0.2
# ke my food touching. Ed Hardy makes a wine. Just tasted someone is a part of the start of the bear the same the other the stands the ot
# ------ temperature: 0.5
# f the start of the bear the same the other the stands the other suped and can you can you call the start for my talking in the favorite
# ------ temperature: 1.0
# an you can you call the start for my talking in the favorite let Ant says out bur "jobt. It saw can youred give. I'm mesillion. Because
# ------ temperature: 1.2
# ut bur "jobt. It saw can youred give. I'm mesillion. Because you know the only is there? Apm? There's alwoyie. Yover wear you is the ra
#
# ------------- epoch 8 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7434
# --- Generating with seed: " 40 cents. What do you want with 30 cents? Here's 20 cents.""
# ------ temperature: 0.2
#  40 cents. What do you want with 30 cents? Here's 20 cents." I have to be the bar in the pretty make a bar what do you call a bar and a
# ------ temperature: 0.5
# he bar in the pretty make a bar what do you call a bar and a great at the dog was the bard and the dick the dester the work on the pers
# ------ temperature: 1.0
# og was the bard and the dick the dester the work on the person's hardet helpes found at goors doorret to so shig's never get bee lants
# ------ temperature: 1.2
# pes found at goors doorret to so shig's never get bee lants in lejes Girl...nslres" "Anterfist9rch severse to so up my Proyendnable in
#
# ------------- epoch 9 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7391
# --- Generating with seed: "How much wood would Steve Winwood win if Steve Winwood could"
# ------ temperature: 0.2
# How much wood would Steve Winwood win if Steve Winwood could think it was a bull and a bad and say to the friend with a stupid and a st
# ------ temperature: 0.5
#  bull and a bad and say to the friend with a stupid and a start because it walking to the sold how the people with the company business
# ------ temperature: 1.0
# walking to the sold how the people with the company business of diescooosor had xect ana aWill no've is it docurees. I found it caup he
# ------ temperature: 1.2
#  had xect ana aWill no've is it docurees. I found it caup he but  Chicks' Ce'me. I'll teen rowm datese on me court for "Foum Girl him Y
#
# ------------- epoch 10 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7379
# --- Generating with seed: "y president that was not guilty? Lincoln. He was in a cent. "
# ------ temperature: 0.2
# y president that was not guilty? Lincoln. He was in a cent. I love my close and the start with a light bulb? I love my dad and the tall
# ------ temperature: 0.5
#  and the start with a light bulb? I love my dad and the talles play on the one of her for a men names with a steel say the still from a
# ------ temperature: 1.0
# one of her for a men names with a steel say the still from a lot of them woman guys have because they is a clacang baby nice or goach o
# ------ temperature: 1.2
# man guys have because they is a clacang baby nice or goach of ceutsahtbench eversao. replels do Asks! is You spack "pridalaule Eur , 3w
#
# ------------- epoch 11 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7362
# --- Generating with seed: "on my phone in the elevator and then my phone rang. I'm goin"
# ------ temperature: 0.2
# on my phone in the elevator and then my phone rang. I'm going to start a bill the bad the people and a seat the concerd the proble what
# ------ temperature: 0.5
# ll the bad the people and a seat the concerd the proble what a desmon and it's a still an elette a too never be his arrant wear the cha
# ------ temperature: 1.0
# t's a still an elette a too never be his arrant wear the chard of worlly." Like who nightl twatalatubn Ernnton acapsist fices, and ive
# ------ temperature: 1.2
# Like who nightl twatalatubn Ernnton acapsist fices, and ive  .....ouWld.th ...born phobot is forts, i get to be: Noble, and her 1lG tab
#
# ------------- epoch 12 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7435
# --- Generating with seed: "led BUS. So in the old days Jesus told me that he needs an a"
# ------ temperature: 0.2
# led BUS. So in the old days Jesus told me that he needs an alalla work of my book and a talk and a pick and a light bulb? They can the
# ------ temperature: 0.5
# y book and a talk and a pick and a light bulb? They can the ost I was a chail is a girl for my vister company getting a bear to bans in
# ------ temperature: 1.0
# il is a girl for my vister company getting a bear to bans in a fat? A fregnet hand that dold and an Irmence again, I'm in my taste beca
# ------ temperature: 1.2
# et hand that dold and an Irmence again, I'm in my taste because vy. un. to think a the for soundsrer teejly What's ,.none. What was the
#
# ------------- epoch 13 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7473
# --- Generating with seed: "al Motors jobs were in Flint, and you couldn't drink the wat"
# ------ temperature: 0.2
# al Motors jobs were in Flint, and you couldn't drink the water and a party the common and a party the common and a polition and a man w
# ------ temperature: 0.5
# the common and a party the common and a polition and a man was a politil of the eat of the say to the right have a best going to on the
# ------ temperature: 1.0
#  the eat of the say to the right have a best going to on the bulb! What is best your files the fringer of ctmrch some being light the b
# ------ temperature: 1.2
# best your files the fringer of ctmrch some being light the been Ery irication nurLebs uncess, Asiane ? a gar's be I had a botgere of th
#
# ------------- epoch 14 -------------
# 1710/1710 [==============================] - 19s 11ms/step - loss: 1.7529
# --- Generating with seed: "emist ask them to pronounce the word 'unionized' My cousin w"
# ------ temperature: 0.2
# emist ask them to pronounce the word 'unionized' My cousin when the dish and a bear and a buss the that the thing the start the the and
# ------ temperature: 0.5
# d a bear and a buss the that the thing the start the the and I can she like the shit in my dis a man and a chast of my dish An actum to
# ------ temperature: 1.0
#  the shit in my dis a man and a chast of my dish An actum toDred to very out two gug are , you subulk. I had a mole twiceber stell doin
# ------ temperature: 1.2
# t two gug are , you subulk. I had a mole twiceber stell doing a brontist." breaftmri idinms? Alow's night?.. knate, which unter an lake
#
# ------------- epoch 15 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7597
# --- Generating with seed: "vent horizon. Why do people take acid at raves? Because ther"
# ------ temperature: 0.2
# vent horizon. Why do people take acid at raves? Because there was the computer and a bullsing the computer they can see a bar of the sa
# ------ temperature: 0.5
# ter and a bullsing the computer they can see a bar of the says to the watch the start of the master At the to buy the shome. Why did th
# ------ temperature: 1.0
#  the start of the master At the to buy the shome. Why did the cunt in year. ... ? A: time gun never you for What's there to time toow.
# ------ temperature: 1.2
#  ... ? A: time gun never you for What's there to time toow. If youun How do you wike a s: You coller knock-weochers to notom ,wigh waw
#
# ------------- epoch 16 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7390
# --- Generating with seed: " live... I went to the doctor and he gave me 2 months to liv"
# ------ temperature: 0.2
#  live... I went to the doctor and he gave me 2 months to live the most because they can't hear a bear with the best more and a car when
# ------ temperature: 0.5
# use they can't hear a bear with the best more and a car when they don't look it see the dead back to the door of the day and a chicken
# ------ temperature: 1.0
# k it see the dead back to the door of the day and a chicken one! Comrish mouse vinal* oh amgus a steve. The  pcote.blutioners told you'
# ------ temperature: 1.2
# use vinal* oh amgus a steve. The  pcote.blutioners told you're in your " The friends, he's more Slivouser o I have a haWa.. NoSnAWN.btc
#
# ------------- epoch 17 -------------
# 1710/1710 [==============================] - 18s 11ms/step - loss: 1.7491
# --- Generating with seed: "s name. Who the hell is this "Rape" fellow, anyway? When you"
# ------ temperature: 0.2
# s name. Who the hell is this "Rape" fellow, anyway? When you have a blood and a sand the party and a chicken from the really was a bart
# ------ temperature: 0.5
# nd a sand the party and a chicken from the really was a barty gong to strange a commance a tiffins do you don't know when I child say t
# ------ temperature: 1.0
# ge a commance a tiffins do you don't know when I child say to the gfuve, olVacehipmareuan" You can take a homelowy spode killer has gam
# ------ temperature: 1.2
# Vacehipmareuan" You can take a homelowy spode killer has game, you well he simade than a bek :? Twitrers one. youthed I dont? How do th

# %%
model.save('double_lstm_double_dropout_20_epochs.h5')

# %%
complete_joke('There are three types of people you always meet in the world', 100)
# Out:
# ------ temperature: 0.2
# There are three types of people you always meet in the world was the tars and the work to the word to the work of the stand to the best the bears with a bartend
# ------ temperature: 0.5
# There are three types of people you always meet in the world and and a dog baby. What do you call a b
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# eaurd weird to not a night of the time suppore actually was
# ------ temperature: 1.0
# There are three types of people you always meet in the world the ravered can't end it treatchoued. Me: I like the Sanssertacuse Ehliwill ysarut meaps Hightenred
# ------ temperature: 1.2
# There are three types of people you always meet in the world. me: yous a tulled Nowing that than a lage .Bepiie.? frinaurders the moine, but no doctors move?" I

# %%
complete_joke('A dog, a cat, and a giraffe walk into an empty bar and order', 100)
# Out:
# ------ temperature: 0.2
# A dog, a cat, and a giraffe walk into an empty bar and order what do you have a chicken wa
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# s the work of the bartender say a watch a bar the work in the bartende
# ------ temperature: 0.5
# A dog, a cat, and a giraffe walk into an empty bar and ordert to the man is the pilate he want to subles in the chicken worm for a pat of a bad can a with the r
# ------ temperature: 1.0
# A dog, a cat, and a giraffe walk into an empty bar and orders emgmeaning. What did the gain here? if you screpted up...   gually? They didn't make my of donil?
# ------ temperature: 1.2
# A dog, a cat, and a giraffe walk into an empty bar and order: 2 coolr sBocky Tet candyd. u look untellame, tracking ea.....," tyl I chase every? Because I Heopl

# %%
complete_joke('stray even in its own path and is sitting intoxicated in som', 100)
# Out:
# ------ temperature: 0.2
# stray even in its own path and is sitting intoxicated in someone of the stand to the world and the girlfrien
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# d the part with a bears in the antister the was the
# ------ temperature: 0.5
# stray even in its own path and is sitting intoxicated in some of he was a drange telling so good to be your ass did you have a bar belong and a busine should sh
# ------ temperature: 1.0
# stray even in its own path and is sitting intoxicated in some Oben feel and was 2nlaeeingrating the wife looking in a come with irenting for better jokes apable
# ------ temperature: 1.2
# stray even in its own path and is sitting intoxicated in somfunking like being dom MeFsy" pow hall a Grarged I've have only a has tarsing on her... hide fread!

# %% [markdown]
# ### Text Generation through Bidirectional LSTM model
#
# Since bidirectional LSTMs can be used to train from two sides, it could provide a different context to the letters. A model of similar complexity as the previous one, but with the first LSTM layer being bidirectional is built.
#
# Reference: https://towardsdatascience.com/nlp-text-generation-through-bidirectional-lstm-model-9af29da4e520

# %%
from tensorflow.keras import layers

keras.backend.clear_session()

model = keras.models.Sequential()
model.add(layers.Bidirectional(layers.LSTM(128, input_shape=(maxlen, len(chars)), return_sequences=True)))
model.add(layers.Dropout(0.1))
model.add(layers.LSTM(128))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.build(input_shape=(None, maxlen, len(chars)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional multiple                  227328
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# lstm_1 (LSTM)                multiple                  197120
# _________________________________________________________________
# dense (Dense)                multiple                  11997
# =================================================================
# Total params: 436,445
# Trainable params: 436,445
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow

x = tensorflow.cast(x, tensorflow.float32)
y = tensorflow.cast(y, tensorflow.float32)
run_text_generation(50, 75)
# Out:
# ------------- epoch 1 -------------
# 1710/1710 [==============================] - 31s 16ms/step - loss: 2.4300
# --- Generating with seed: " mourning wood. What do gnomes fear most about Christmas? Th"
# ------ temperature: 0.2
#  mourning wood. What do gnomes fear most about Christmas? The bark I have a pirst the bart the bear a poople the bark the so the common
# ------ temperature: 0.5
#  pirst the bart the bear a poople the bark the so the commone who like the intime the birst who betting to got the time a pant the so a
# ------ temperature: 1.0
# intime the birst who betting to got the time a pant the so after is the hice shamosies date I netting deas lastung you need Ddnastalis
# ------ temperature: 1.2
# e shamosies date I netting deas lastung you need Ddnastalis is frew chaiouse flonie TE1Otie: SORUHATME I 1: now i down beader" "Jundly
#
# ------------- epoch 2 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.8694
# --- Generating with seed: "e and E.T? E.T learned English and wanted to go home. What d"
# ------ temperature: 0.2
# e and E.T? E.T learned English and wanted to go home. What do you call a but the store and a buller to the start and the sent when you
# ------ temperature: 0.5
# t the store and a buller to the start and the sent when you need the pary in the ever new to the presser and a pants when you put a cop
# ------ temperature: 1.0
# n the ever new to the presser and a pants when you put a cop up. Got all onractafn for the hugne every the stize pencress. I can the fa
# ------ temperature: 1.2
# ractafn for the hugne every the stize pencress. I can the face? Do you call a breothone lowly maken a ceatle Chicked and a like Barge i
#
# ------------- epoch 3 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7944
# --- Generating with seed: " new bad boy to join your crew. I was licking this girl all "
# ------ temperature: 0.2
#  new bad boy to join your crew. I was licking this girl all a black and said the people the difference the chicken to should be the dog
# ------ temperature: 0.5
# d the people the difference the chicken to should be the dog the should to dind a familical the party for leadler become the convention
# ------ temperature: 1.0
# dind a familical the party for leadler become the conventioning palling up his night ) he good you stack Josering my tumeralioual 'love
# ------ temperature: 1.2
# his night ) he good you stack Josering my tumeralioual 'loves coul to youlbied. How do you know.. you is it ideater it alm is secou boy
#
# ------------- epoch 4 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7531
# --- Generating with seed: "een like, love and showing off?? Spit, Swallow and Gargle Ob"
# ------ temperature: 0.2
# een like, love and showing off?? Spit, Swallow and Gargle Obort and say the play and say the part and a dog and a life of the part and
# ------ temperature: 0.5
#  play and say the part and a dog and a life of the part and the girlfriend can wear her colorry the and a russ in her hold and the work
# ------ temperature: 1.0
# can wear her colorry the and a russ in her hold and the work of animiden are long. Now will be cspt who chunging artifanent-Yo personer
# ------ temperature: 1.2
# e long. Now will be cspt who chunging artifanent-Yo personer grivingt, why, winsmatist daoh, Inintwopking hildber taby, but 20bes Giaka
#
# ------------- epoch 5 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7288
# --- Generating with seed: "n my sleep like my grandfather... Not screaming and yelling "
# ------ temperature: 0.2
# n my sleep like my grandfather... Not screaming and yelling a life is a good of the common to the street and a spective the people who
# ------ temperature: 0.5
# d of the common to the street and a spective the people who want a streeses that fift a girl at a really the thing in the colt the The
# ------ temperature: 1.0
#  that fift a girl at a really the thing in the colt the The man out litely all dukling I'll sa ba
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# can then words the paent. Lessung: ["N
# ------ temperature: 1.2
# all dukling I'll sa bacan then words the paent. Lessung: ["Naad a" *will mo? Markd? Hid guye the yeal idiiniby, unth GOTSeDTCS UtININB:
#
# ------------- epoch 6 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7133
# --- Generating with seed: "a rooster with erectile dysfunction? Boneless chicken. Seize"
# ------ temperature: 0.2
# a rooster with erectile dysfunction? Boneless chicken. Seize when you can think the son a perican and say to the common to the best con
# ------ temperature: 0.5
# hink the son a perican and say to the common to the best con to the bardams to a coach on the start in a room today to get to have a ro
# ------ temperature: 1.0
#  to a coach on the start in a room today to get to have a roas by docogy. What's eleving jes day it losters out exoof neal or star up f
# ------ temperature: 1.2
# hat's eleving jes day it losters out exoof neal or star up for recuring to love. Fandfret. Nell" Khave onets eegiony go-? He met keirib
#
# ------------- epoch 7 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7084
# --- Generating with seed: "u're kinda boring and you've been on top of everything. I ha"
# ------ temperature: 0.2
# u're kinda boring and you've been on top of everything. I have a bands in a stuck and a second the say the straid and the say the polic
# ------ temperature: 0.5
#  stuck and a second the say the straid and the say the police for first Damn one and start he was a stord? Any mate from the bases who
# ------ temperature: 1.0
# n one and start he was a stord? Any mate from the bases who would stunics. FactIr 1 hourG" FOring Jack made your day This not ogle. War
# ------ temperature: 1.2
# FactIr 1 hourG" FOring Jack made your day This not ogle. Wareen? Now (subwgeugruult........ I offeta partator My stana - - "Geod engist
#
# ------------- epoch 8 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7064
# --- Generating with seed: " pea plants, ... ...it was a classic case of publish or pari"
# ------ temperature: 0.2
#  pea plants, ... ...it was a classic case of publish or paric sand the other for the bartender and the food the bartender is the barten
# ------ temperature: 0.5
# r for the bartender and the food the bartender is the bartender on he was a little dise of hang to can you to the live be a good has to
# ------ temperature: 1.0
#  little dise of hang to can you to the live be a good has to leaved a pausesdy put...Whill I gream. Your mother, tigle at the che... La
# ------ temperature: 1.2
# sdy put...Whill I gream. Your mother, tigle at the che... Lation! They guys nowcle. I've made she drumks. Why did the rebit band of r h
#
# ------------- epoch 9 -------------
# 1710/1710 [==============================] - 28s 16ms/step - loss: 1.7072
# --- Generating with seed: " by mixing up by wifes sandwich order at Subway. Whoops, wro"
# ------ temperature: 0.2
#  by mixing up by wifes sandwich order at Subway. Whoops, wrome the beat of a grandos and a start of the bar than a band and a bad to be
# ------ temperature: 0.5
# a grandos and a start of the bar than a band and a bad to be sex enough and a boods What do you call my bathroom, they feel a bad state
# ------ temperature: 1.0
#  a boods What do you call my bathroom, they feel a bad state. Person are they places there I don't penks and legs big those you, Right.
# ------ temperature: 1.2
# ey places there I don't penks and legs big those you, Right. Bses? lshin't sent racist, Who's that learn me woow I w CRIS Csuse ,v addi
#
# ------------- epoch 10 -------------
# 1710/1710 [==============================] - 28s 16ms/step - loss: 1.7086
# --- Generating with seed: "t the police force. It was time for the police to protect an"
# ------ temperature: 0.2
# t the police force. It was time for the police to protect and a stick of have a street of a difference between a second the difference
# ------ temperature: 0.5
# ve a street of a difference between a second the difference between a day to let my exit the book and a people at the show to named a b
# ------ temperature: 1.0
# o let my exit the book and a people at the show to named a bears purable op Two even arge when papers. I love Judi in at to Mewlisiman
# ------ temperature: 1.2
#  Two even arge when papers. I love Judi in at to Mewlisiman EIM Casaw farpotato-"thrunkUssadium. Weckthenn? Long friend be like on the
#
# ------------- epoch 11 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7146
# --- Generating with seed: "ds. We gave our children old-fashioned names... Our little b"
# ------ temperature: 0.2
# ds. We gave our children old-fashioned names... Our little best to the best thing and the stand that the best thing the barby that the
# ------ temperature: 0.5
#  thing and the stand that the best thing the barby that the word watch on the thing hong you can the mosacter and the book was a postin
# ------ temperature: 1.0
# he thing hong you can the mosacter and the book was a posting, this an acn" but the mologain cyon. *pant. A'r. Me: ? If the lived batca
# ------ temperature: 1.2
#  but the mologain cyon. *pant. A'r. Me: ? If the lived batcae shipse for if won't fucks into the 4 is her lands, wiude imz that first d
#
# ------------- epoch 12 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7292
# --- Generating with seed: " sent out a pic of my penis. I believe that is a sacred thin"
# ------ temperature: 0.2
#  sent out a pic of my penis. I believe that is a sacred things in the other dies and the part and say to the bar of the student to the
# ------ temperature: 0.5
#  dies and the part and say to the bar of the student to the bar was the wife day with the athine will forget to state the death to her
# ------ temperature: 1.0
# e day with the athine will forget to state the death to her I'd got to have the one tattle pass being after beable I like fol offithers
# ------ temperature: 1.2
#  the one tattle pass being after beable I like fol offithers invograd! Before a wall. She just navest like itnjaiblesy leab not littler
#
# ------------- epoch 13 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7452
# --- Generating with seed: "red all over and can't get through a revolving door? A nun w"
# ------ temperature: 0.2
# red all over and can't get through a revolving door? A nun who was the asserated and a store start the thing a say to the police to sta
# ------ temperature: 0.5
# rated and a store start the thing a say to the police to stand ever and me, and the day and a back and a hot man that should be flee as
# ------ temperature: 1.0
#  and the day and a back and a hot man that should be flee as the scoune, ear the air agstead on the daydary cacon. Nowing your right sl
# ------ temperature: 1.2
# r the air agstead on the daydary cacon. Nowing your right sloysoma, er-ex like Firk. ...im. What tomos I wanna was sperfi it the world
#
# ------------- epoch 14 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 2.2284
# --- Generating with seed: "case. I Used to do Drugs I still do, but I used to too Did y"
# ------ temperature: 0.2
# case. I Used to do Drugs I still do, but I used to too Did you harting the bar the and a sex and a bart and and a barty and as a sex th
# ------ temperature: 0.5
# bar the and a sex and a bart and and a barty and as a sex the to and a man and a labater I like it a discoler say to my life are the gu
# ------ temperature: 1.0
# and a labater I like it a discoler say to my life are the guy extlend, of There of ey leghit scrowtther's wife evergounce sos oft to Ma
# ------ temperature: 1.2
# here of ey leghit scrowtther's wife evergounce sos oft to Mayher, and out flythrring oex, junt "What help his tack litonut.ed Do he krl
#
# ------------- epoch 15 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 9.1644
# --- Generating with seed: "ural of moose, meese" Which astronaut wears the biggest helm"
# ------ temperature: 0.2
# ural of moose, meese" Which astronaut wears the biggest helm ng axsthlhhmTefwlu cpe angheOs dedehsno eehuiR )   eyeoiie feckrtw m witse
# ------ temperature: 0.5
# fwlu cpe angheOs dedehsno eehuiR )   eyeoiie feckrtw m witsei0w s omen  ate* Ia   Whatv. Yof tw  atCoyeR"  ruifCemWIofpe windom$n ? sa.
# ------ temperature: 1.0
# * Ia   Whatv. Yof tw  atCoyeR"  ruifCemWIofpe windom$n ? sa. -I neW silt favt. khIWlliipedRuM c shhllictuind s jMyfQchedntlegmttPan fod
# ------ temperature: 1.2
# vt. khIWlliipedRuM c shhllictuind s jMyfQchedntlegmttPan fodo  youkd   e" eN r  ea bewcseyy:anfroithh dek ahak om gutt a ate*.coiptrosl
#
# ------------- epoch 16 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 30.5767
# --- Generating with seed: "st made news traveling around slandering the pope and Cathol"
# ------ temperature: 0.2
# st made news traveling around slandering the pope and Cathollci on ornon.anrtcrlulfagr gesksraTp. etriog efnu sahIrihm slh?lhtrobtoppot
# ------ temperature: 0.5
# rtcrlulfagr gesksraTp. etriog efnu sahIrihm slh?lhtrobtoppott s.ngs nlIc bfr4piKe ziwc n aa asthalmwg antgrA re pu r lo cobeMandf a tin
# ------ temperature: 1.0
# r4piKe ziwc n aa asthalmwg antgrA re pu r lo cobeMandf a ting tos oisssocko.ar le" av pfotiflinud wlpwllsfHwr  oefcu  way onsn tursyiea
# ------ temperature: 1.2
# .ar le" av pfotiflinud wlpwllsfHwr  oefcu  way onsn tursyiean t cpovunntmayeny oc odfikfro o brboess uut weFiru    ifomsfr d tyi grytMh
#
# ------------- epoch 17 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 17.0056
# --- Generating with seed: "ly..... ....because I know you cannot read fast" Did you hea"
# ------ temperature: 0.2
# ly..... ....because I know you cannot read fast" Did you heashiJ come ton  :hed .s iha lih twna *w  at dhe moo vi onS in .dy theI.d ch
# ------ temperature: 0.5
# :hed .s iha lih twna *w  at dhe moo vi onS in .dy theI.d ch ac  sin  ,ut ound di aw ,le nethen un cl Wasi s :athyI thyW  x sly nt',ton
# ------ temperature: 1.0
# nd di aw ,le nethen un cl Wasi s :athyI thyW  x sly nt',ton  muky mirh.agankads adhoanst. sonn,ifmbned rago  ocl  thad of]ns thEudeS ..
# ------ temperature: 1.2
# kads adhoanst. sonn,ifmbned rago  ocl  thad of]ns thEudeS ...iraed y mpat lun chryei  egerec   ghiretlanssW . ly 0k ]narpilr eel *ssh.c
#
# ------------- epoch 18 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 10.6967
# --- Generating with seed: "it was upset the name "shampoo" was taken What do you call a"
# ------ temperature: 0.2
# it was upset the name "shampoo" was taken What do you call an wej  idhhithcinefd i gkeChe w su t th" n ,of  hoi th ine tft inipcmbis  a
# ------ temperature: 0.5
# inefd i gkeChe w su t th" n ,of  hoi th ine tft inipcmbis  a iot br *  enie wifnpya  tm ifc  I pe  in who  he o :oenitktl t aat;mee .ob
# ------ temperature: 1.0
#  wifnpya  tm ifc  I pe  in who  he o :oenitktl t aat;mee .obe ofi wkiywhru no clriken hinI"  nunaslej ostentsnne?   aso hjye WheCua  Wh
# ------ temperature: 1.2
# no clriken hinI"  nunaslej ostentsnne?   aso hjye WheCua  Wha aoea* nae Whs"if cieHitdiotul tha mhiseeennt a?r aayirtuiyncdpNerarinffte
#
# ------------- epoch 19 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 8.4560
# --- Generating with seed: ". This man has has a unique set of skills and goes on a reve"
# ------ temperature: 0.2
# . This man has has a unique set of skills and goes on a revec   and cefhe  e p d  ua hyt d ang meS   ah  ghbf  a beWhede  anN ei fu l a
# ------ temperature: 0.5
# e p d  ua hyt d ang meS   ah  ghbf  a beWhede  anN ei fu l a bae ah h acfh' te tat eme?g Wheh  is e  emne nac W ." thxe benara ban dh t
# ------ temperature: 1.0
#  te tat eme?g Wheh  is e  emne nac W ." thxe benara ban dh td e  ec follhaovatdun n  uhayl  b mipebetv sla dare them hhryealear.m akhue
# ------ temperature: 1.2
# vatdun n  uhayl  b mipebetv sla dare them hhryealear.m akhuea,.w  hhie unrhyinoahs Wnaur p  seahr memeoctd yhhahis lo fy   l c acreh lo
#
# ------------- epoch 20 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 9.1741
# --- Generating with seed: "ween priest and acne? What is the difference between a Catho"
# ------ temperature: 0.2
# ween priest and acne? What is the difference between a Catho h pe shaessh he s the Whs sTWooo eoh s aes os isst   oune sosbo phovs s e
# ------ temperature: 0.5
# e s the Whs sTWooo eoh s aes os isst   oune sosbo phovs s e hirs a bpr he o    ha  uss Jo shehetyoe IJ4owhs gaeshewo ooa ss ep oha be s
# ------ temperature: 1.0
#     ha  uss Jo shehetyoe IJ4owhs gaeshewo ooa ss ep oha be stlaa  lavhu1eesh.."? soroihwidedthtos tearohaee   oceb ihwoeoaang.lWuyp  d
# ------ temperature: 1.2
# h.."? soroihwidedthtos tearohaee   oceb ihwoeoaang.lWuyp  d no.ihofresr ifewss yi e sahve .GosmesR iughlls hist? .f sswrepfec'fsiforeu
#
# ------------- epoch 21 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 7.6712
# --- Generating with seed: "at's Santa's favourite metal band? Sleigher. I met my girlfr"
# ------ temperature: 0.2
# at's Santa's favourite metal band? Sleigher. I met my girlfrt   o  e  eo he  fo hand hhh hoh   a he hd   a  thh d   th d  th   he  o
# ------ temperature: 0.5
#   fo hand hhh hoh   a he hd   a  thh d   th d  th   he  o    bou yen e dh  e me thd tdeme bes dh  vn  a  ah dod  bres o oo et  ha h hfe
# ------ temperature: 1.0
# e me thd tdeme bes dh  vn  a  ah dod  bres o oo et  ha h hfed.bd omhhett0bHd anoeh heidseeesobhint tnehlttH teWffe h  thdh Atnwpaa dh d
# ------ temperature: 1.2
# d anoeh heidseeesobhint tnehlttH teWffe h  thdh Atnwpaa dh da  kpoun/IAt  va etryDwe  d d azooiwso  sts fcgh shesdh. gonmth dtMe.eede
#
# ------------- epoch 22 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 6.8519
# --- Generating with seed: ", it's me" They both say in unison. Whenever I see a hot gir"
# ------ temperature: 0.2
# , it's me" They both say in unison. Whenever I see a hot gird" ad ane I'salj  an saiO o an doe to  til  wood an  ood as aPha I an &  le
# ------ temperature: 0.5
# j  an saiO o an doe to  til  wood an  ood as aPha I an &  leyia dod oodTledh asdni dou. MOfa1 sr slanof&ds  oua Dontant  ahed  Wyhoall
# ------ temperature: 1.0
# h asdni dou. MOfa1 sr slanof&ds  oua Dontant  ahed  Wyhoall ionoh d  linesre alvOr  swoa woelus owalo e T"nnkltantyloddd s oeca'm weltl
# ------ temperature: 1.2
# e alvOr  swoa woelus owalo e T"nnkltantyloddd s oeca'm weltlyacdy  nsltlo cdAsnsddreg gorua naThly gy ra cetlv ysoelPd  'ghlepe..wte mo
#
# ------------- epoch 23 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 5.5590
# --- Generating with seed: "true you have lain with a Wildling girl?" Jon Snow: "Yes, si"
# ------ temperature: 0.2
# true you have lain with a Wildling girl?" Jon Snow: "Yes, si  al a  Ba an   a  an a a lan a a  o  a  Hio  ae f  a a" a aL oo a  and  a
# ------ temperature: 0.5
#  a  an a a lan a a  o  a  Hio  ae f  a a" a aL oo a  and  a doah  un f uweEna t Dake sele  i  oonn k anzilera ao b a as  ue ao  Tr la a
# ------ temperature: 1.0
# na t Dake sele  i  oonn k anzilera ao b a as  ue ao  Tr la amiDtt, il  oerie.sn tt Waokt estpoouiorona in aanmpeQt itwhd* W tudbi3mt 't
# ------ temperature: 1.2
# e.sn tt Waokt estpoouiorona in aanmpeQt itwhd* W tudbi3mt 'tisunt'iish  nan iez.,tldnn pesloa e eF iIrtml Totiti tv znthe  lnau   hamen
#
# ------------- epoch 24 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 5.1606
# --- Generating with seed: "t much, but it's all I can afford. What's the difference bet"
# ------ temperature: 0.2
# t much, but it's all I can afford. What's the difference betS e sWie e he   s    o enasa ih cn      nan  eneW  es  e e     I  se      a
# ------ temperature: 0.5
#  s    o enasa ih cn      nan  eneW  es  e e     I  se      aety   ad twokasi , w Iat d.un  Iy  ma o0nl rths  kenndhe  u aOhin s   :s in
# ------ temperature: 1.0
# i , w Iat d.un  Iy  ma o0nl rths  kenndhe  u aOhin s   :s in wsyts mn  ?onefom sethl es  d.eris l fpe onee.hiseW Bwanfkoylre iacher a n
# ------ temperature: 1.2
# fom sethl es  d.eris l fpe onee.hiseW Bwanfkoylre iacher a n t t esi Sstow weMWacbut.yatm. rt stynornsnaw psuokrcc  . fsuoadoUcYen oghr
#
# ------------- epoch 25 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 4.7903
# --- Generating with seed: "riage That's mainly because I've been having the same sex wi"
# ------ temperature: 0.2
# riage That's mainly because I've been having the same sex wi  P" s   S       Is   a  I   w so  H               W B   oew      Mh
# ------ temperature: 0.5
#   Is   a  I   w so  H               W B   oew      Mh          IP sh  go s I nsat  o   s d h    et y  s tI cP   wo  a  e  as Io     a
# ------ temperature: 1.0
# I nsat  o   s d h    et y  s tI cP   wo  a  e  as Io     a  pI?ns  w-n os n m  maeb$yjus H ocrha ads a  h  msIy  wmsdu so Jasto i eds e
# ------ temperature: 1.2
#  m  maeb$yjus H ocrha ads a  h  msIy  wmsdu so Jasto i eds eloavh dd usere l sll gh ayrdctyIa t h  Ihn  ofeg   Ibcig sseorais olh Alie
#
# ------------- epoch 26 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 4.5966
# --- Generating with seed: "hear her say "I love you," she's talking to our dog. Going a"
# ------ temperature: 0.2
# hear her say "I love you," she's talking to our dog. Going a  a    ae   a   a  ateo  a  aa  a  ane     O   a o  al  W      da m   a
# ------ temperature: 0.5
#  a  ateo  a  aa  a  ane     O   a o  al  W      da m   a    t oleoeLdet i eaK a a     an o kcl  tmy eay g  t  Haledd en di ta  el  e ua
# ------ temperature: 1.0
# aK a a     an o kcl  tmy eay g  t  Haledd en di ta  el  e uaioS!a* t n erH lyowh  Ii nI b" etdr ?ls  n, smhmye eecuHslit cnl  hwslomnet
# ------ temperature: 1.2
# lyowh  Ii nI b" etdr ?ls  n, smhmye eecuHslit cnl  hwslomnetujgyadeyg Sdmyg's, ceym  anetdec,tH pensat traho  alfIyetonHmtEol nmdrccel.
#
# ------------- epoch 27 -------------
#  114/1710 [=>............................] - ETA: 26s - loss: 4.2560
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-4032bd106a62> in <module>
#       3 x = tensorflow.cast(x, tensorflow.float32)
#       4 y = tensorflow.cast(y, tensorflow.float32)
# ----> 5 run_text_generation(50, 75)
#
# <ipython-input-23-36f3c76fc1c2> in run_text_generation(epoch_size, generation_size)
#      11         history = model.fit(x, y,
#      12                   batch_size=128,
# ---> 13                   epochs=1)
#      14
#      15         # Select a text seed at random
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Interrupted run at 50 epochs because the loss started converging a lot, and generated quality rapidly dropped. Reran the model with only 10 epochs.

# %%
run_text_generation(10, 75)
# Out:
# ------------- epoch 1 -------------
# 1710/1710 [==============================] - 31s 16ms/step - loss: 2.4214
# --- Generating with seed: "ng stupid Many women say a guy who makes them laugh is all t"
# ------ temperature: 0.2
# ng stupid Many women say a guy who makes them laugh is all the bar and a bar to the ban and a pering and the man and a boople to a bar
# ------ temperature: 0.5
# r to the ban and a pering and the man and a boople to a bar so was a caller to was into the was to up the off to makic a spile off a mo
# ------ temperature: 1.0
#  to was into the was to up the off to makic a spile off a moytlican are adds? Oh Bruemman licalicon. I off thas's the ? My Pild Fiodds
# ------ temperature: 1.2
# s? Oh Bruemman licalicon. I off thas's the ? My Pild Fiodds me Oh you to your intingite Ttad Jamer whick his forridd reals inpart What
#
# ------------- epoch 2 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.8688
# --- Generating with seed: "ne causes a lot of pain and makes a constant high pitched wh"
# ------ temperature: 0.2
# ne causes a lot of pain and makes a constant high pitched when you the most seen to the mead and the start to start a back and the sone
# ------ temperature: 0.5
#  seen to the mead and the start to start a back and the sone the yonith dog home because the start that only dead of so nothing to watc
# ------ temperature: 1.0
#  home because the start that only dead of so nothing to watch for gees Ind aitcest donami-al. you people herving ex, but woman a plose
# ------ temperature: 1.2
# aitcest donami-al. you people herving ex, but woman a plose boit "waltieds curlersion Curriroth every foy always. common and into drad
#
# ------------- epoch 3 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7862
# --- Generating with seed: "essing. If you're drunk, you're 3 sheets to the wind... ...i"
# ------ temperature: 0.2
# essing. If you're drunk, you're 3 sheets to the wind... ...in it can the sece was a buss and a strater the sex to sex the difference be
# ------ temperature: 0.5
# ce was a buss and a strater the sex to sex the difference between my varica hot him sick the colfice what a dog to the not with the pig
# ------ temperature: 1.0
#  hot him sick the colfice what a dog to the not with the pigsn findershe tuasuary Spenclam carlehs is ever bymen?  ? Your inhes xwile h
# ------ temperature: 1.2
# asuary Spenclam carlehs is ever bymen?  ? Your inhes xwile heavias? Is phoullan. Hifey and bike" dog swempt, hey cut a A0nFath. Kor?" S
#
# ------------- epoch 4 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7435
# --- Generating with seed: "mfort myself by thinking "they're just keeping me to themsel"
# ------ temperature: 0.2
# mfort myself by thinking "they're just keeping me to themself a body and the dog the find a chick in a parent of the difference between
# ------ temperature: 0.5
# e dog the find a chick in a parent of the difference between me t
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# he sone thing the money? One this is the lot of and such there is the
# ------ temperature: 1.0
# ing the money? One this is the lot of and such there is the tally through. If my blo thin the molding goat peoole there apped. Talkle h
# ------ temperature: 1.2
# If my blo thin the molding goat peoole there apped. Talkle hik, stitara guys excupter blisonh latel Loly. No. then staght. You've lot i
#
# ------------- epoch 5 -------------
# 1710/1710 [==============================] - 28s 16ms/step - loss: 1.7204
# --- Generating with seed: " to hell, there will be a 6-year-old pushing a shopping cart"
# ------ temperature: 0.2
#  to hell, there will be a 6-year-old pushing a shopping cart the burger and a black the said the park to be the people on the short to
# ------ temperature: 0.5
#  a black the said the park to be the people on the short to be been and a cub today the start of a sangerary most who was for a polerac
# ------ temperature: 1.0
# ub today the start of a sangerary most who was for a poleracer "cent what are in the ig year. West I his guy export. Walt not with a si
# ------ temperature: 1.2
# re in the ig year. West I his guy export. Walt not with a simma Awaching.vierttune.. I think a musesnen? pull cummingwly vaggisch, iaca
#
# ------------- epoch 6 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.7052
# --- Generating with seed: "ealed. You know why you shouldn't eat spaghetti late at nigh"
# ------ temperature: 0.2
# ealed. You know why you shouldn't eat spaghetti late at night and a ground and a girl and a selects and a self and a second can be a sh
# ------ temperature: 0.5
# and a girl and a selects and a self and a second can be a shit than the up and a tamen of the life enough to steal the child that her o
# ------ temperature: 1.0
# and a tamen of the life enough to steal the child that her on Weses? is doesn't want the bubing. Ao the ontins a wrish blub? This, I na
# ------ temperature: 1.2
# sn't want the bubing. Ao the ontins a wrish blub? This, I named do sconredumt, larger pluan: Im smell beout. what many wife I've could
#
# ------------- epoch 7 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.6967
# --- Generating with seed: "omething... something. The more complex the handshake, the l"
# ------ temperature: 0.2
# omething... something. The more complex the handshake, the look that the straight and a both store the straight things who was a second
# ------ temperature: 0.5
# raight and a both store the straight things who was a second and a carried is on best shour snow" I don't put you looks on the wife and
# ------ temperature: 1.0
# is on best shour snow" I don't put you looks on the wife and you bos make cover with jldn, I traunh a brother off thip off their an ele
# ------ temperature: 1.2
# over with jldn, I traunh a brother off thip off their an elecike rid ece: say? Letrgars, Checkou dream? That also more. Westokes my fam
#
# ------------- epoch 8 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.6908
# --- Generating with seed: "ul things about it What's the difference between a blonde an"
# ------ temperature: 0.2
# ul things about it What's the difference between a blonde and a son and a strees and a so the day of the face and a solmy the bartender
# ------ temperature: 0.5
# trees and a so the day of the face and a solmy the bartender and a don't so so the other has a coffee and a living go on my hichen to t
# ------ temperature: 1.0
#  so the other has a coffee and a living go on my hichen to the legs doesns I want your rame and drivers the secking hatmy-famous. The c
# ------ temperature: 1.2
# I want your rame and drivers the secking hatmy-famous. The caty: All my worg mill ConRatiry? queein he stary. 'I'm said before. Just co
#
# ------------- epoch 9 -------------
# 1710/1710 [==============================] - 27s 16ms/step - loss: 1.6955
# --- Generating with seed: "o are my girlfriend's. Why are Father Christmas' reindeer li"
# ------ temperature: 0.2
# o are my girlfriend's. Why are Father Christmas' reindeer like the bartender of a store and a boot of the computer of a stroke of the s
# ------ temperature: 0.5
# r of a store and a boot of the computer of a stroke of the stand and the bitch of a world you forgot the most was to a lot in the not o
# ------ temperature: 1.0
# tch of a world you forgot the most was to a lot in the not of a pretty his from movie. Bould someone confused. we state a life. On day
# ------ temperature: 1.2
# from movie. Bould someone confused. we state a life. On day teach lighter then's was derice have to life hour videas! What's the differ

# %%
model.save('bidirectional_lstm.h5')

# %%
complete_joke('There are three types of people you always meet in the world', 100)
# Out:
# ------ temperature: 0.2
# There are three types of people you always meet in the world to start the store to the best the pickles of the bar and a bar the stroke and a store the back of
# ------ temperature: 0.5
# There are three types of people you always meet in the world to store to make for a most of a long sintic the burce of the only the always was i
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# n a dick and a d
# ------ temperature: 1.0
# There are three types of people you always meet in the world of the incopa gard, surpers papers hear I got man any her ups. Retouling to pet droming as not work
# ------ temperature: 1.2
# There are three types of people you always meet in the world's Skebuls-fam long into Yo Idooms that a new has mow soo. What do you need from homes. lucker pakes

# %%
complete_joke('A dog, a cat, and a giraffe walk into an empty bar and order', 100)
# Out:
# ------ temperature: 0.2
# A dog, a cat, and a giraffe walk into an empty bar and order the stand of the store to start the not to the bartender of the life was a strand of a store that t
# ------ temperature: 0.5
# A dog, a cat, and a giraffe walk into an empty bar and orders and his racist is complay in the time of it have says to the looge to the stroke? A not joke of th
# ------ temperature: 1.0
# A dog, a cat, and a giraffe walk into an empty bar and ordering a mass? A: N stroke to do I cell, as the srightbulb.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  Americans shakes about without her plays of
# ------ temperature: 1.2
# A dog, a cat, and a giraffe walk into an empty bar and order: knew bulb? Wank. A Snanmoto. Make. ? MY Md, but line Bwenal go about Phobed keep hole cur man Mar

# %%
complete_joke('stray even in its own path and is sitting intoxicated in som', 100)
# Out:
# ------ temperature: 0.2
# stray even in its own path and is sitting intoxicated in some convent of the store the time of a computer of the police of the bartender of the bartender of the
# ------ temperature: 0.5
# stray even in its own path and is sitting intoxicated in some because if they stop a stroke to stop stand the poother that should be the first to t
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# he computer a
# ------ temperature: 1.0
# stray even in its own path and is sitting intoxicated in some naite." "You have to so serviewe hat you can't will an urd.... So if you u tuads home would so wet
# ------ temperature: 1.2
# stray even in its own path and is sitting intoxicated in someooo greep. Just and a why would seel siaver... Because happy to start asulamesly, I'm jose. Why did

# %% [markdown]
# ### Implemeting Transformer based miniature GPT model for text generation
#
# For comparison, I also implemented a transformer based model. The model I chose was a miniature GPT model based.
#
# Reference: https://keras.io/examples/generative/text_generation_with_miniature_gpt/
#
#
# Setup

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
import numpy as np
import os
import re
import string
import random

# %% [markdown]
# Implement a Transformer block as a layer

# %%
def causal_attention_mask(batch_size, n_dest, n_src, dtype):
    """
    Mask the upper half of the dot product matrix in self attention.
    This prevents flow of information from future tokens to current token.
    1's in the lower triangle, counting from the lower right corner.
    """
    i = tf.range(n_dest)[:, None]
    j = tf.range(n_src)
    m = i >= j - n_src + n_dest
    mask = tf.cast(m, dtype)
    mask = tf.reshape(mask, [1, n_dest, n_src])
    mult = tf.concat(
        [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
    )
    return tf.tile(mask, mult)


class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads, embed_dim)
        self.ffn = keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        attention_output = self.att(inputs, inputs, attention_mask=causal_mask)
        attention_output = self.dropout1(attention_output)
        out1 = self.layernorm1(inputs + attention_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output)
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# Implement an embedding layer

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %% [markdown]
# Implement the miniature GPT model

# %%
vocab_size = 30000  # Only consider the top 30k words
maxlen = 80  # Max sequence size
embed_dim = 256  # Embedding size for each token
num_heads = 2  # Number of attention heads
feed_forward_dim = 256  # Hidden layer size in feed forward network inside transformer


def create_model():
    inputs = layers.Input(shape=(maxlen,), dtype=tf.int32)
    embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, num_heads, feed_forward_dim)
    x = transformer_block(x)
    outputs = layers.Dense(vocab_size)(x)
    model = keras.Model(inputs=inputs, outputs=[outputs, x])
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(
        "adam", loss=[loss_fn, None],
    )  # No loss and optimization based on word embeddings from transformer block
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 80)]              0
# _________________________________________________________________
# token_and_position_embedding (None, 80, 256)           7700480
# _________________________________________________________________
# transformer_block_9 (Transfo (None, 80, 256)           658688
# _________________________________________________________________
# dense_31 (Dense)             (None, 80, 30000)         7710000
# =================================================================
# Total params: 16,069,168
# Trainable params: 16,069,168
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Prepare the dataset for word-level language modeling

# %%
import csv

file = open('shortjokes.csv')
csvreader = csv.reader(file)
jokes_text = []
jokes_sample_size = 10001
jokes_count = 0

for row in csvreader:
    jokes_count += 1
    if jokes_count > jokes_sample_size:
        break
    jokes_text.append(row[1])
    
jokes_text = jokes_text[1:]

# %%
batch_size = 128

# Create a dataset
text_ds = tf.data.Dataset.from_tensor_slices(jokes_text)
text_ds = text_ds.shuffle(buffer_size=256)
text_ds = text_ds.batch(batch_size)


def custom_standardization(input_string):
    """ Remove html line-break tags and handle punctuation """
    lowercased = tf.strings.lower(input_string)
    stripped_html = tf.strings.regex_replace(lowercased, "<br />", " ")
    return tf.strings.regex_replace(stripped_html, f"([{string.punctuation}])", r" \1")


# Create a vectorization layer and adapt it to the text
vectorize_layer = TextVectorization(
    standardize=custom_standardization,
    max_tokens=vocab_size - 1,
    output_mode="int",
    output_sequence_length=maxlen + 1,
)
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()  # To get words back from token indices


def prepare_lm_inputs_labels(text):
    """
    Shift word sequences by 1 position so that the target for position (i) is
    word at position (i+1). The model will use all words up till position (i)
    to predict the next word.
    """
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


text_ds = text_ds.map(prepare_lm_inputs_labels)
text_ds = text_ds.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# Implement a Keras callback for generating text

# %%
class TextGenerator(keras.callbacks.Callback):
    """A callback to generate text from a trained model.
    1. Feed some starting prompt to the model
    2. Predict probabilities for the next token
    3. Sample the next token and add it to the next input

    Arguments:
        max_tokens: Integer, the number of tokens to be generated after prompt.
        start_tokens: List of integers, the token indices for the starting prompt.
        index_to_word: List of strings, obtained from the TextVectorization layer.
        top_k: Integer, sample from the `top_k` token predictions.
        print_every: Integer, print after this many epochs.
    """

    def __init__(
        self, max_tokens, start_tokens, index_to_word, top_k=10, print_every=1
    ):
        self.max_tokens = max_tokens
        self.start_tokens = start_tokens
        self.index_to_word = index_to_word
        self.print_every = print_every
        self.k = top_k

    def sample_from(self, logits):
        logits, indices = tf.math.top_k(logits, k=self.k, sorted=True)
        indices = np.asarray(indices).astype("int32")
        preds = keras.activations.softmax(tf.expand_dims(logits, 0))[0]
        preds = np.asarray(preds).astype("float32")
        return np.random.choice(indices, p=preds)

    def detokenize(self, number):
        return self.index_to_word[number]

    def on_epoch_end(self, epoch, logs=None):
        start_tokens = [_ for _ in self.start_tokens]
        if (epoch + 1) % self.print_every != 0:
            return
        num_tokens_generated = 0
        tokens_generated = []
        while num_tokens_generated <= self.max_tokens:
            pad_len = maxlen - len(start_tokens)
            sample_index = len(start_tokens) - 1
            if pad_len < 0:
                x = start_tokens[:maxlen]
                sample_index = maxlen - 1
            elif pad_len > 0:
                x = start_tokens + [0] * pad_len
            else:
                x = start_tokens
            x = np.array([x])
            y, _ = self.model.predict(x)
            sample_token = self.sample_from(y[0][sample_index])
            tokens_generated.append(sample_token)
            start_tokens.append(sample_token)
            num_tokens_generated = len(tokens_generated)
        txt = " ".join(
            [self.detokenize(_) for _ in self.start_tokens + tokens_generated]
        )
        print(f"generated text:\n{txt}\n")


# Tokenize starting prompt
word_to_index = {}
for index, word in enumerate(vocab):
    word_to_index[word] = index

start_prompt = "So there are three types of people you always meet in the world"
start_tokens = [word_to_index.get(_, 1) for _ in start_prompt.split()]
num_tokens_generated = 100
text_gen_callback = TextGenerator(num_tokens_generated, start_tokens, vocab)

# %% [markdown]
# Train the model

# %%
model = create_model()

model.fit(text_ds, verbose=2, epochs=25, callbacks=[text_gen_callback])
# Out:
# Epoch 1/25
# 79/79 - 20s - loss: 3.0822 - dense_27_loss: 3.0822
# generated text:
# [UNK] there are three types of people you always meet in the world a a a i the , and . .
#
# Epoch 2/25
# 79/79 - 19s - loss: 1.5742 - dense_27_loss: 1.5742
# generated text:
# [UNK] there are three types of people you always meet in the world , but i 'm the other . .
#
# Epoch 3/25
# 79/79 - 19s - loss: 1.3578 - dense_27_loss: 1.3578
# generated text:
# [UNK] there are three types of people you always meet in the world 's .
#
# Epoch 4/25
# 79/79 - 19s - loss: 1.2276 - dense_27_loss: 1.2276
# generated text:
# [UNK] there are three types of people you always meet in the world . .
#
# Epoch 5/25
# 79/79 - 20s - loss: 1.1260 - dense_27_loss: 1.1260
# generated text:
# [UNK] there are three types of people you always meet in the world ! " - i 'm going to the back of people are in a busty crustacean .
#
# Epoch 6/25
# 79/79 - 20s - loss: 1.0379 - dense_27_loss: 1.0379
# generated text:
# [UNK] there are three types of people you always meet in the world . . . . . . . . . . . . . . . . . . . . . . . . . the bartender : they can 't get to do i 'm going to do you get the other , but it 's
#
# Epoch 7/25
# 79/79 - 20s - loss: 0.9574 - dense_27_loss: 0.9574
# generated text:
# [UNK] there are three types of people you always meet in the world . . .
#
# Epoch 8/25
# 79/79 - 20s - loss: 0.8830 - dense_27_loss: 0.8830
# generated text:
# [UNK] there are three types of people you always meet in the world . .
#
# Epoch 9/25
# 79/79 - 20s - loss: 0.8136 - dense_27_loss: 0.8136
# generated text:
# [UNK] there are three types of people you always meet in the world war . they don 't know who . that 's hair .
#
# Epoch 10/25
# 79/79 - 20s - loss: 0.7478 - dense_27_loss: 0.7478
# generated text:
# [UNK] there are three types of people you always meet in the world . . but they can 't believe this joke
#
# Epoch 11/25
# 79/79 - 20s - loss: 0.6839 - dense_27_loss: 0.6839
# generated text:
# [UNK] there are three types of people you always meet in the world . . and this one of those people say , i 'm still can 't have a whole life savings he is a
#
# Epoch 12/25
# 79/79 - 20s - loss: 0.6230 - dense_27_loss: 0.6230
# generated text:
# [UNK] there are three types of people you always meet in the world . . who 's just uncultured .
#
# Epoch 13/25
# 79/79 - 20s - loss: 0.5680 - dense_27_loss: 0.5680
# generated text:
# [UNK] there are three types of people you always meet in the world cup and they don 't know what do .
#
# Epoch 14/25
# 79/79 - 20s - loss: 0.5172 - dense_27_loss: 0.5172
# generated text:
# [UNK] there are three types of people you always meet in the world housing !
#
# Epoch 15/25
# 79/79 - 20s - loss: 0.4705 - dense_27_loss: 0.4705
# generated text:
# [UNK] there are three types of people you always meet in the world those that 's why they 're identical too . .
#
# Epoch 16/25
# 79/79 - 20s - loss: 0.4314 - dense_27_loss: 0.4314
# generated text:
# [UNK] there are three types of people you always meet in the world cup .
#
# Epoch 17/25
# 79/79 - 20s - loss: 0.3952 - dense_27_loss: 0.3952
# generated text:
# [UNK] there are three types of people you always meet in the world . that 's two years .
#
# Epoch 18/25
# 79/79 - 20s - loss: 0.3640 - dense_27_loss: 0.3640
# generated text:
# [UNK] there are three types of people you always meet in the world much right through 4 .
#
# Epoch 19/25
# 79/79 - 20s - loss: 0.3377 - dense_27_loss: 0.3377
# generated text:
# [UNK] there are three types of people you always meet in the world housing !
#
# Epoch 20/25
# 79/79 - 20s - loss: 0.3150 - dense_27_loss: 0.3150
# generated text:
# [UNK] there are three types of people you always meet in the world war two .
#
# Epoch 21/25
# 79/79 - 20s - loss: 0.2954 - dense_27_loss: 0.2954
# generated text:
# [UNK] there are three types of people you always meet in the world . that most people aren 't buying them out .
#
# Epoch 22/25
# 79/79 - 20s - loss: 0.2779 - dense_27_loss: 0.2779
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him .
#
# Epoch 23/25
# 79/79 - 20s - loss: 0.2623 - dense_27_loss: 0.2623
# generated text:
# [UNK] there are three types of people you always meet in the world housing !
#
# Epoch 24/25
# 79/79 - 20s - loss: 0.2487 - dense_27_loss: 0.2487
# generated text:
# [UNK] there are three types of people you always meet in the world cup , and now , and the slide show and fuck , and water .
#
# Epoch 25/25
# 79/79 - 20s - loss: 0.2363 - dense_27_loss: 0.2363
# generated text:
# [UNK] there are three types of people you always meet in the world ! that day and people will run away peacefully if his sheep

# %% [markdown]
# Running for further 25 epochs

# %%
model.fit(text_ds, verbose=2, epochs=25, callbacks=[text_gen_callback])
# Out:
# Epoch 1/25
# 79/79 - 19s - loss: 0.2251 - dense_27_loss: 0.2251
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him .
#
# Epoch 2/25
# 79/79 - 19s - loss: 0.2136 - dense_27_loss: 0.2136
# generated text:
# [UNK] there are three types of people you always meet in the world cup of people and now .
#
# Epoch 3/25
# 79/79 - 19s - loss: 0.2048 - dense_27_loss: 0.2048
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him .
#
# Epoch 4/25
# 79/79 - 19s - loss: 0.1972 - dense_27_loss: 0.1972
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him him .
#
# Epoch 5/25
# 79/79 - 19s - loss: 0.1899 - dense_27_loss: 0.1899
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him .
#
# Epoch 6/25
# 79/79 - 19s - loss: 0.1824 - dense_27_loss: 0.1824
# generated text:
# [UNK] there are three types of people you always meet in the world cup of them .
#
# Epoch 7/25
# 79/79 - 20s - loss: 0.1748 - dense_27_loss: 0.1748
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him .
#
# Epoch 8/25
# 79/79 - 20s - loss: 0.1693 - dense_27_loss: 0.1693
# generated text:
# [UNK] there are three types of people you always meet in the world cup , and playing with a glass of them .
#
# Epoch 9/25
# 79/79 - 20s - loss: 0.1632 - dense_27_loss: 0.1632
# generated text:
# [UNK] there are three types of people you always meet in the world war .
#
# Epoch 10/25
# 79/79 - 20s - loss: 0.1596 - dense_27_loss: 0.1596
# generated text:
# [UNK] there are three types of people you always meet in the world wide . them ) those people in the ocean ? a whole wig
#
# Epoch 11/25
# 79/79 - 20s - loss: 0.1551 - dense_27_loss: 0.1551
# generated text:
# [UNK] there are three types of people you always meet in the world war .
#
# Epoch 12/25
# 79/79 - 20s - loss: 0.1537 - dense_27_loss: 0.1537
# generated text:
# [UNK] there are three types of people you always meet in the world seven years .
#
# Epoch 13/25
# 79/79 - 20s - loss: 0.1478 - dense_27_loss: 0.1478
# generated text:
# [UNK] there are three types of people you always meet in the world cereal .
#
# Epoch 14/25
# 79/79 - 20s - loss: 0.1438 - dense_27_loss: 0.1438
# generated text:
# [UNK] there are three types of people you always meet in the world 1 . that 's been .
#
# Epoch 15/25
# 79/79 - 20s - loss: 0.1415 - dense_27_loss: 0.1415
# generated text:
# [UNK] there are three types of people you always meet in the world housing , ! !
#
# Epoch 16/25
# 79/79 - 20s - loss: 0.1396 - dense_27_loss: 0.1396
# generated text:
# [UNK] there are three types of people you always meet in the world , and alcohol . that 's been in my socks .
#
# Epoch 17/25
# 79/79 - 20s - loss: 0.1377 - dense_27_loss: 0.1377
# generated text:
# [UNK] there are three types of people you always meet in the world sheep , and blowing up !
#
# Epoch 18/25
# 79/79 - 20s - loss: 0.1351 - dense_27_loss: 0.1351
# generated text:
# [UNK] there are three types of people you always meet in the world .
#
# Epoch 19/25
# 79/79 - 20s - loss: 0.1328 - dense_27_loss: 0.1328
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him .
#
# Epoch 20/25
# 79/79 - 20s - loss: 0.1306 - dense_27_loss: 0.1306
# generated text:
# [UNK] there are three types of people you always meet in the world .
#
# Epoch 21/25
# 79/79 - 20s - loss: 0.1294 - dense_27_loss: 0.1294
# generated text:
# [UNK] there are three types of people you always meet in the world .
#
# Epoch 22/25
# 79/79 - 20s - loss: 0.1277 - dense_27_loss: 0.1277
# generated text:
# [UNK] there are three types of people you always meet in the world . that 's a new species .
#
# Epoch 23/25
# 79/79 - 20s - loss: 0.1259 - dense_27_loss: 0.1259
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him down him .
#
# Epoch 24/25
# 79/79 - 20s - loss: 0.1246 - dense_27_loss: 0.1246
# generated text:
# [UNK] there are three types of people you always meet in the world .
#
# Epoch 25/25
# 79/79 - 20s - loss: 0.1235 - dense_27_loss: 0.1235
# generated text:
# [UNK] there are three types of people you always meet in the world revolves around him him him .
